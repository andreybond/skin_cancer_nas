# %% [markdown]
# # Code for model estimation

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.metrics import classification_report

from sklearn.metrics import roc_curve, auc

import matplotlib.pyplot as plt

from sklearn.preprocessing import OneHotEncoder

# %%
l = 2
set_id = 3
fold_n = 0
#                            models/darts_retrained/6ch_128x128_no_metainfo_registered_5Fold_newC43-5f/XV2_SGD_orig_02DropChannel_5 lrs_2oct_newC43NoDup_ClassSet8 _ManCorected_registered_350epochs_fold-0/validation4_logits_predictions.csv
validation_file_path="/mnt/models/darts_retrained/6ch_128x128_no_metainfo_registered_5Fold_newC43-5f/XV2_SGD_orig_02DropChannel_{}lrs_2oct_newC43NoDup_ClassSet{}_ManCorected_registered_350epochs_fold-{}/validation4_logits_predictions.csv".format(l, set_id, fold_n)
train_file_path="/mnt/models/darts_retrained/6ch_128x128_no_metainfo_registered_5Fold_newC43-5f/XV2_SGD_orig_02DropChannel_{}lrs_2oct_newC43NoDup_ClassSet{}_ManCorected_registered_350epochs_fold-{}/train4_logits_predictions.csv".format(l, set_id, fold_n)

df_val = pd.read_csv(validation_file_path, index_col=0)
df_train = pd.read_csv(train_file_path, index_col=0)

# %%
df_val
# Out:
#      true_value  pred_value    logit_0    logit_1    logit_2   logit_3
# 0           0.0         0.0  10.862171  -3.860684  -3.940548 -2.183483
# 1           0.0         2.0 -10.078033 -12.643808  15.660099  7.538659
# 2           0.0         0.0  10.862171  -3.860684  -3.940548 -2.183483
# 3           0.0         1.0  -0.770609   3.256650  -2.877132  0.536556
# 4           0.0         0.0   8.381739  -1.337310  -4.462004 -2.587733
# ..          ...         ...        ...        ...        ...       ...
# 175         3.0         3.0  -7.954622  -1.330556   3.344617  5.879862
# 176         3.0         3.0  -4.412617  -7.270431   2.767723  9.146964
# 177         3.0         0.0   5.477484   0.297902  -4.540776 -1.008942
# 178         3.0         2.0  -7.815864  -3.889286   7.416153  4.059173
# 179         3.0         1.0   2.111175   4.621544  -2.775423 -3.823961
#
# [180 rows x 6 columns]

# %%
from sklearn.metrics import precision_recall_fscore_support
precision_recall_fscore_support(df_val['true_value'], df_val['pred_value'], average='weighted')
# Out:
# (0.7206156156156156, 0.7166666666666667, 0.7183608841980127, None)

# %%
import seaborn as sn

# %%
# https://stackoverflow.com/questions/55541254/precision-recall-curve-with-n-fold-cross-validation-showing-standard-deviation

import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import make_blobs
from sklearn.metrics import precision_recall_curve, auc
from sklearn.model_selection import KFold
from sklearn.svm import SVC
from numpy import interp
from sklearn.metrics import auc

X, y = make_blobs(n_samples=500, n_features=2, centers=2, cluster_std=10.0,
    random_state=10)

k_fold = KFold(n_splits=5, shuffle=True, random_state=10)
predictor = SVC(kernel='linear', C=1.0, probability=True, random_state=10)

y_real = []
y_proba = []

precision_array = []
threshold_array=[]
recall_array = np.linspace(0, 1, 100)

for i, (train_index, test_index) in enumerate(k_fold.split(X)):
    Xtrain, Xtest = X[train_index], X[test_index]
    ytrain, ytest = y[train_index], y[test_index]
    predictor.fit(Xtrain, ytrain)
    pred_proba = predictor.predict_proba(Xtest)
    precision_fold, recall_fold, thresh = precision_recall_curve(ytest, pred_proba[:,1])
    precision_fold, recall_fold, thresh = precision_fold[::-1], recall_fold[::-1], thresh[::-1]  # reverse order of results
    thresh = np.insert(thresh, 0, 1.0)
    precision_array = interp(recall_array, recall_fold, precision_fold)
    threshold_array = interp(recall_array, recall_fold, thresh)
    pr_auc = auc(recall_array, precision_array)

    lab_fold = 'Fold %d AUC=%.4f' % (i+1, pr_auc)
    plt.plot(recall_fold, precision_fold, alpha=0.3, label=lab_fold)
    y_real.append(ytest)
    y_proba.append(pred_proba[:,1])

y_real = np.concatenate(y_real)
y_proba = np.concatenate(y_proba)
precision, recall, _ = precision_recall_curve(y_real, y_proba)
lab = 'Overall AUC=%.4f' % (auc(recall, precision))

plt.plot(recall, precision, lw=2,color='red', label=lab)

plt.legend(loc='lower left', fontsize='small')

mean_precision = np.mean(precision_array)
std_precision = np.std(precision_array)
plt.fill_between(recall, precision + std_precision, precision - std_precision, alpha=0.3, linewidth=0, color='grey')
plt.show()

# %% [markdown]
# # Metrics calculation

# %%
from sklearn.metrics import roc_auc_score

class MultiClassMetrics():
    def __init__(self, y_true, y_pred):
        self.y_true = y_true
        self.y_pred = y_pred
        
    def calculate_scores(self, class_mapping_dict=None):
    
        y_true_ = self.y_true
        y_pred_ = self.y_pred
        if classes_map_dict is not None:
            y_true_ = y_true_.map(classes_map_dict)
            y_pred_ = y_pred_.map(classes_map_dict)
    
        self.cnf_matrix = confusion_matrix(y_true_, y_pred_)
        self.FP = self.cnf_matrix.sum(axis=0) - np.diag(self.cnf_matrix) 
        self.FN = self.cnf_matrix.sum(axis=1) - np.diag(self.cnf_matrix)
        self.TP = np.diag(self.cnf_matrix)
        self.TN = self.cnf_matrix.sum() - (self.FP + self.FN + self.TP)
        self.FP = self.FP.astype(float)
        self.FN = self.FN.astype(float)
        self.TP = self.TP.astype(float)
        self.TN = self.TN.astype(float)
        # Sensitivity, hit rate, recall, or true positive rate
        self.TPR = self.TP/(self.TP+self.FN)
        # Specificity or true negative rate
        self.TNR = self.TN/(self.TN+self.FP) 
        # Precision or positive predictive value
        self.PPV = self.TP/(self.TP+self.FP)
        # Negative predictive value
        self.NPV = self.TN/(self.TN+self.FN)
        # Fall out or false positive rate
        self.FPR = self.FP/(self.FP+self.TN)
        # False negative rate
        self.FNR = self.FN/(self.TP+self.FN)
        # False discovery rate
        self.FDR = self.FP/(self.TP+self.FP)
        # Overall accuracy for each class
        self.ACC = (self.TP+self.TN)/(self.TP+self.FP+self.FN+self.TN)

        self.F1_micro = f1_score(y_true_, y_pred_, average='micro')
        self.F1_macro = f1_score(y_true_, y_pred_, average='macro')
        self.F1_weighted = f1_score(y_true_, y_pred_, average='weighted')
        
#         self.AUC = auc(y_true_, y_pred_)

class MultiClassFoldsMetrics():
    def __init__(self, multi_class_metrics_list):
        self.multi_class_metrics_list = multi_class_metrics_list
        
    def calc_scores(self, class_mapping_dict=None, classes_n=None):
#         classes_n = self.multi_class_metrics_list[0].y_true.unique().shape[0]
        folds_n = len(self.multi_class_metrics_list)
        
        self.classes_n = classes_n
        self.folds_n = folds_n
        
        self.TPR_arr = np.zeros((folds_n, classes_n))
        self.TNR_arr = np.zeros((folds_n, classes_n))
        self.PPV_arr = np.zeros((folds_n, classes_n))
        self.NPV_arr = np.zeros((folds_n, classes_n))
        self.FPR_arr = np.zeros((folds_n, classes_n))
        self.FNR_arr = np.zeros((folds_n, classes_n))
        self.FDR_arr = np.zeros((folds_n, classes_n))
        self.ACC_arr = np.zeros((folds_n, classes_n))
        self.F1_micro_arr = np.zeros((folds_n))
        self.F1_macro_arr = np.zeros((folds_n))
        self.F1_weighted_arr = np.zeros((folds_n))
        self.cnf_matrix_arr = np.zeros((classes_n, classes_n))
#         self.AUC_arr = np.zeros((folds_n, classes_n))
        
        fold_n = 0
        for m in self.multi_class_metrics_list:
            m.calculate_scores(class_mapping_dict)

            self.TPR_arr[fold_n,:]=m.TPR
            self.TNR_arr[fold_n,:]=m.TNR
            self.PPV_arr[fold_n,:]=m.PPV
            self.NPV_arr[fold_n,:]=m.NPV
            self.FPR_arr[fold_n,:]=m.FPR
            self.FNR_arr[fold_n,:]=m.FNR
            self.FDR_arr[fold_n,:]=m.FDR
            self.ACC_arr[fold_n,:]=m.ACC
            self.F1_micro_arr[fold_n]=m.F1_micro
            self.F1_macro_arr[fold_n]=m.F1_macro
            self.F1_weighted_arr[fold_n]=m.F1_weighted
            self.cnf_matrix_arr = np.add(self.cnf_matrix_arr, m.cnf_matrix)
            
#             self.AUC_arr = m.AUC
            
            fold_n = fold_n + 1
            
    def print_scores(self):
        print('TPR={}, TNR={}, PPV={}, NPV={}, FPR={}, FNR={}, FDR={}, ACC={}, F1_micro={}, F1_macro={}, F1_weighted={}'.format(  #, AUC={}
                self.TPR_arr.mean(axis=0), 
                self.TNR_arr.mean(axis=0), 
                self.PPV_arr.mean(axis=0), 
                self.NPV_arr.mean(axis=0), 
                self.FPR_arr.mean(axis=0), 
                self.FNR_arr.mean(axis=0), 
                self.FDR_arr.mean(axis=0), 
                self.ACC_arr.mean(axis=0), 
                self.F1_micro_arr.mean(), 
                self.F1_macro_arr.mean(), 
                self.F1_weighted_arr.mean()  #,
#                 self.AUC_arr.mean(axis=0) 
                )
             )
        print('{}'.format(self.cnf_matrix_arr))
        
    def print_mean_classification_report(self, classes_map_dict=None, target_names=None):
        y_true_, y_pred_ = self.collect_ys(classes_map_dict)
        print(classification_report(y_true_, y_pred_, target_names=target_names))
        
    def collect_ys(self, classes_map_dict=None):
        y_true_ = pd.Series()
        y_pred_ = pd.Series()
        for m in self.multi_class_metrics_list:
            __y_tr = m.y_true.copy()
            __y_pr = m.y_pred.copy()
            
            if classes_map_dict is not None:
                __y_tr = __y_tr.map(classes_map_dict)
                __y_pr = __y_pr.map(classes_map_dict)
                
            y_true_ = y_true_.append(__y_tr, ignore_index=True, verify_integrity=False)
            y_pred_ = y_pred_.append(__y_pr, ignore_index=True, verify_integrity=False)
            
        return y_true_, y_pred_

# %%
def build_multi_class_metrics_list(val_file_template, layer, set_id, folds_n, classes_n):
    
    multi_class_metrics_list = []
    for fold_n in range(folds_n):
        file_path=val_file_template.format(layer, set_id, fold_n)
        df = pd.read_csv(file_path)
        
        true_value = df['true_value']
        pred_value = df['pred_value']
        
        multi_class_metric = MultiClassMetrics(true_value, pred_value)
        multi_class_metrics_list.append(multi_class_metric)
        
    return MultiClassFoldsMetrics(multi_class_metrics_list)

# %%
val_file_template="/mnt/models/darts_retrained/6ch_128x128_no_metainfo_registered_5Fold_newC43-5f/XV2_SGD_orig_02DropChannel_{}lrs_2oct_newC43NoDup_ClassSet{}_ManCorected_registered_350epochs_fold-{}/validation4_logits_predictions.csv"
train_file_template="/mnt/models/darts_retrained/6ch_128x128_no_metainfo_registered_5Fold_newC43-5f/XV2_SGD_orig_02DropChannel_{}lrs_2oct_newC43NoDup_ClassSet{}_ManCorected_registered_350epochs_fold-{}/train4_logits_predictions.csv"

# %% [markdown]
# # ClassSet1

# %%
layers = [1,2,3,4,5]
sets = [1]

folds_n = 5
classes_n = 2

for l in layers:
    for set_id in sets:
        
        print('Layers-{}, Set-{}'.format(l, set_id))
        
        print('Validation:')
#         val_file_template = validation_file_path.format()
#         val_file_template = "/mnt/models/darts_retrained/6ch_128x128_no_metainfo_registered_10Fold/XV2_SGD_orig_02DropChannel_{}lrs_2oct_ClassSet{}_ManCorected_registered_fold-{}/validation2_logits_predictions.csv"
        multi_class_folds_metrics = build_multi_class_metrics_list(val_file_template, l, set_id, folds_n, classes_n)
        
        classes_map_dict = None
        multi_class_folds_metrics.calc_scores(classes_map_dict, classes_n)
        multi_class_folds_metrics.print_scores()
        multi_class_folds_metrics.print_mean_classification_report(classes_map_dict, target_names=['Melanoma_like_lesions', 'Pigmented_benign'])
      
        
        print('--------------------------------')
        
        
        print('Training:')
#         val_file_template = "/mnt/models/darts_retrained/6ch_128x128_no_metainfo_registered_10Fold/XV2_SGD_orig_02DropChannel_{}lrs_2oct_ClassSet{}_ManCorected_registered_fold-{}/train2_logits_predictions.csv"
        multi_class_folds_metrics = build_multi_class_metrics_list(train_file_template, l, set_id, folds_n, classes_n)
        
        classes_map_dict = None
        multi_class_folds_metrics.calc_scores(classes_map_dict, classes_n)
        multi_class_folds_metrics.print_scores()
        multi_class_folds_metrics.print_mean_classification_report(classes_map_dict, target_names=['Melanoma_like_lesions', 'Pigmented_benign'])
        
        print('--------------------------------')
        print('================================')
        print('--------------------------------')
# Out:
# Layers-1, Set-1
# Validation:
# TPR=[0.72747253 0.95808491], TNR=[0.95808491 0.72747253], PPV=[0.73907563 0.95625831], NPV=[0.95625831 0.73907563], FPR=[0.04191509 0.27252747], FNR=[0.27252747 0.04191509], FDR=[0.26092437 0.04374169], ACC=[0.92579787 0.92579787], F1_micro=0.9257978723404255, F1_macro=0.8424306888792208, F1_weighted=0.9249793859288753
# [[ 48.  18.]
#  [ 17. 389.]]
#                        precision    recall  f1-score   support
#
# Melanoma_like_lesions       0.74      0.73      0.73        66
#      Pigmented_benign       0.96      0.96      0.96       406
#
#              accuracy                           0.93       472
#             macro avg       0.85      0.84      0.84       472
#          weighted avg       0.93      0.93      0.93       472
#
# --------------------------------
# Training:
# TPR=[0.95065312 0.99876923], TNR=[0.99876923 0.95065312], PPV=[0.99215686 0.99206198], NPV=[0.99206198 0.99215686], FPR=[0.00123077 0.04934688], FNR=[0.04934688 0.00123077], FDR=[0.00784314 0.00793802], ACC=[0.99205223 0.99205223], F1_micro=0.9920522346054261, F1_macro=0.983095162080479, F1_weighted=0.9919625301000092
# [[ 251.   13.]
#  [   2. 1622.]]
#                        precision    recall  f1-score   support
#
# Melanoma_like_lesions       0.99      0.95      0.97       264
#      Pigmented_benign       0.99      1.00      1.00      1624
#
#              accuracy                           0.99      1888
#             macro avg       0.99      0.97      0.98      1888
#          weighted avg       0.99      0.99      0.99      1888
#
# --------------------------------
# ================================
# --------------------------------
# Layers-2, Set-1
# Validation:
# TPR=[0.83296703 0.96052394], TNR=[0.96052394 0.83296703], PPV=[0.78358112 0.97251197], NPV=[0.97251197 0.78358112], FPR=[0.03947606 0.16703297], FNR=[0.16703297 0.03947606], FDR=[0.21641888 0.02748803], ACC=[0.94268617 0.94268617], F1_micro=0.942686170212766, F1_macro=0.8857518271423978, F1_weighted=0.9439352453743137
# [[ 55.  11.]
#  [ 16. 390.]]
#                        precision    recall  f1-score   support
#
# Melanoma_like_lesions       0.77      0.83      0.80        66
#      Pigmented_benign       0.97      0.96      0.97       406
#
#              accuracy                           0.94       472
#             macro avg       0.87      0.90      0.88       472
#          weighted avg       0.94      0.94      0.94       472
#
# --------------------------------
# Training:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:117: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:118: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# TPR=[1.         0.99938462], TNR=[0.99938462 1.        ], PPV=[0.9962963 1.       ], NPV=[1.        0.9962963], FPR=[0.00061538 0.        ], FNR=[0.         0.00061538], FDR=[0.0037037 0.       ], ACC=[0.9994709 0.9994709], F1_micro=0.9994708994708994, F1_macro=0.9989113373558169, F1_weighted=0.9994729642757522
# [[2.640e+02 0.000e+00]
#  [1.000e+00 1.623e+03]]
#                        precision    recall  f1-score   support
#
# Melanoma_like_lesions       1.00      1.00      1.00       264
#      Pigmented_benign       1.00      1.00      1.00      1624
#
#              accuracy                           1.00      1888
#             macro avg       1.00      1.00      1.00      1888
#          weighted avg       1.00      1.00      1.00      1888
#
# --------------------------------
# ================================
# --------------------------------
# Layers-3, Set-1
# Validation:
# TPR=[0.78901099 0.96055405], TNR=[0.96055405 0.78901099], PPV=[0.77662142 0.96540003], NPV=[0.96540003 0.77662142], FPR=[0.03944595 0.21098901], FNR=[0.21098901 0.03944595], FDR=[0.22337858 0.03459997], ACC=[0.93643617 0.93643617], F1_micro=0.9364361702127658, F1_macro=0.8711580426795719, F1_weighted=0.93717981790636
# [[ 52.  14.]
#  [ 16. 390.]]
#                        precision    recall  f1-score   support
#
# Melanoma_like_lesions       0.76      0.79      0.78        66
#      Pigmented_benign       0.97      0.96      0.96       406
#
#              accuracy                           0.94       472
#             macro avg       0.87      0.87      0.87       472
#          weighted avg       0.94      0.94      0.94       472
#
# --------------------------------
# Training:
# TPR=[0.98105951 1.        ], TNR=[1.         0.98105951], PPV=[1.         0.99694185], NPV=[0.99694185 1.        ], FPR=[0.         0.01894049], FNR=[0.01894049 0.        ], FDR=[0.         0.00305815], ACC=[0.99735168 0.99735168], F1_micro=0.9973516829899808, F1_macro=0.994397012795584, F1_weighted=0.9973279276561187
# [[ 259.    5.]
#  [   0. 1624.]]
#                        precision    recall  f1-score   support
#
# Melanoma_like_lesions       1.00      0.98      0.99       264
#      Pigmented_benign       1.00      1.00      1.00      1624
#
#              accuracy                           1.00      1888
#             macro avg       1.00      0.99      0.99      1888
#          weighted avg       1.00      1.00      1.00      1888
#
# --------------------------------
# ================================
# --------------------------------
# Layers-4, Set-1
# Validation:
# TPR=[0.77362637 0.96793135], TNR=[0.96793135 0.77362637], PPV=[0.80993125 0.96361632], NPV=[0.96361632 0.80993125], FPR=[0.03206865 0.22637363], FNR=[0.22637363 0.03206865], FDR=[0.19006875 0.03638368], ACC=[0.94064716 0.94064716], F1_micro=0.9406471631205673, F1_macro=0.874984491898935, F1_weighted=0.9402252515855103
# [[ 51.  15.]
#  [ 13. 393.]]
#                        precision    recall  f1-score   support
#
# Melanoma_like_lesions       0.80      0.77      0.78        66
#      Pigmented_benign       0.96      0.97      0.97       406
#
#              accuracy                           0.94       472
#             macro avg       0.88      0.87      0.88       472
#          weighted avg       0.94      0.94      0.94       472
#
# --------------------------------
# Training:
# TPR=[0.98468795 1.        ], TNR=[1.         0.98468795], PPV=[1.         0.99755164], NPV=[0.99755164 1.        ], FPR=[0.         0.01531205], FNR=[0.01531205 0.        ], FDR=[0.         0.00244836], ACC=[0.99787515 0.99787515], F1_micro=0.9978751547900485, F1_macro=0.9954628826937993, F1_weighted=0.997853019291567
# [[ 260.    4.]
#  [   0. 1624.]]
#                        precision    recall  f1-score   support
#
# Melanoma_like_lesions       1.00      0.98      0.99       264
#      Pigmented_benign       1.00      1.00      1.00      1624
#
#              accuracy                           1.00      1888
#             macro avg       1.00      0.99      1.00      1888
#          weighted avg       1.00      1.00      1.00      1888
#
# --------------------------------
# ================================
# --------------------------------
# Layers-5, Set-1
# Validation:
# TPR=[0.75714286 0.96296296], TNR=[0.96296296 0.75714286], PPV=[0.77475025 0.96094313], NPV=[0.96094313 0.77475025], FPR=[0.03703704 0.24285714], FNR=[0.24285714 0.03703704], FDR=[0.22524975 0.03905687], ACC=[0.93417553 0.93417553], F1_micro=0.9341755319148938, F1_macro=0.8613634431910656, F1_weighted=0.9338567145289731
# [[ 50.  16.]
#  [ 15. 391.]]
#                        precision    recall  f1-score   support
#
# Melanoma_like_lesions       0.77      0.76      0.76        66
#      Pigmented_benign       0.96      0.96      0.96       406
#
#              accuracy                           0.93       472
#             macro avg       0.86      0.86      0.86       472
#          weighted avg       0.93      0.93      0.93       472
#
# --------------------------------
# Training:
# TPR=[0.98860668 1.        ], TNR=[1.         0.98860668], PPV=[1.         0.99815762], NPV=[0.99815762 1.        ], FPR=[0.         0.01139332], FNR=[0.01139332 0.        ], FDR=[0.         0.00184238], ACC=[0.99840988 0.99840988], F1_micro=0.9984098840481819, F1_macro=0.9966630614418414, F1_weighted=0.9984034854305763
# [[ 261.    3.]
#  [   0. 1624.]]
#                        precision    recall  f1-score   support
#
# Melanoma_like_lesions       1.00      0.99      0.99       264
#      Pigmented_benign       1.00      1.00      1.00      1624
#
#              accuracy                           1.00      1888
#             macro avg       1.00      0.99      1.00      1888
#          weighted avg       1.00      1.00      1.00      1888
#
# --------------------------------
# ================================
# --------------------------------

# %% [markdown]
# ### 2 - layers is the best (looking at TPR for MLL class)

# %%
data = np.array([[ 55.,  11.],
                 [ 16., 390.]])
if False:
    data = data.astype('float') / data.sum(axis=1)[:, np.newaxis]
df_cm = pd.DataFrame(data, columns=['MLL', 'PBL'], index = ['MLL', 'PBL'])
df_cm.index.name = 'Actual'
df_cm.columns.name = 'Predicted'
plt.figure(figsize = (10,7), dpi=50)
sn.set(font_scale=1.4)#for label size
sn.heatmap(df_cm, cmap="Blues", annot=True, annot_kws={"size": 16}, fmt='g')# font size

# %%
data = np.array([[ 55.,  11.],
                 [ 16., 390.]])
if True:
    data = data.astype('float') / data.sum(axis=1)[:, np.newaxis]
df_cm = pd.DataFrame(data, columns=['MLL', 'PBL'], index = ['MLL', 'PBL'])
df_cm.index.name = 'Actual'
df_cm.columns.name = 'Predicted'
plt.figure(figsize = (10,7), dpi=50)
sn.set(font_scale=1.4)#for label size
sn.heatmap(df_cm, cmap="Blues", annot=True, annot_kws={"size": 16}, fmt='.2%')# font size

# %% [markdown]
# # ClassSet3

# %%
layers = [1,2,3,4,5]
sets = [3]

folds_n = 5
classes_n = 4

for l in layers:
    for set_id in sets:
        
        print('Layers-{}, Set-{}'.format(l, set_id))
        
        print('Validation:')
#         val_file_template = "/mnt/models/darts_retrained/6ch_128x128_no_metainfo_registered_10Fold/XV2_SGD_orig_02DropChannel_{}lrs_2oct_ClassSet{}_ManCorected_registered_fold-{}/validation2_logits_predictions.csv"
        multi_class_folds_metrics = build_multi_class_metrics_list(val_file_template, l, set_id, folds_n, classes_n)
        
        classes_map_dict = None
        multi_class_folds_metrics.calc_scores(classes_map_dict, classes_n)
        multi_class_folds_metrics.print_scores()
        multi_class_folds_metrics.print_mean_classification_report(classes_map_dict, target_names=['Melanoma_like_lesions', 'Pigmented_benign', 'Keratin_lesions', 'Nonmelanoma_skin_cancer'])
          
        print('--------------------------------')    
        print('Melanoma-like lesions vs. all other:')
        classes_map_dict={0:0, 1:1, 2:1, 3:1}
#         classes_map_dict={0:1, 1:0, 2:0, 3:0}
        multi_class_folds_metrics.calc_scores(classes_map_dict, classes_n=2)
        multi_class_folds_metrics.print_scores()
        multi_class_folds_metrics.print_mean_classification_report(classes_map_dict, target_names=['MLL', 'PB+KL+NonMSC'])
        
        print('--------------------------------')    
        print('Melanoma-like lesions+non-melanoma skin cancers vs. pigmented benign lesions + keratin lesions:')
        classes_map_dict={0:0, 1:1, 2:1, 3:0}
#         classes_map_dict={0:1, 1:0, 2:0, 3:1}
        multi_class_folds_metrics.calc_scores(classes_map_dict, classes_n=2)
        multi_class_folds_metrics.print_scores()
        multi_class_folds_metrics.print_mean_classification_report(classes_map_dict, target_names=['MLL+NonMSC', 'PB+KL'])
        
        print('--------------------------------')
        print('--------------------------------')
        print('--------------------------------')
        
        print('Training:')
#         val_file_template = "/mnt/models/darts_retrained/6ch_128x128_no_metainfo_registered_10Fold/XV2_SGD_orig_02DropChannel_{}lrs_2oct_ClassSet{}_ManCorected_registered_fold-{}/train2_logits_predictions.csv"
        multi_class_folds_metrics = build_multi_class_metrics_list(train_file_template, l, set_id, folds_n, classes_n)
        
        classes_map_dict = None
        multi_class_folds_metrics.calc_scores(classes_map_dict, classes_n)
        multi_class_folds_metrics.print_scores()
        multi_class_folds_metrics.print_mean_classification_report(classes_map_dict, target_names=['Melanoma_like_lesions', 'Pigmented_benign', 'Keratin_lesions', 'Nonmelanoma_skin_cancer'])
          
        print('--------------------------------')    
        print('Melanoma-like lesions vs. all other:')
        classes_map_dict={0:0, 1:1, 2:1, 3:1}
        multi_class_folds_metrics.calc_scores(classes_map_dict, classes_n=2)
        multi_class_folds_metrics.print_scores()
        multi_class_folds_metrics.print_mean_classification_report(classes_map_dict, target_names=['MLL', 'PB+KL+NonMSC'])
        
        print('--------------------------------')    
        print('Melanoma-like lesions+non-melanoma skin cancers vs. pigmented benign lesions + keratin lesions:')
        classes_map_dict={0:0, 1:1, 2:1, 3:0}
        multi_class_folds_metrics.calc_scores(classes_map_dict, classes_n=2)
        multi_class_folds_metrics.print_scores()
        multi_class_folds_metrics.print_mean_classification_report(classes_map_dict, target_names=['MLL+NonMSC', 'PB+KL'])        
        print('--------------------------------')
        print('================================')
        print('--------------------------------')
# Out:
# Layers-1, Set-3
# Validation:
# TPR=[0.68241758 0.8422162  0.63681633 0.61378151], TNR=[0.96855724 0.7913035  0.91757267 0.91529372], PPV=[0.64912281 0.77474412 0.75159537 0.64077381], NPV=[0.9744955  0.85898426 0.86825485 0.90896124], FPR=[0.03144276 0.2086965  0.08242733 0.08470628], FNR=[0.31758242 0.1577838  0.36318367 0.38621849], FDR=[0.35087719 0.22525588 0.24840463 0.35922619], ACC=[0.9473143  0.81476226 0.83950767 0.85748583], F1_micro=0.7295350275274929, F1_macro=0.69356182998239, F1_weighted=0.7267921332727943
# [[ 45.  12.   0.   9.]
#  [ 12. 342.  28.  24.]
#  [  4.  58. 158.  28.]
#  [ 10.  31.  25. 105.]]
#                          precision    recall  f1-score   support
#
#   Melanoma_like_lesions       0.63      0.68      0.66        66
#        Pigmented_benign       0.77      0.84      0.81       406
#         Keratin_lesions       0.75      0.64      0.69       248
# Nonmelanoma_skin_cancer       0.63      0.61      0.62       171
#
#                accuracy                           0.73       891
#               macro avg       0.70      0.69      0.69       891
#            weighted avg       0.73      0.73      0.73       891
#
# --------------------------------
# Melanoma-like lesions vs. all other:
# TPR=[0.68241758 0.96855724], TNR=[0.96855724 0.68241758], PPV=[0.64912281 0.9744955 ], NPV=[0.9744955  0.64912281], FPR=[0.03144276 0.31758242], FNR=[0.31758242 0.03144276], FDR=[0.35087719 0.0255045 ], ACC=[0.9473143 0.9473143], F1_micro=0.9473142995079652, F1_macro=0.8141846602198992, F1_weighted=0.9480366268572382
# [[ 45.  21.]
#  [ 26. 799.]]
#               precision    recall  f1-score   support
#
#          MLL       0.63      0.68      0.66        66
# PB+KL+NonMSC       0.97      0.97      0.97       825
#
#     accuracy                           0.95       891
#    macro avg       0.80      0.83      0.81       891
# weighted avg       0.95      0.95      0.95       891
#
# --------------------------------
# Melanoma-like lesions+non-melanoma skin cancers vs. pigmented benign lesions + keratin lesions:
# TPR=[0.71220148 0.89606328], TNR=[0.89606328 0.71220148], PPV=[0.71596666 0.89671015], NPV=[0.89671015 0.71596666], FPR=[0.10393672 0.28779852], FNR=[0.28779852 0.10393672], FDR=[0.28403334 0.10328985], ACC=[0.84737333 0.84737333], F1_micro=0.847373328789255, F1_macro=0.8038983415280399, F1_weighted=0.8470198531956237
# [[169.  68.]
#  [ 68. 586.]]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:117: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:118: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#               precision    recall  f1-score   support
#
#   MLL+NonMSC       0.71      0.71      0.71       237
#        PB+KL       0.90      0.90      0.90       654
#
#     accuracy                           0.85       891
#    macro avg       0.80      0.80      0.80       891
# weighted avg       0.85      0.85      0.85       891
#
# --------------------------------
# --------------------------------
# --------------------------------
# Training:
# TPR=[0.9128447  0.97536372 0.87700117 0.91810863], TNR=[0.99636317 0.94016836 0.9801745  0.97847096], PPV=[0.95344032 0.93218143 0.94542419 0.91034638], NPV=[0.99306397 0.97869979 0.95406697 0.98059699], FPR=[0.00363683 0.05983164 0.0198255  0.02152904], FNR=[0.0871553  0.02463628 0.12299883 0.08189137], FDR=[0.04655968 0.06781857 0.05457581 0.08965362], ACC=[0.99017797 0.9562171  0.95144811 0.96689009], F1_micro=0.9323666370637399, F1_macro=0.9270286851181598, F1_weighted=0.931787180472204
# [[2.410e+02 1.900e+01 1.000e+00 3.000e+00]
#  [4.000e+00 1.584e+03 2.100e+01 1.500e+01]
#  [2.000e+00 7.600e+01 8.700e+02 4.400e+01]
#  [6.000e+00 2.100e+01 2.900e+01 6.280e+02]]
#                          precision    recall  f1-score   support
#
#   Melanoma_like_lesions       0.95      0.91      0.93       264
#        Pigmented_benign       0.93      0.98      0.95      1624
#         Keratin_lesions       0.94      0.88      0.91       992
# Nonmelanoma_skin_cancer       0.91      0.92      0.91       684
#
#                accuracy                           0.93      3564
#               macro avg       0.93      0.92      0.93      3564
#            weighted avg       0.93      0.93      0.93      3564
#
# --------------------------------
# Melanoma-like lesions vs. all other:
# TPR=[0.9128447  0.99636317], TNR=[0.99636317 0.9128447 ], PPV=[0.95344032 0.99306397], NPV=[0.99306397 0.95344032], FPR=[0.00363683 0.0871553 ], FNR=[0.0871553  0.00363683], FDR=[0.04655968 0.00693603], ACC=[0.99017797 0.99017797], F1_micro=0.9901779746509835, F1_macro=0.9633423233068097, F1_weighted=0.9900594977266731
# [[ 241.   23.]
#  [  12. 3288.]]
#               precision    recall  f1-score   support
#
#          MLL       0.95      0.91      0.93       264
# PB+KL+NonMSC       0.99      1.00      0.99      3300
#
#     accuracy                           0.99      3564
#    macro avg       0.97      0.95      0.96      3564
# weighted avg       0.99      0.99      0.99      3564
#
# --------------------------------
# Melanoma-like lesions+non-melanoma skin cancers vs. pigmented benign lesions + keratin lesions:
# TPR=[0.92612542 0.97515139], TNR=[0.97515139 0.92612542], PPV=[0.93118035 0.9733848 ], NPV=[0.9733848  0.93118035], FPR=[0.02484861 0.07387458], FNR=[0.07387458 0.02484861], FDR=[0.06881965 0.0266152 ], ACC=[0.96211717 0.96211717], F1_micro=0.9621171687634117, F1_macro=0.9513354219955948, F1_weighted=0.9620581287849108
# [[ 878.   70.]
#  [  65. 2551.]]
#               precision    recall  f1-score   support
#
#   MLL+NonMSC       0.93      0.93      0.93       948
#        PB+KL       0.97      0.98      0.97      2616
#
#     accuracy                           0.96      3564
#    macro avg       0.95      0.95      0.95      3564
# weighted avg       0.96      0.96      0.96      3564
#
# --------------------------------
# ================================
# --------------------------------
# Layers-2, Set-3
# Validation:
# TPR=[0.77472527 0.85697079 0.71779592 0.66689076], TNR=[0.97212032 0.8741884  0.88491689 0.94174142], PPV=[0.69969188 0.85071435 0.70703628 0.73771522], NPV=[0.98163701 0.88118345 0.89091903 0.9224071 ], FPR=[0.02787968 0.1258116  0.11508311 0.05825858], FNR=[0.22527473 0.14302921 0.28220408 0.33310924], FDR=[0.30030812 0.14928565 0.29296372 0.26228478], ACC=[0.95736417 0.866437   0.83841525 0.88897902], F1_micro=0.7755977206789024, F1_macro=0.7490849939651808, F1_weighted=0.7751604204441471
# [[ 51.   7.   2.   6.]
#  [ 10. 348.  37.  11.]
#  [  5.  40. 178.  25.]
#  [  8.  14.  35. 114.]]
#                          precision    recall  f1-score   support
#
#   Melanoma_like_lesions       0.69      0.77      0.73        66
#        Pigmented_benign       0.85      0.86      0.85       406
#         Keratin_lesions       0.71      0.72      0.71       248
# Nonmelanoma_skin_cancer       0.73      0.67      0.70       171
#
#                accuracy                           0.78       891
#               macro avg       0.74      0.75      0.75       891
#            weighted avg       0.78      0.78      0.78       891
#
# --------------------------------
# Melanoma-like lesions vs. all other:
# TPR=[0.77472527 0.97212032], TNR=[0.97212032 0.77472527], PPV=[0.69969188 0.98163701], NPV=[0.98163701 0.69969188], FPR=[0.02787968 0.22527473], FNR=[0.22527473 0.02787968], FDR=[0.30030812 0.01836299], ACC=[0.95736417 0.95736417], F1_micro=0.9573641685228942, F1_macro=0.8547228306280779, F1_weighted=0.9586312705915209
# [[ 51.  15.]
#  [ 23. 802.]]
#               precision    recall  f1-score   support
#
#          MLL       0.69      0.77      0.73        66
# PB+KL+NonMSC       0.98      0.97      0.98       825
#
#     accuracy                           0.96       891
#    macro avg       0.84      0.87      0.85       891
# weighted avg       0.96      0.96      0.96       891
#
# --------------------------------
# Melanoma-like lesions+non-melanoma skin cancers vs. pigmented benign lesions + keratin lesions:
# TPR=[0.75544941 0.92205324], TNR=[0.92205324 0.75544941], PPV=[0.78533409 0.91201737], NPV=[0.91201737 0.78533409], FPR=[0.07794676 0.24455059], FNR=[0.24455059 0.07794676], FDR=[0.21466591 0.08798263], ACC=[0.8777552 0.8777552], F1_micro=0.8777551980581038, F1_macro=0.8428020235141791, F1_weighted=0.8774070241326857
# [[179.  58.]
#  [ 51. 603.]]
#               precision    recall  f1-score   support
#
#   MLL+NonMSC       0.78      0.76      0.77       237
#        PB+KL       0.91      0.92      0.92       654
#
#     accuracy                           0.88       891
#    macro avg       0.85      0.84      0.84       891
# weighted avg       0.88      0.88      0.88       891
#
# --------------------------------
# --------------------------------
# --------------------------------
# Training:
# TPR=[0.99622642 0.99568661 0.99596467 0.99562044], TNR=[0.99969743 0.99896907 0.99766764 0.99791425], PPV=[0.9962963  0.99877301 0.99401477 0.99133563], NPV=[0.99969697 0.99640624 0.99844735 0.99895893], FPR=[0.00030257 0.00103093 0.00233236 0.00208575], FNR=[0.00377358 0.00431339 0.00403533 0.00437956], FDR=[0.0037037  0.00122699 0.00598523 0.00866437], ACC=[0.99943899 0.99747427 0.99719337 0.99747269], F1_micro=0.9957896608556581, F1_macro=0.9954651776785498, F1_weighted=0.9957960760327529
# [[2.630e+02 0.000e+00 1.000e+00 0.000e+00]
#  [1.000e+00 1.617e+03 3.000e+00 3.000e+00]
#  [0.000e+00 1.000e+00 9.880e+02 3.000e+00]
#  [0.000e+00 1.000e+00 2.000e+00 6.810e+02]]
#                          precision    recall  f1-score   support
#
#   Melanoma_like_lesions       1.00      1.00      1.00       264
#        Pigmented_benign       1.00      1.00      1.00      1624
#         Keratin_lesions       0.99      1.00      0.99       992
# Nonmelanoma_skin_cancer       0.99      1.00      0.99       684
#
#                accuracy                           1.00      3564
#               macro avg       1.00      1.00      1.00      3564
#            weighted avg       1.00      1.00      1.00      3564
#
# --------------------------------
# Melanoma-like lesions vs. all other:
# TPR=[0.99622642 0.99969743], TNR=[0.99969743 0.99622642], PPV=[0.9962963  0.99969697], NPV=[0.99969697 0.9962963 ], FPR=[0.00030257 0.00377358], FNR=[0.00377358 0.00030257], FDR=[0.0037037  0.00030303], ACC=[0.99943899 0.99943899], F1_micro=0.9994389890787776, F1_macro=0.9979615243698937, F1_weighted=0.9994389608588998
# [[2.630e+02 1.000e+00]
#  [1.000e+00 3.299e+03]]
#               precision    recall  f1-score   support
#
#          MLL       1.00      1.00      1.00       264
# PB+KL+NonMSC       1.00      1.00      1.00      3300
#
#     accuracy                           1.00      3564
#    macro avg       1.00      1.00      1.00      3564
# weighted avg       1.00      1.00      1.00      3564
#
# --------------------------------
# Melanoma-like lesions+non-melanoma skin cancers vs. pigmented benign lesions + keratin lesions:
# TPR=[0.99578947 0.99732313], TNR=[0.99732313 0.99578947], PPV=[0.99267004 0.99847108], NPV=[0.99847108 0.99267004], FPR=[0.00267687 0.00421053], FNR=[0.00421053 0.00267687], FDR=[0.00732996 0.00152892], ACC=[0.99691168 0.99691168], F1_micro=0.9969116815945522, F1_macro=0.9960517289468747, F1_weighted=0.9969142666982054
# [[ 944.    4.]
#  [   7. 2609.]]
#               precision    recall  f1-score   support
#
#   MLL+NonMSC       0.99      1.00      0.99       948
#        PB+KL       1.00      1.00      1.00      2616
#
#     accuracy                           1.00      3564
#    macro avg       1.00      1.00      1.00      3564
# weighted avg       1.00      1.00      1.00      3564
#
# --------------------------------
# ================================
# --------------------------------
# Layers-3, Set-3
# Validation:
# TPR=[0.80549451 0.86696778 0.73412245 0.67294118], TNR=[0.97217909 0.88662397 0.89727266 0.93762291], PPV=[0.7087395  0.86543388 0.73617057 0.72892157], NPV=[0.98407846 0.88918336 0.89795861 0.9235564 ], FPR=[0.02782091 0.11337603 0.10272734 0.06237709], FNR=[0.19450549 0.13303222 0.26587755 0.32705882], FDR=[0.2912605  0.13456612 0.26382943 0.27107843], ACC=[0.95968062 0.87764855 0.85183653 0.8867762 ], F1_micro=0.7879709531251827, F1_macro=0.7614495149315337, F1_weighted=0.7876282800037476
# [[ 53.   8.   1.   4.]
#  [ 11. 352.  33.  10.]
#  [  3.  32. 182.  31.]
#  [  9.  15.  32. 115.]]
#                          precision    recall  f1-score   support
#
#   Melanoma_like_lesions       0.70      0.80      0.75        66
#        Pigmented_benign       0.86      0.87      0.87       406
#         Keratin_lesions       0.73      0.73      0.73       248
# Nonmelanoma_skin_cancer       0.72      0.67      0.69       171
#
#                accuracy                           0.79       891
#               macro avg       0.75      0.77      0.76       891
#            weighted avg       0.79      0.79      0.79       891
#
# --------------------------------
# Melanoma-like lesions vs. all other:
# TPR=[0.80549451 0.97217909], TNR=[0.97217909 0.80549451], PPV=[0.7087395  0.98407846], NPV=[0.98407846 0.7087395 ], FPR=[0.02782091 0.19450549], FNR=[0.19450549 0.02782091], FDR=[0.2912605  0.01592154], ACC=[0.95968062 0.95968062], F1_micro=0.9596806224489061, F1_macro=0.8643002483751697, F1_weighted=0.9610614230667732
# [[ 53.  13.]
#  [ 23. 802.]]
#               precision    recall  f1-score   support
#
#          MLL       0.70      0.80      0.75        66
# PB+KL+NonMSC       0.98      0.97      0.98       825
#
#     accuracy                           0.96       891
#    macro avg       0.84      0.89      0.86       891
# weighted avg       0.96      0.96      0.96       891
#
# --------------------------------
# Melanoma-like lesions+non-melanoma skin cancers vs. pigmented benign lesions + keratin lesions:
# TPR=[0.76413374 0.91606274], TNR=[0.91606274 0.76413374], PPV=[0.77571849 0.9145819 ], NPV=[0.9145819  0.77571849], FPR=[0.08393726 0.23586626], FNR=[0.23586626 0.08393726], FDR=[0.22428151 0.0854181 ], ACC=[0.87558369 0.87558369], F1_micro=0.8755836877040712, F1_macro=0.8411485570185689, F1_weighted=0.8756456598303588
# [[181.  56.]
#  [ 55. 599.]]
#               precision    recall  f1-score   support
#
#   MLL+NonMSC       0.77      0.76      0.77       237
#        PB+KL       0.91      0.92      0.92       654
#
#     accuracy                           0.88       891
#    macro avg       0.84      0.84      0.84       891
# weighted avg       0.88      0.88      0.88       891
#
# --------------------------------
# --------------------------------
# --------------------------------
# Training:
# TPR=[0.98483309 0.99507312 0.98385361 0.99270073], TNR=[0.99909137 0.99483867 0.99689093 0.99583332], PPV=[0.98888112 0.99388161 0.9919173  0.98268016], NPV=[0.99879062 0.9958774  0.9938222  0.99826568], FPR=[0.00090863 0.00516133 0.00310907 0.00416668], FNR=[0.01516691 0.00492688 0.01614639 0.00729927], FDR=[0.01111888 0.00611839 0.0080827  0.01731984], ACC=[0.99803646 0.99494736 0.9932655  0.9952318 ], F1_micro=0.9907405581271721, F1_macro=0.9891546013369105, F1_weighted=0.9907314763075104
# [[2.600e+02 2.000e+00 1.000e+00 1.000e+00]
#  [2.000e+00 1.616e+03 3.000e+00 3.000e+00]
#  [1.000e+00 7.000e+00 9.760e+02 8.000e+00]
#  [0.000e+00 1.000e+00 4.000e+00 6.790e+02]]
#                          precision    recall  f1-score   support
#
#   Melanoma_like_lesions       0.99      0.98      0.99       264
#        Pigmented_benign       0.99      1.00      0.99      1624
#         Keratin_lesions       0.99      0.98      0.99       992
# Nonmelanoma_skin_cancer       0.98      0.99      0.99       684
#
#                accuracy                           0.99      3564
#               macro avg       0.99      0.99      0.99      3564
#            weighted avg       0.99      0.99      0.99      3564
#
# --------------------------------
# Melanoma-like lesions vs. all other:
# TPR=[0.98483309 0.99909137], TNR=[0.99909137 0.98483309], PPV=[0.98888112 0.99879062], NPV=[0.99879062 0.98888112], FPR=[0.00090863 0.01516691], FNR=[0.01516691 0.00090863], FDR=[0.01111888 0.00120938], ACC=[0.99803646 0.99803646], F1_micro=0.9980364590075324, F1_macro=0.9928195955008995, F1_weighted=0.9980350286490822
# [[2.600e+02 4.000e+00]
#  [3.000e+00 3.297e+03]]
#               precision    recall  f1-score   support
#
#          MLL       0.99      0.98      0.99       264
# PB+KL+NonMSC       1.00      1.00      1.00      3300
#
#     accuracy                           1.00      3564
#    macro avg       0.99      0.99      0.99      3564
# weighted avg       1.00      1.00      1.00      3564
#
# --------------------------------
# Melanoma-like lesions+non-melanoma skin cancers vs. pigmented benign lesions + keratin lesions:
# TPR=[0.99156775 0.99464919], TNR=[0.99464919 0.99156775], PPV=[0.98535105 0.9969385 ], NPV=[0.9969385  0.98535105], FPR=[0.00535081 0.00843225], FNR=[0.00843225 0.00535081], FDR=[0.01464895 0.0030615 ], ACC=[0.99382848 0.99382848], F1_micro=0.9938284814615006, F1_macro=0.9921142240504786, F1_weighted=0.9938359816950643
# [[ 940.    8.]
#  [  14. 2602.]]
#               precision    recall  f1-score   support
#
#   MLL+NonMSC       0.99      0.99      0.99       948
#        PB+KL       1.00      0.99      1.00      2616
#
#     accuracy                           0.99      3564
#    macro avg       0.99      0.99      0.99      3564
# weighted avg       0.99      0.99      0.99      3564
#
# --------------------------------
# ================================
# --------------------------------
# Layers-4, Set-3
# Validation:
# TPR=[0.78901099 0.85447154 0.69371429 0.67260504], TNR=[0.97214249 0.85769226 0.8957219  0.93615686], PPV=[0.69936652 0.83528511 0.72272899 0.71695968], NPV=[0.98285145 0.87774193 0.88399957 0.9233469 ], FPR=[0.02785751 0.14230774 0.1042781  0.06384314], FNR=[0.21098901 0.14552846 0.30628571 0.32739496], FDR=[0.30063348 0.16471489 0.27727101 0.28304032], ACC=[0.95850053 0.85632464 0.83948284 0.88557713], F1_micro=0.7699425713124195, F1_macro=0.7455101869251329, F1_weighted=0.768618658014257
# [[ 52.  10.   1.   3.]
#  [ 11. 347.  38.  10.]
#  [  2.  41. 172.  33.]
#  [ 10.  18.  28. 115.]]
#                          precision    recall  f1-score   support
#
#   Melanoma_like_lesions       0.69      0.79      0.74        66
#        Pigmented_benign       0.83      0.85      0.84       406
#         Keratin_lesions       0.72      0.69      0.71       248
# Nonmelanoma_skin_cancer       0.71      0.67      0.69       171
#
#                accuracy                           0.77       891
#               macro avg       0.74      0.75      0.75       891
#            weighted avg       0.77      0.77      0.77       891
#
# --------------------------------
# Melanoma-like lesions vs. all other:
# TPR=[0.78901099 0.97214249], TNR=[0.97214249 0.78901099], PPV=[0.69936652 0.98285145], NPV=[0.98285145 0.69936652], FPR=[0.02785751 0.21098901], FNR=[0.21098901 0.02785751], FDR=[0.30063348 0.01714855], ACC=[0.95850053 0.95850053], F1_micro=0.9585005309502691, F1_macro=0.8584397275630213, F1_weighted=0.9597263831925746
# [[ 52.  14.]
#  [ 23. 802.]]
#               precision    recall  f1-score   support
#
#          MLL       0.69      0.79      0.74        66
# PB+KL+NonMSC       0.98      0.97      0.98       825
#
#     accuracy                           0.96       891
#    macro avg       0.84      0.88      0.86       891
# weighted avg       0.96      0.96      0.96       891
#
# --------------------------------
# Melanoma-like lesions+non-melanoma skin cancers vs. pigmented benign lesions + keratin lesions:
# TPR=[0.75953105 0.91440791], TNR=[0.91440791 0.75953105], PPV=[0.76555432 0.91316016], NPV=[0.91316016 0.76555432], FPR=[0.08559209 0.24046895], FNR=[0.24046895 0.08559209], FDR=[0.23444568 0.08683984], ACC=[0.8732295 0.8732295], F1_micro=0.8732294992494115, F1_macro=0.8374895487059215, F1_weighted=0.8730980255041783
# [[180.  57.]
#  [ 56. 598.]]
#               precision    recall  f1-score   support
#
#   MLL+NonMSC       0.76      0.76      0.76       237
#        PB+KL       0.91      0.91      0.91       654
#
#     accuracy                           0.87       891
#    macro avg       0.84      0.84      0.84       891
# weighted avg       0.87      0.87      0.87       891
#
# --------------------------------
# --------------------------------
# --------------------------------
# Training:
# TPR=[1.         0.99507502 0.99293944 0.99270073], TNR=[0.99909228 0.99742533 0.99844585 0.99722041], PPV=[0.98928571 0.99692112 0.99596462 0.98839461], NPV=[1.         0.99588944 0.9972823  0.99826568], FPR=[0.00090772 0.00257467 0.00155415 0.00277959], FNR=[0.         0.00492498 0.00706056 0.00729927], FDR=[0.01071429 0.00307888 0.00403538 0.01160539], ACC=[0.99915966 0.99635461 0.99691365 0.99635185], F1_micro=0.9943898885667057, F1_macro=0.9938636659102629, F1_weighted=0.994401605605726
# [[2.640e+02 0.000e+00 0.000e+00 0.000e+00]
#  [3.000e+00 1.616e+03 1.000e+00 4.000e+00]
#  [0.000e+00 3.000e+00 9.850e+02 4.000e+00]
#  [0.000e+00 2.000e+00 3.000e+00 6.790e+02]]
#                          precision    recall  f1-score   support
#
#   Melanoma_like_lesions       0.99      1.00      0.99       264
#        Pigmented_benign       1.00      1.00      1.00      1624
#         Keratin_lesions       1.00      0.99      0.99       992
# Nonmelanoma_skin_cancer       0.99      0.99      0.99       684
#
#                accuracy                           0.99      3564
#               macro avg       0.99      1.00      0.99      3564
#            weighted avg       0.99      0.99      0.99      3564
#
# --------------------------------
# Melanoma-like lesions vs. all other:
# TPR=[1.         0.99909228], TNR=[0.99909228 1.        ], PPV=[0.98928571 1.        ], NPV=[1.         0.98928571], FPR=[0.00090772 0.        ], FNR=[0.         0.00090772], FDR=[0.01071429 0.        ], ACC=[0.99915966 0.99915966], F1_micro=0.9991596638655462, F1_macro=0.9970202613879016, F1_weighted=0.9991702724728734
# [[2.640e+02 0.000e+00]
#  [3.000e+00 3.297e+03]]
#               precision    recall  f1-score   support
#
#          MLL       0.99      1.00      0.99       264
# PB+KL+NonMSC       1.00      1.00      1.00      3300
#
#     accuracy                           1.00      3564
#    macro avg       0.99      1.00      1.00      3564
# weighted avg       1.00      1.00      1.00      3564
#
# --------------------------------
# Melanoma-like lesions+non-melanoma skin cancers vs. pigmented benign lesions + keratin lesions:
# TPR=[0.99473684 0.99579568], TNR=[0.99579568 0.99473684], PPV=[0.98849247 0.99808575], NPV=[0.99808575 0.98849247], FPR=[0.00420432 0.00526316], FNR=[0.00526316 0.00420432], FDR=[0.01150753 0.00191425], ACC=[0.99551152 0.99551152], F1_micro=0.9955115153380312, F1_macro=0.994266807776936, F1_weighted=0.9955171364315906
# [[ 943.    5.]
#  [  11. 2605.]]
#               precision    recall  f1-score   support
#
#   MLL+NonMSC       0.99      0.99      0.99       948
#        PB+KL       1.00      1.00      1.00      2616
#
#     accuracy                           1.00      3564
#    macro avg       0.99      1.00      0.99      3564
# weighted avg       1.00      1.00      1.00      3564
#
# --------------------------------
# ================================
# --------------------------------
# Layers-5, Set-3
# Validation:
# TPR=[0.74395604 0.86940681 0.72563265 0.66672269], TNR=[0.97699828 0.86379322 0.88798189 0.94726851], PPV=[0.73038961 0.84272256 0.71566973 0.75573607], NPV=[0.97948609 0.88792795 0.89344496 0.92292908], FPR=[0.02300172 0.13620678 0.11201811 0.05273149], FNR=[0.25604396 0.13059319 0.27436735 0.33327731], FDR=[0.26961039 0.15727744 0.28433027 0.24426393], ACC=[0.95962413 0.86641196 0.84278436 0.89342361], F1_micro=0.7811220303755804, F1_macro=0.7528976761332835, F1_weighted=0.7799458228396353
# [[ 49.  10.   2.   5.]
#  [ 10. 353.  33.  10.]
#  [  3.  42. 180.  23.]
#  [  6.  14.  37. 114.]]
#                          precision    recall  f1-score   support
#
#   Melanoma_like_lesions       0.72      0.74      0.73        66
#        Pigmented_benign       0.84      0.87      0.86       406
#         Keratin_lesions       0.71      0.73      0.72       248
# Nonmelanoma_skin_cancer       0.75      0.67      0.71       171
#
#                accuracy                           0.78       891
#               macro avg       0.76      0.75      0.75       891
#            weighted avg       0.78      0.78      0.78       891
#
# --------------------------------
# Melanoma-like lesions vs. all other:
# TPR=[0.74395604 0.97699828], TNR=[0.97699828 0.74395604], PPV=[0.73038961 0.97948609], NPV=[0.97948609 0.73038961], FPR=[0.02300172 0.25604396], FNR=[0.25604396 0.02300172], FDR=[0.26961039 0.02051391], ACC=[0.95962413 0.95962413], F1_micro=0.9596241252737647, F1_macro=0.8535623319636485, F1_weighted=0.9596255374457942
# [[ 49.  17.]
#  [ 19. 806.]]
#               precision    recall  f1-score   support
#
#          MLL       0.72      0.74      0.73        66
# PB+KL+NonMSC       0.98      0.98      0.98       825
#
#     accuracy                           0.96       891
#    macro avg       0.85      0.86      0.85       891
# weighted avg       0.96      0.96      0.96       891
#
# --------------------------------
# Melanoma-like lesions+non-melanoma skin cancers vs. pigmented benign lesions + keratin lesions:
# TPR=[0.7343465  0.92972224], TNR=[0.92972224 0.7343465 ], PPV=[0.79264538 0.90633291], NPV=[0.90633291 0.79264538], FPR=[0.07027776 0.2656535 ], FNR=[0.2656535  0.07027776], FDR=[0.20735462 0.09366709], ACC=[0.87774286 0.87774286], F1_micro=0.8777428555182833, F1_macro=0.839536785308842, F1_weighted=0.8760967608065849
# [[174.  63.]
#  [ 46. 608.]]
#               precision    recall  f1-score   support
#
#   MLL+NonMSC       0.79      0.73      0.76       237
#        PB+KL       0.91      0.93      0.92       654
#
#     accuracy                           0.88       891
#    macro avg       0.85      0.83      0.84       891
# weighted avg       0.88      0.88      0.88       891
#
# --------------------------------
# --------------------------------
# --------------------------------
# Training:
# TPR=[1.         0.99692118 0.99596975 0.99414985], TNR=[0.99969743 0.99845493 0.99805522 0.9986099 ], PPV=[0.9962963  0.99815947 0.99500488 0.99418174], NPV=[1.         0.99742929 0.99844432 0.9986141 ], FPR=[0.00030257 0.00154507 0.00194478 0.0013901 ], FNR=[0.         0.00307882 0.00403025 0.00585015], FDR=[0.0037037  0.00184053 0.00499512 0.00581826], ACC=[0.99971989 0.99775517 0.99747505 0.99775438], F1_micro=0.9963522432282961, F1_macro=0.9963223657284168, F1_weighted=0.9963558282168685
# [[2.640e+02 0.000e+00 0.000e+00 0.000e+00]
#  [1.000e+00 1.619e+03 2.000e+00 2.000e+00]
#  [0.000e+00 2.000e+00 9.880e+02 2.000e+00]
#  [0.000e+00 1.000e+00 3.000e+00 6.800e+02]]
#                          precision    recall  f1-score   support
#
#   Melanoma_like_lesions       1.00      1.00      1.00       264
#        Pigmented_benign       1.00      1.00      1.00      1624
#         Keratin_lesions       0.99      1.00      1.00       992
# Nonmelanoma_skin_cancer       0.99      0.99      0.99       684
#
#                accuracy                           1.00      3564
#               macro avg       1.00      1.00      1.00      3564
#            weighted avg       1.00      1.00      1.00      3564
#
# --------------------------------
# Melanoma-like lesions vs. all other:
# TPR=[1.         0.99969743], TNR=[0.99969743 1.        ], PPV=[0.9962963 1.       ], NPV=[1.        0.9962963], FPR=[0.00030257 0.        ], FNR=[0.         0.00030257], FDR=[0.0037037 0.       ], ACC=[0.99971989 0.99971989], F1_micro=0.9997198879551821, F1_macro=0.9989897203336471, F1_weighted=0.9997210908672439
# [[2.640e+02 0.000e+00]
#  [1.000e+00 3.299e+03]]
#               precision    recall  f1-score   support
#
#          MLL       1.00      1.00      1.00       264
# PB+KL+NonMSC       1.00      1.00      1.00      3300
#
#     accuracy                           1.00      3564
#    macro avg       1.00      1.00      1.00      3564
# weighted avg       1.00      1.00      1.00      3564
#
# --------------------------------
# Melanoma-like lesions+non-melanoma skin cancers vs. pigmented benign lesions + keratin lesions:
# TPR=[0.99577828 0.99808868], TNR=[0.99808868 0.99577828], PPV=[0.99473116 0.99847327], NPV=[0.99847327 0.99473116], FPR=[0.00191132 0.00422172], FNR=[0.00422172 0.00191132], FDR=[0.00526884 0.00152673], ACC=[0.99747427 0.99747427], F1_micro=0.9974742661789477, F1_macro=0.9967639334393713, F1_weighted=0.9974745052371696
# [[ 944.    4.]
#  [   5. 2611.]]
#               precision    recall  f1-score   support
#
#   MLL+NonMSC       0.99      1.00      1.00       948
#        PB+KL       1.00      1.00      1.00      2616
#
#     accuracy                           1.00      3564
#    macro avg       1.00      1.00      1.00      3564
# weighted avg       1.00      1.00      1.00      3564
#
# --------------------------------
# ================================
# --------------------------------

# %% [markdown]
# ### 3 - layers give best TPR for MLL class

# %%
data = np.array([[ 53.,   8.,   1.,   4.],
                 [ 11., 352.,  33.,  10.],
                 [  3.,  32., 182.,  31.],
                 [  9.,  15.,  32., 115.]])
if False:
    data = data.astype('float') / data.sum(axis=1)[:, np.newaxis]
df_cm = pd.DataFrame(data, columns=['MLL', 'PBL', 'KL', 'NonMSC'], index = ['MLL', 'PBL', 'KL', 'NonMSC'])
df_cm.index.name = 'Actual'
df_cm.columns.name = 'Predicted'
plt.figure(figsize = (10,7), dpi=50)
sn.set(font_scale=1.4)#for label size
sn.heatmap(df_cm, cmap="Blues", annot=True, annot_kws={"size": 16}, fmt='g')# font size

# %%
data = np.array([[ 53.,   8.,   1.,   4.],
                 [ 11., 352.,  33.,  10.],
                 [  3.,  32., 182.,  31.],
                 [  9.,  15.,  32., 115.]])
if True:
    data = data.astype('float') / data.sum(axis=1)[:, np.newaxis]
df_cm = pd.DataFrame(data, columns=['MLL', 'PBL', 'KL', 'NonMSC'], index = ['MLL', 'PBL', 'KL', 'NonMSC'])
df_cm.index.name = 'Actual'
df_cm.columns.name = 'Predicted'
plt.figure(figsize = (10,7), dpi=50)
sn.set(font_scale=1.4)#for label size
sn.heatmap(df_cm, cmap="Blues", annot=True, annot_kws={"size": 16}, fmt='.2%')# font size

# %% [markdown]
# # ClassSet4

# %%
layers = [1,2,3,4,5]
sets = [4]

folds_n = 5
classes_n = 2

for l in layers:
    for set_id in sets:
        
        print('Layers-{}, Set-{}'.format(l, set_id))
        
        print('Validation:')
#         val_file_template = "/mnt/models/darts_retrained/6ch_128x128_no_metainfo_registered_10Fold/XV2_SGD_orig_02DropChannel_{}lrs_2oct_ClassSet{}_ManCorected_registered_fold-{}/validation2_logits_predictions.csv"
        multi_class_folds_metrics = build_multi_class_metrics_list(val_file_template, l, set_id, folds_n, classes_n)
        
        classes_map_dict = None
        multi_class_folds_metrics.calc_scores(classes_map_dict, classes_n)
        multi_class_folds_metrics.print_scores()
        multi_class_folds_metrics.print_mean_classification_report(classes_map_dict, target_names=['C43', 'D22'])
          
        print('--------------------------------')
        print('--------------------------------')
        print('--------------------------------')
        
        print('Training:')
#         val_file_template = "/mnt/models/darts_retrained/6ch_128x128_no_metainfo_registered_10Fold/XV2_SGD_orig_02DropChannel_{}lrs_2oct_ClassSet{}_ManCorected_registered_fold-{}/train2_logits_predictions.csv"
        multi_class_folds_metrics = build_multi_class_metrics_list(train_file_template, l, set_id, folds_n, classes_n)
        
        classes_map_dict = None
        multi_class_folds_metrics.calc_scores(classes_map_dict, classes_n)
        multi_class_folds_metrics.print_scores()
        multi_class_folds_metrics.print_mean_classification_report(classes_map_dict, target_names=['C43', 'D22'])
              
        print('--------------------------------')
        print('================================')
        print('--------------------------------')
# Out:
# Layers-1, Set-4
# Validation:
# TPR=[0.78974359 0.97721519], TNR=[0.97721519 0.78974359], PPV=[0.85165945 0.96773359], NPV=[0.96773359 0.85165945], FPR=[0.02278481 0.21025641], FNR=[0.21025641 0.02278481], FDR=[0.14834055 0.03226641], ACC=[0.95186335 0.95186335], F1_micro=0.9518633540372671, F1_macro=0.8931593149791016, F1_weighted=0.9508759304850575
# [[ 49.  13.]
#  [  9. 386.]]
#               precision    recall  f1-score   support
#
#          C43       0.84      0.79      0.82        62
#          D22       0.97      0.98      0.97       395
#
#     accuracy                           0.95       457
#    macro avg       0.91      0.88      0.89       457
# weighted avg       0.95      0.95      0.95       457
#
# --------------------------------
# --------------------------------
# --------------------------------
# Training:
# TPR=[0.996 1.   ], TNR=[1.    0.996], PPV=[1.         0.99936909], NPV=[0.99936909 1.        ], FPR=[0.    0.004], FNR=[0.004 0.   ], FDR=[0.         0.00063091], ACC=[0.99945355 0.99945355], F1_micro=0.9994535519125683, F1_macro=0.9988319211068026, F1_weighted=0.9994512237073032
# [[2.47e+02 1.00e+00]
#  [0.00e+00 1.58e+03]]
#               precision    recall  f1-score   support
#
#          C43       1.00      1.00      1.00       248
#          D22       1.00      1.00      1.00      1580
#
#     accuracy                           1.00      1828
#    macro avg       1.00      1.00      1.00      1828
# weighted avg       1.00      1.00      1.00      1828
#
# --------------------------------
# ================================
# --------------------------------
# Layers-2, Set-4
# Validation:
# TPR=[0.80641026 0.97721519], TNR=[0.97721519 0.80641026], PPV=[0.85396825 0.96995666], NPV=[0.96995666 0.85396825], FPR=[0.02278481 0.19358974], FNR=[0.19358974 0.02278481], FDR=[0.14603175 0.03004334], ACC=[0.95408505 0.95408505], F1_micro=0.9540850453893933, F1_macro=0.9000161006690632, F1_weighted=0.9535259124670455
# [[ 50.  12.]
#  [  9. 386.]]
#               precision    recall  f1-score   support
#
#          C43       0.85      0.81      0.83        62
#          D22       0.97      0.98      0.97       395
#
#     accuracy                           0.95       457
#    macro avg       0.91      0.89      0.90       457
# weighted avg       0.95      0.95      0.95       457
#
# --------------------------------
# --------------------------------
# --------------------------------
# Training:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:117: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:118: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# TPR=[1. 1.], TNR=[1. 1.], PPV=[1. 1.], NPV=[1. 1.], FPR=[0. 0.], FNR=[0. 0.], FDR=[0. 0.], ACC=[1. 1.], F1_micro=1.0, F1_macro=1.0, F1_weighted=1.0
# [[ 248.    0.]
#  [   0. 1580.]]
#               precision    recall  f1-score   support
#
#          C43       1.00      1.00      1.00       248
#          D22       1.00      1.00      1.00      1580
#
#     accuracy                           1.00      1828
#    macro avg       1.00      1.00      1.00      1828
# weighted avg       1.00      1.00      1.00      1828
#
# --------------------------------
# ================================
# --------------------------------
# Layers-3, Set-4
# Validation:
# TPR=[0.80512821 0.96708861], TNR=[0.96708861 0.80512821], PPV=[0.79432234 0.96955372], NPV=[0.96955372 0.79432234], FPR=[0.03291139 0.19487179], FNR=[0.19487179 0.03291139], FDR=[0.20567766 0.03044628], ACC=[0.94524606 0.94524606], F1_micro=0.9452460582895366, F1_macro=0.8836303255681983, F1_weighted=0.9454875872850719
# [[ 50.  12.]
#  [ 13. 382.]]
#               precision    recall  f1-score   support
#
#          C43       0.79      0.81      0.80        62
#          D22       0.97      0.97      0.97       395
#
#     accuracy                           0.95       457
#    macro avg       0.88      0.89      0.88       457
# weighted avg       0.95      0.95      0.95       457
#
# --------------------------------
# --------------------------------
# --------------------------------
# Training:
# TPR=[1. 1.], TNR=[1. 1.], PPV=[1. 1.], NPV=[1. 1.], FPR=[0. 0.], FNR=[0. 0.], FDR=[0. 0.], ACC=[1. 1.], F1_micro=1.0, F1_macro=1.0, F1_weighted=1.0
# [[ 248.    0.]
#  [   0. 1580.]]
#               precision    recall  f1-score   support
#
#          C43       1.00      1.00      1.00       248
#          D22       1.00      1.00      1.00      1580
#
#     accuracy                           1.00      1828
#    macro avg       1.00      1.00      1.00      1828
# weighted avg       1.00      1.00      1.00      1828
#
# --------------------------------
# ================================
# --------------------------------
# Layers-4, Set-4
# Validation:
# TPR=[0.78974359 0.97468354], TNR=[0.97468354 0.78974359], PPV=[0.82606838 0.96764584], NPV=[0.96764584 0.82606838], FPR=[0.02531646 0.21025641], FNR=[0.21025641 0.02531646], FDR=[0.17393162 0.03235416], ACC=[0.94966555 0.94966555], F1_micro=0.9496655518394649, F1_macro=0.8878490541175573, F1_weighted=0.9485643612938933
# [[ 49.  13.]
#  [ 10. 385.]]
#               precision    recall  f1-score   support
#
#          C43       0.83      0.79      0.81        62
#          D22       0.97      0.97      0.97       395
#
#     accuracy                           0.95       457
#    macro avg       0.90      0.88      0.89       457
# weighted avg       0.95      0.95      0.95       457
#
# --------------------------------
# --------------------------------
# --------------------------------
# Training:
# TPR=[1. 1.], TNR=[1. 1.], PPV=[1. 1.], NPV=[1. 1.], FPR=[0. 0.], FNR=[0. 0.], FDR=[0. 0.], ACC=[1. 1.], F1_micro=1.0, F1_macro=1.0, F1_weighted=1.0
# [[ 248.    0.]
#  [   0. 1580.]]
#               precision    recall  f1-score   support
#
#          C43       1.00      1.00      1.00       248
#          D22       1.00      1.00      1.00      1580
#
#     accuracy                           1.00      1828
#    macro avg       1.00      1.00      1.00      1828
# weighted avg       1.00      1.00      1.00      1828
#
# --------------------------------
# ================================
# --------------------------------
# Layers-5, Set-4
# Validation:
# TPR=[0.82435897 0.96202532], TNR=[0.96202532 0.82435897], PPV=[0.78003663 0.97191545], NPV=[0.97191545 0.78003663], FPR=[0.03797468 0.17564103], FNR=[0.17564103 0.03797468], FDR=[0.21996337 0.02808455], ACC=[0.94311992 0.94311992], F1_micro=0.9431199235547062, F1_macro=0.8830166664811919, F1_weighted=0.9440651850218738
# [[ 51.  11.]
#  [ 15. 380.]]
#               precision    recall  f1-score   support
#
#          C43       0.77      0.82      0.80        62
#          D22       0.97      0.96      0.97       395
#
#     accuracy                           0.94       457
#    macro avg       0.87      0.89      0.88       457
# weighted avg       0.94      0.94      0.94       457
#
# --------------------------------
# --------------------------------
# --------------------------------
# Training:
# TPR=[1. 1.], TNR=[1. 1.], PPV=[1. 1.], NPV=[1. 1.], FPR=[0. 0.], FNR=[0. 0.], FDR=[0. 0.], ACC=[1. 1.], F1_micro=1.0, F1_macro=1.0, F1_weighted=1.0
# [[ 248.    0.]
#  [   0. 1580.]]
#               precision    recall  f1-score   support
#
#          C43       1.00      1.00      1.00       248
#          D22       1.00      1.00      1.00      1580
#
#     accuracy                           1.00      1828
#    macro avg       1.00      1.00      1.00      1828
# weighted avg       1.00      1.00      1.00      1828
#
# --------------------------------
# ================================
# --------------------------------

# %% [markdown]
# ### 5- layers give best TPR for MLL class

# %%
data = np.array([[ 51.,  11.],
                 [ 12., 380.]])
if False: 
    data = data.astype('float') / data.sum(axis=1)[:, np.newaxis]
# df_cm = pd.DataFrame(data, columns=['C43', 'D22'], index = ['C43', 'D22'])
df_cm = pd.DataFrame(data, columns=['MM', 'MN'], index = ['MM', 'MN'])
df_cm.index.name = 'Actual'
df_cm.columns.name = 'Predicted'
plt.figure(figsize = (10,7), dpi=50)
sn.set(font_scale=1.4)#for label size
sn.heatmap(df_cm, cmap="Blues", annot=True, annot_kws={"size": 16}, fmt='g')# font size

# %%
data = np.array([[ 51.,  11.],
                 [ 12., 380.]])
if True:
    data = data.astype('float') / data.sum(axis=1)[:, np.newaxis]

# df_cm = pd.DataFrame(data, columns=['C43', 'D22'], index = ['C43', 'D22'])
df_cm = pd.DataFrame(data, columns=['MM', 'MN'], index = ['MM', 'MN'])
df_cm.index.name = 'Actual'
df_cm.columns.name = 'Predicted'
plt.figure(figsize = (10,7), dpi=50)
sn.set(font_scale=1.4)#for label size
sn.heatmap(df_cm, cmap="Blues", annot=True, annot_kws={"size": 16}, fmt='.2%')# font size

# %% [markdown]
# # ClassSet8

# %%
layers = [1,2,3,4,5]
sets = [8]

folds_n = 5
classes_n = 5

for l in layers:
    for set_id in sets:
        
        print('Layers-{}, Set-{}'.format(l, set_id))
        
        print('Validation:')
#         val_file_template = "/mnt/models/darts_retrained/6ch_128x128_no_metainfo_registered_10Fold/XV2_SGD_orig_02DropChannel_{}lrs_2oct_ClassSet{}_ManCorected_registered_fold-{}/validation2_logits_predictions.csv"
        multi_class_folds_metrics = build_multi_class_metrics_list(val_file_template, l, set_id, folds_n, classes_n)
        
        classes_map_dict = None
        multi_class_folds_metrics.calc_scores(classes_map_dict, classes_n)
        multi_class_folds_metrics.print_scores()
        multi_class_folds_metrics.print_mean_classification_report(classes_map_dict, target_names=['Melanoma_like_lesions', 'Pigmented_benign', 'Keratin_lesions', 'Nonmelanoma_skin_cancer', 'Other'])
          
        print('--------------------------------')    
        print('Melanoma-like lesions vs. all other:')
        classes_map_dict={0:0, 1:1, 2:1, 3:1, 4:1}
        multi_class_folds_metrics.calc_scores(classes_map_dict, classes_n=2)
        multi_class_folds_metrics.print_scores()
        multi_class_folds_metrics.print_mean_classification_report(classes_map_dict, target_names=['MLL', 'PB+KL+NonMSC+Other'])
        
        print('--------------------------------')    
        print('Melanoma-like lesions+non-melanoma skin cancers vs. pigmented benign lesions + keratin lesions:')
        classes_map_dict={0:0, 1:1, 2:1, 3:0, 4:1}
        multi_class_folds_metrics.calc_scores(classes_map_dict, classes_n=2)
        multi_class_folds_metrics.print_scores()
        multi_class_folds_metrics.print_mean_classification_report(classes_map_dict, target_names=['MLL+NonMSC', 'PB+KL+Other'])
        
        print('--------------------------------')
        print('--------------------------------')
        print('--------------------------------')
        
        print('Training:')
#         val_file_template = "/mnt/models/darts_retrained/6ch_128x128_no_metainfo_registered_10Fold/XV2_SGD_orig_02DropChannel_{}lrs_2oct_ClassSet{}_ManCorected_registered_fold-{}/train2_logits_predictions.csv"
        multi_class_folds_metrics = build_multi_class_metrics_list(train_file_template, l, set_id, folds_n, classes_n)
        
        classes_map_dict = None
        multi_class_folds_metrics.calc_scores(classes_map_dict, classes_n)
        multi_class_folds_metrics.print_scores()
        multi_class_folds_metrics.print_mean_classification_report(classes_map_dict, target_names=['Melanoma_like_lesions', 'Pigmented_benign', 'Keratin_lesions', 'Nonmelanoma_skin_cancer', 'Other'])
          
        print('--------------------------------')    
        print('Melanoma-like lesions vs. all other:')
        classes_map_dict={0:0, 1:1, 2:1, 3:1, 4:1}
        multi_class_folds_metrics.calc_scores(classes_map_dict, classes_n=2)
        multi_class_folds_metrics.print_scores()
        multi_class_folds_metrics.print_mean_classification_report(classes_map_dict, target_names=['MLL', 'PB+KL+NonMSC+Other'])
        
        print('--------------------------------')    
        print('Melanoma-like lesions+non-melanoma skin cancers vs. pigmented benign lesions + keratin lesions:')
        classes_map_dict={0:0, 1:1, 2:1, 3:0, 4:1}
        multi_class_folds_metrics.calc_scores(classes_map_dict, classes_n=2)
        multi_class_folds_metrics.print_scores()
        multi_class_folds_metrics.print_mean_classification_report(classes_map_dict, target_names=['MLL+NonMSC', 'PB+KL+Other'])
        print('--------------------------------')
        print('================================')
        print('--------------------------------')
# Out:
# Layers-1, Set-8
# Validation:
# TPR=[0.68241758 0.71903041 0.51991837 0.41529412 0.76771501], TNR=[0.99249514 0.87800017 0.9470306  0.96668248 0.73163128], PPV=[0.84385614 0.70948219 0.69009973 0.65051527 0.62286159], NPV=[0.98447172 0.88466154 0.90177605 0.92253066 0.84600476], FPR=[0.00750486 0.12199983 0.0529694  0.03331752 0.26836872], FNR=[0.31758242 0.28096959 0.48008163 0.58470588 0.23228499], FDR=[0.15614386 0.29051781 0.30990027 0.34948473 0.37713841], ACC=[0.97781033 0.83194822 0.8713579  0.8992364  0.74472556], F1_micro=0.6625392068523464, F1_macro=0.6413666266650511, F1_weighted=0.655216606509021
# [[ 45.  11.   1.   2.   7.]
#  [  5. 292.  19.   6.  84.]
#  [  1.  31. 129.  13.  74.]
#  [  3.  11.  12.  71.  74.]
#  [  1.  68.  29.  20. 390.]]
#                          precision    recall  f1-score   support
#
#   Melanoma_like_lesions       0.82      0.68      0.74        66
#        Pigmented_benign       0.71      0.72      0.71       406
#         Keratin_lesions       0.68      0.52      0.59       248
# Nonmelanoma_skin_cancer       0.63      0.42      0.50       171
#                   Other       0.62      0.77      0.69       508
#
#                accuracy                           0.66      1399
#               macro avg       0.69      0.62      0.65      1399
#            weighted avg       0.67      0.66      0.66      1399
#
# --------------------------------
# Melanoma-like lesions vs. all other:
# TPR=[0.68241758 0.99249514], TNR=[0.99249514 0.68241758], PPV=[0.84385614 0.98447172], NPV=[0.98447172 0.84385614], FPR=[0.00750486 0.31758242], FNR=[0.31758242 0.00750486], FDR=[0.15614386 0.01552828], ACC=[0.97781033 0.97781033], F1_micro=0.977810329049657, F1_macro=0.8562896518434753, F1_weighted=0.9759291938991168
# [[  45.   21.]
#  [  10. 1323.]]
#                     precision    recall  f1-score   support
#
#                MLL       0.82      0.68      0.74        66
# PB+KL+NonMSC+Other       0.98      0.99      0.99      1333
#
#           accuracy                           0.98      1399
#          macro avg       0.90      0.84      0.87      1399
#       weighted avg       0.98      0.98      0.98      1399
#
# --------------------------------
# Melanoma-like lesions+non-melanoma skin cancers vs. pigmented benign lesions + keratin lesions:
# TPR=[0.51072514 0.96047739], TNR=[0.96047739 0.51072514], PPV=[0.74237781 0.90657775], NPV=[0.90657775 0.74237781], FPR=[0.03952261 0.48927486], FNR=[0.48927486 0.03952261], FDR=[0.25762219 0.09342225], ACC=[0.88420001 0.88420001], F1_micro=0.8842000113200011, F1_macro=0.7603288507967958, F1_weighted=0.8740283694508119
# [[ 121.  116.]
#  [  46. 1116.]]
#               precision    recall  f1-score   support
#
#   MLL+NonMSC       0.72      0.51      0.60       237
#  PB+KL+Other       0.91      0.96      0.93      1162
#
#     accuracy                           0.88      1399
#    macro avg       0.82      0.74      0.77      1399
# weighted avg       0.88      0.88      0.88      1399
#
# --------------------------------
# --------------------------------
# --------------------------------
# Training:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:117: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:118: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# TPR=[0.85595065 0.88548718 0.74497234 0.69602834 0.91140751], TNR=[0.99605986 0.94511969 0.98848368 0.98717482 0.85691181], PPV=[0.91805498 0.86871541 0.9339933  0.88510212 0.78449137], NPV=[0.99289831 0.95291206 0.94735163 0.95898441 0.94442689], FPR=[0.00394014 0.05488031 0.01151632 0.01282518 0.14308819], FNR=[0.14404935 0.11451282 0.25502766 0.30397166 0.08859249], FDR=[0.08194502 0.13128459 0.0660067  0.11489788 0.21550863], ACC=[0.98945485 0.92780482 0.94531395 0.95157769 0.87670154], F1_micro=0.8454264260961825, F1_macro=0.8419263890277918, F1_weighted=0.8440774793185973
# [[ 226.   16.    0.    6.   16.]
#  [  11. 1438.   16.   13.  146.]
#  [   0.   68.  739.   21.  164.]
#  [   8.    6.   10.  476.  184.]
#  [   2.  128.   27.   23. 1852.]]
#                          precision    recall  f1-score   support
#
#   Melanoma_like_lesions       0.91      0.86      0.88       264
#        Pigmented_benign       0.87      0.89      0.88      1624
#         Keratin_lesions       0.93      0.74      0.83       992
# Nonmelanoma_skin_cancer       0.88      0.70      0.78       684
#                   Other       0.78      0.91      0.84      2032
#
#                accuracy                           0.85      5596
#               macro avg       0.88      0.82      0.84      5596
#            weighted avg       0.85      0.85      0.84      5596
#
# --------------------------------
# Melanoma-like lesions vs. all other:
# TPR=[0.85595065 0.99605986], TNR=[0.99605986 0.85595065], PPV=[0.91805498 0.99289831], NPV=[0.99289831 0.91805498], FPR=[0.00394014 0.14404935], FNR=[0.14404935 0.00394014], FDR=[0.08194502 0.00710169], ACC=[0.98945485 0.98945485], F1_micro=0.9894548504412244, F1_macro=0.9396548453786717, F1_weighted=0.9893036175608423
# [[ 226.   38.]
#  [  21. 5311.]]
#                     precision    recall  f1-score   support
#
#                MLL       0.91      0.86      0.88       264
# PB+KL+NonMSC+Other       0.99      1.00      0.99      5332
#
#           accuracy                           0.99      5596
#          macro avg       0.95      0.93      0.94      5596
#       weighted avg       0.99      0.99      0.99      5596
#
# --------------------------------
# Melanoma-like lesions+non-melanoma skin cancers vs. pigmented benign lesions + keratin lesions:
# TPR=[0.75537514 0.9849395 ], TNR=[0.9849395  0.75537514], PPV=[0.91210878 0.95193242], NPV=[0.95193242 0.91210878], FPR=[0.0150605  0.24462486], FNR=[0.24462486 0.0150605 ], FDR=[0.08789122 0.04806758], ACC=[0.94603638 0.94603638], F1_micro=0.9460363778461447, F1_macro=0.8963459935753187, F1_weighted=0.9437849982002586
# [[ 716.  232.]
#  [  70. 4578.]]
#               precision    recall  f1-score   support
#
#   MLL+NonMSC       0.91      0.76      0.83       948
#  PB+KL+Other       0.95      0.98      0.97      4648
#
#     accuracy                           0.95      5596
#    macro avg       0.93      0.87      0.90      5596
# weighted avg       0.94      0.95      0.94      5596
#
# --------------------------------
# ================================
# --------------------------------
# Layers-2, Set-8
# Validation:
# TPR=[0.74395604 0.80542005 0.61681633 0.58504202 0.74012813], TNR=[0.98949037 0.901279   0.93920805 0.94790966 0.83380801], PPV=[0.77512821 0.77124084 0.69284278 0.60817227 0.71852657], NPV=[0.98729883 0.9188563  0.9193602  0.94258253 0.84916256], FPR=[0.01050963 0.098721   0.06079195 0.05209034 0.16619199], FNR=[0.25604396 0.19457995 0.38318367 0.41495798 0.25987187], FDR=[0.22487179 0.22875916 0.30715722 0.39182773 0.28147343], ACC=[0.97782567 0.87348547 0.88207261 0.90352213 0.79979918], F1_micro=0.7183525324598568, F1_macro=0.7034673284329871, F1_weighted=0.7167127768646442
# [[ 49.   6.   1.   5.   5.]
#  [  4. 327.  22.   8.  45.]
#  [  0.  27. 153.  18.  50.]
#  [  6.   3.  14. 100.  48.]
#  [  4.  62.  33.  33. 376.]]
#                          precision    recall  f1-score   support
#
#   Melanoma_like_lesions       0.78      0.74      0.76        66
#        Pigmented_benign       0.77      0.81      0.79       406
#         Keratin_lesions       0.69      0.62      0.65       248
# Nonmelanoma_skin_cancer       0.61      0.58      0.60       171
#                   Other       0.72      0.74      0.73       508
#
#                accuracy                           0.72      1399
#               macro avg       0.71      0.70      0.70      1399
#            weighted avg       0.72      0.72      0.72      1399
#
# --------------------------------
# Melanoma-like lesions vs. all other:
# TPR=[0.74395604 0.98949037], TNR=[0.98949037 0.74395604], PPV=[0.77512821 0.98729883], NPV=[0.98729883 0.77512821], FPR=[0.01050963 0.25604396], FNR=[0.25604396 0.01050963], FDR=[0.22487179 0.01270117], ACC=[0.97782567 0.97782567], F1_micro=0.9778256723980787, F1_macro=0.8720939587067542, F1_weighted=0.9773589532353697
# [[  49.   17.]
#  [  14. 1319.]]
#                     precision    recall  f1-score   support
#
#                MLL       0.78      0.74      0.76        66
# PB+KL+NonMSC+Other       0.99      0.99      0.99      1333
#
#           accuracy                           0.98      1399
#          macro avg       0.88      0.87      0.87      1399
#       weighted avg       0.98      0.98      0.98      1399
#
# --------------------------------
# Melanoma-like lesions+non-melanoma skin cancers vs. pigmented benign lesions + keratin lesions:
# TPR=[0.6752931  0.94235116], TNR=[0.94235116 0.6752931 ], PPV=[0.70227796 0.93453012], NPV=[0.93453012 0.70227796], FPR=[0.05764884 0.3247069 ], FNR=[0.3247069  0.05764884], FDR=[0.29772204 0.06546988], ACC=[0.89705759 0.89705759], F1_micro=0.8970575915172414, F1_macro=0.812796757488061, F1_weighted=0.8957825963741222
# [[ 160.   77.]
#  [  67. 1095.]]
#               precision    recall  f1-score   support
#
#   MLL+NonMSC       0.70      0.68      0.69       237
#  PB+KL+Other       0.93      0.94      0.94      1162
#
#     accuracy                           0.90      1399
#    macro avg       0.82      0.81      0.81      1399
# weighted avg       0.90      0.90      0.90      1399
#
# --------------------------------
# --------------------------------
# --------------------------------
# Training:
# TPR=[0.97721335 0.98522127 0.97680828 0.97219837 0.98080512], TNR=[0.99962459 0.99395528 0.99695935 0.99430128 0.98792644], PPV=[0.99237473 0.98526004 0.98576551 0.95976589 0.97896151], NPV=[0.9988757  0.99396713 0.99501437 0.99612722 0.98905218], FPR=[0.00037541 0.00604472 0.00304065 0.00569872 0.01207356], FNR=[0.02278665 0.01477873 0.02319172 0.02780163 0.01919488], FDR=[0.00762527 0.01473996 0.01423449 0.04023411 0.02103849], ACC=[0.99856919 0.99142042 0.99338774 0.99160058 0.98534179], F1_micro=0.9801598604621795, F1_macro=0.9793570741395472, F1_weighted=0.9801703694021239
# [[2.580e+02 1.000e+00 0.000e+00 3.000e+00 2.000e+00]
#  [0.000e+00 1.600e+03 5.000e+00 7.000e+00 1.200e+01]
#  [0.000e+00 5.000e+00 9.690e+02 5.000e+00 1.300e+01]
#  [1.000e+00 0.000e+00 2.000e+00 6.650e+02 1.600e+01]
#  [1.000e+00 1.800e+01 7.000e+00 1.300e+01 1.993e+03]]
#                          precision    recall  f1-score   support
#
#   Melanoma_like_lesions       0.99      0.98      0.98       264
#        Pigmented_benign       0.99      0.99      0.99      1624
#         Keratin_lesions       0.99      0.98      0.98       992
# Nonmelanoma_skin_cancer       0.96      0.97      0.97       684
#                   Other       0.98      0.98      0.98      2032
#
#                accuracy                           0.98      5596
#               macro avg       0.98      0.98      0.98      5596
#            weighted avg       0.98      0.98      0.98      5596
#
# --------------------------------
# Melanoma-like lesions vs. all other:
# TPR=[0.97721335 0.99962459], TNR=[0.99962459 0.97721335], PPV=[0.99237473 0.9988757 ], NPV=[0.9988757  0.99237473], FPR=[0.00037541 0.02278665], FNR=[0.02278665 0.00037541], FDR=[0.00762527 0.0011243 ], ACC=[0.99856919 0.99856919], F1_micro=0.9985691912927968, F1_macro=0.991930954659807, F1_weighted=0.9985592890831498
# [[2.58e+02 6.00e+00]
#  [2.00e+00 5.33e+03]]
#                     precision    recall  f1-score   support
#
#                MLL       0.99      0.98      0.98       264
# PB+KL+NonMSC+Other       1.00      1.00      1.00      5332
#
#           accuracy                           1.00      5596
#          macro avg       1.00      0.99      0.99      5596
#       weighted avg       1.00      1.00      1.00      5596
#
# --------------------------------
# Melanoma-like lesions+non-melanoma skin cancers vs. pigmented benign lesions + keratin lesions:
# TPR=[0.97780515 0.99440767], TNR=[0.99440767 0.97780515], PPV=[0.97281818 0.9954843 ], NPV=[0.9954843  0.97281818], FPR=[0.00559233 0.02219485], FNR=[0.02219485 0.00559233], FDR=[0.02718182 0.0045157 ], ACC=[0.99159962 0.99159962], F1_micro=0.9915996245567598, F1_macro=0.9850832204459025, F1_weighted=0.9916033837938502
# [[ 927.   21.]
#  [  26. 4622.]]
#               precision    recall  f1-score   support
#
#   MLL+NonMSC       0.97      0.98      0.98       948
#  PB+KL+Other       1.00      0.99      0.99      4648
#
#     accuracy                           0.99      5596
#    macro avg       0.98      0.99      0.99      5596
# weighted avg       0.99      0.99      0.99      5596
#
# --------------------------------
# ================================
# --------------------------------
# Layers-3, Set-8
# Validation:
# TPR=[0.75824176 0.79792231 0.59673469 0.46756303 0.76767618], TNR=[0.98500996 0.88816307 0.94787378 0.96664587 0.80341902], PPV=[0.72526611 0.74514154 0.71221216 0.66563389 0.6942265 ], NPV=[0.98796385 0.9152279  0.91618817 0.92881987 0.85759191], FPR=[0.01499004 0.11183693 0.05212622 0.03335413 0.19658098], FNR=[0.24175824 0.20207769 0.40326531 0.53243697 0.23232382], FDR=[0.27473389 0.25485846 0.28778784 0.33436611 0.3057735 ], ACC=[0.97427712 0.86200046 0.88564405 0.90565248 0.79043651], F1_micro=0.7090053170283814, F1_macro=0.6860806355481859, F1_weighted=0.7043853304023363
# [[ 50.   9.   1.   2.   4.]
#  [  8. 324.  16.   5.  53.]
#  [  1.  31. 148.   9.  59.]
#  [  9.   8.  15.  80.  59.]
#  [  2.  63.  28.  25. 390.]]
#                          precision    recall  f1-score   support
#
#   Melanoma_like_lesions       0.71      0.76      0.74        66
#        Pigmented_benign       0.74      0.80      0.77       406
#         Keratin_lesions       0.71      0.60      0.65       248
# Nonmelanoma_skin_cancer       0.66      0.47      0.55       171
#                   Other       0.69      0.77      0.73       508
#
#                accuracy                           0.71      1399
#               macro avg       0.70      0.68      0.69      1399
#            weighted avg       0.71      0.71      0.70      1399
#
# --------------------------------
# Melanoma-like lesions vs. all other:
# TPR=[0.75824176 0.98500996], TNR=[0.98500996 0.75824176], PPV=[0.72526611 0.98796385], NPV=[0.98796385 0.72526611], FPR=[0.01499004 0.24175824], FNR=[0.24175824 0.01499004], FDR=[0.27473389 0.01203615], ACC=[0.97427712 0.97427712], F1_micro=0.9742771220832287, F1_macro=0.8617080116410959, F1_weighted=0.9746377795825751
# [[  50.   16.]
#  [  20. 1313.]]
#                     precision    recall  f1-score   support
#
#                MLL       0.71      0.76      0.74        66
# PB+KL+NonMSC+Other       0.99      0.98      0.99      1333
#
#           accuracy                           0.97      1399
#          macro avg       0.85      0.87      0.86      1399
#       weighted avg       0.98      0.97      0.97      1399
#
# --------------------------------
# Melanoma-like lesions+non-melanoma skin cancers vs. pigmented benign lesions + keratin lesions:
# TPR=[0.59409466 0.95699922], TNR=[0.95699922 0.59409466], PPV=[0.73896256 0.92072618], NPV=[0.92072618 0.73896256], FPR=[0.04300078 0.40590534], FNR=[0.40590534 0.04300078], FDR=[0.26103744 0.07927382], ACC=[0.89560365 0.89560365], F1_micro=0.8956036539739209, F1_macro=0.7970810273504368, F1_weighted=0.8905849104648956
# [[ 141.   96.]
#  [  50. 1112.]]
#               precision    recall  f1-score   support
#
#   MLL+NonMSC       0.74      0.59      0.66       237
#  PB+KL+Other       0.92      0.96      0.94      1162
#
#     accuracy                           0.90      1399
#    macro avg       0.83      0.78      0.80      1399
# weighted avg       0.89      0.90      0.89      1399
#
# --------------------------------
# --------------------------------
# --------------------------------
# Training:
# TPR=[0.958418   0.98153276 0.92442516 0.89045728 0.9488072 ], TNR=[0.99718697 0.97531795 0.99457276 0.99368987 0.96466141], PPV=[0.94492103 0.94258016 0.9738364  0.95124429 0.93953897], NPV=[0.99793743 0.99235027 0.98391573 0.98490016 0.97087703], FPR=[0.00281303 0.02468205 0.00542724 0.00631013 0.03533859], FNR=[0.041582   0.01846724 0.07557484 0.10954272 0.0511928 ], FDR=[0.05507897 0.05741984 0.0261636  0.04875571 0.06046103], ACC=[0.9953549  0.9771235  0.98213516 0.98106581 0.9589036 ], F1_micro=0.9472914930176127, F1_macro=0.9448582851935683, F1_weighted=0.9470770271997486
# [[2.530e+02 5.000e+00 1.000e+00 1.000e+00 4.000e+00]
#  [2.000e+00 1.594e+03 3.000e+00 7.000e+00 1.800e+01]
#  [2.000e+00 1.400e+01 9.170e+02 9.000e+00 5.000e+01]
#  [9.000e+00 2.000e+00 1.000e+01 6.090e+02 5.400e+01]
#  [2.000e+00 7.700e+01 1.100e+01 1.400e+01 1.928e+03]]
#                          precision    recall  f1-score   support
#
#   Melanoma_like_lesions       0.94      0.96      0.95       264
#        Pigmented_benign       0.94      0.98      0.96      1624
#         Keratin_lesions       0.97      0.92      0.95       992
# Nonmelanoma_skin_cancer       0.95      0.89      0.92       684
#                   Other       0.94      0.95      0.94      2032
#
#                accuracy                           0.95      5596
#               macro avg       0.95      0.94      0.94      5596
#            weighted avg       0.95      0.95      0.95      5596
#
# --------------------------------
# Melanoma-like lesions vs. all other:
# TPR=[0.958418   0.99718697], TNR=[0.99718697 0.958418  ], PPV=[0.94492103 0.99793743], NPV=[0.99793743 0.94492103], FPR=[0.00281303 0.041582  ], FNR=[0.041582   0.00281303], FDR=[0.05507897 0.00206257], ACC=[0.9953549 0.9953549], F1_micro=0.9953549013047702, F1_macro=0.9744204012946721, F1_weighted=0.9953732466670756
# [[ 253.   11.]
#  [  15. 5317.]]
#                     precision    recall  f1-score   support
#
#                MLL       0.94      0.96      0.95       264
# PB+KL+NonMSC+Other       1.00      1.00      1.00      5332
#
#           accuracy                           1.00      5596
#          macro avg       0.97      0.98      0.97      5596
#       weighted avg       1.00      1.00      1.00      5596
#
# --------------------------------
# Melanoma-like lesions+non-melanoma skin cancers vs. pigmented benign lesions + keratin lesions:
# TPR=[0.91993281 0.99225574], TNR=[0.99225574 0.91993281], PPV=[0.96020606 0.98382787], NPV=[0.98382787 0.96020606], FPR=[0.00774426 0.08006719], FNR=[0.08006719 0.00774426], FDR=[0.03979394 0.01617213], ACC=[0.97999438 0.97999438], F1_micro=0.9799943812933835, F1_macro=0.9637391656010955, F1_weighted=0.9797860132610342
# [[ 872.   76.]
#  [  36. 4612.]]
#               precision    recall  f1-score   support
#
#   MLL+NonMSC       0.96      0.92      0.94       948
#  PB+KL+Other       0.98      0.99      0.99      4648
#
#     accuracy                           0.98      5596
#    macro avg       0.97      0.96      0.96      5596
# weighted avg       0.98      0.98      0.98      5596
#
# --------------------------------
# ================================
# --------------------------------
# Layers-4, Set-8
# Validation:
# TPR=[0.75934066 0.78084914 0.64081633 0.49092437 0.78140167], TNR=[0.98199109 0.91134007 0.93738983 0.96747887 0.81130944], PPV=[0.67248168 0.78328951 0.69208651 0.69284773 0.70923157], NPV=[0.98794383 0.91126267 0.92376414 0.93207497 0.86629681], FPR=[0.01800891 0.08865993 0.06261017 0.03252113 0.18869056], FNR=[0.24065934 0.21915086 0.35918367 0.50907563 0.21859833], FDR=[0.32751832 0.21671049 0.30791349 0.30715227 0.29076843], ACC=[0.97139944 0.8734523  0.8848455  0.9092238  0.80042644], F1_micro=0.719673737283578, F1_macro=0.6920520095252627, F1_weighted=0.7158055767037452
# [[ 50.   7.   1.   2.   6.]
#  [ 11. 317.  21.   4.  53.]
#  [  1.  24. 159.  15.  49.]
#  [  8.   3.  16.  84.  60.]
#  [  4.  54.  34.  19. 397.]]
#                          precision    recall  f1-score   support
#
#   Melanoma_like_lesions       0.68      0.76      0.71        66
#        Pigmented_benign       0.78      0.78      0.78       406
#         Keratin_lesions       0.69      0.64      0.66       248
# Nonmelanoma_skin_cancer       0.68      0.49      0.57       171
#                   Other       0.70      0.78      0.74       508
#
#                accuracy                           0.72      1399
#               macro avg       0.71      0.69      0.69      1399
#            weighted avg       0.72      0.72      0.72      1399
#
# --------------------------------
# Melanoma-like lesions vs. all other:
# TPR=[0.75934066 0.98199109], TNR=[0.98199109 0.75934066], PPV=[0.67248168 0.98794383], NPV=[0.98794383 0.67248168], FPR=[0.01800891 0.24065934], FNR=[0.24065934 0.01800891], FDR=[0.32751832 0.01205617], ACC=[0.97139944 0.97139944], F1_micro=0.9713994422694601, F1_macro=0.8483494675742446, F1_weighted=0.9720126446495201
# [[  50.   16.]
#  [  24. 1309.]]
#                     precision    recall  f1-score   support
#
#                MLL       0.68      0.76      0.71        66
# PB+KL+NonMSC+Other       0.99      0.98      0.98      1333
#
#           accuracy                           0.97      1399
#          macro avg       0.83      0.87      0.85      1399
#       weighted avg       0.97      0.97      0.97      1399
#
# --------------------------------
# Melanoma-like lesions+non-melanoma skin cancers vs. pigmented benign lesions + keratin lesions:
# TPR=[0.60720799 0.95354364], TNR=[0.95354364 0.60720799], PPV=[0.72726853 0.92311884], NPV=[0.92311884 0.72726853], FPR=[0.04645636 0.39279201], FNR=[0.39279201 0.04645636], FDR=[0.27273147 0.07688116], ACC=[0.89487882 0.89487882], F1_micro=0.8948788180134212, F1_macro=0.7966868153729137, F1_weighted=0.89000047121413
# [[ 144.   93.]
#  [  54. 1108.]]
#               precision    recall  f1-score   support
#
#   MLL+NonMSC       0.73      0.61      0.66       237
#  PB+KL+Other       0.92      0.95      0.94      1162
#
#     accuracy                           0.89      1399
#    macro avg       0.82      0.78      0.80      1399
# weighted avg       0.89      0.89      0.89      1399
#
# --------------------------------
# --------------------------------
# --------------------------------
# Training:
# TPR=[0.99245283 0.97475404 0.96273286 0.91671318 0.96900546], TNR=[0.99850082 0.98691948 0.99435372 0.99674237 0.97251595], PPV=[0.97108022 0.96915366 0.97358334 0.97509719 0.95326299], NPV=[0.99962512 0.9896774  0.99199858 0.98855025 0.98233502], FPR=[0.00149918 0.01308052 0.00564628 0.00325763 0.02748405], FNR=[0.00754717 0.02524596 0.03726714 0.08328682 0.03099454], FDR=[0.02891978 0.03084634 0.02641666 0.02490281 0.04673701], ACC=[0.99821444 0.98338932 0.98874567 0.98696091 0.97124437], F1_micro=0.9642773556064448, F1_macro=0.9652354997991053, F1_weighted=0.9641800585034801
# [[2.620e+02 1.000e+00 0.000e+00 0.000e+00 1.000e+00]
#  [2.000e+00 1.583e+03 7.000e+00 6.000e+00 2.600e+01]
#  [1.000e+00 7.000e+00 9.550e+02 3.000e+00 2.600e+01]
#  [3.000e+00 0.000e+00 9.000e+00 6.270e+02 4.500e+01]
#  [2.000e+00 4.400e+01 1.000e+01 7.000e+00 1.969e+03]]
#                          precision    recall  f1-score   support
#
#   Melanoma_like_lesions       0.97      0.99      0.98       264
#        Pigmented_benign       0.97      0.97      0.97      1624
#         Keratin_lesions       0.97      0.96      0.97       992
# Nonmelanoma_skin_cancer       0.98      0.92      0.94       684
#                   Other       0.95      0.97      0.96      2032
#
#                accuracy                           0.96      5596
#               macro avg       0.97      0.96      0.97      5596
#            weighted avg       0.96      0.96      0.96      5596
#
# --------------------------------
# Melanoma-like lesions vs. all other:
# TPR=[0.99245283 0.99850082], TNR=[0.99850082 0.99245283], PPV=[0.97108022 0.99962512], NPV=[0.99962512 0.97108022], FPR=[0.00149918 0.00754717], FNR=[0.00754717 0.00149918], FDR=[0.02891978 0.00037488], ACC=[0.99821444 0.99821444], F1_micro=0.9982144421598862, F1_macro=0.9902516010759463, F1_weighted=0.9982299191761299
# [[2.620e+02 2.000e+00]
#  [8.000e+00 5.324e+03]]
#                     precision    recall  f1-score   support
#
#                MLL       0.97      0.99      0.98       264
# PB+KL+NonMSC+Other       1.00      1.00      1.00      5332
#
#           accuracy                           1.00      5596
#          macro avg       0.98      1.00      0.99      5596
#       weighted avg       1.00      1.00      1.00      5596
#
# --------------------------------
# Melanoma-like lesions+non-melanoma skin cancers vs. pigmented benign lesions + keratin lesions:
# TPR=[0.94098544 0.99548271], TNR=[0.99548271 0.94098544], PPV=[0.97689503 0.98809607], NPV=[0.98809607 0.97689503], FPR=[0.00451729 0.05901456], FNR=[0.05901456 0.00451729], FDR=[0.02310497 0.01190393], ACC=[0.9862471 0.9862471], F1_micro=0.9862471013017615, F1_macro=0.9750416737539433, F1_weighted=0.9860972476440247
# [[ 892.   56.]
#  [  21. 4627.]]
#               precision    recall  f1-score   support
#
#   MLL+NonMSC       0.98      0.94      0.96       948
#  PB+KL+Other       0.99      1.00      0.99      4648
#
#     accuracy                           0.99      5596
#    macro avg       0.98      0.97      0.98      5596
# weighted avg       0.99      0.99      0.99      5596
#
# --------------------------------
# ================================
# --------------------------------
# Layers-5, Set-8
# Validation:
# TPR=[0.74505495 0.81276724 0.66057143 0.50319328 0.72632499], TNR=[0.98197979 0.88921769 0.93396057 0.95442376 0.84833273], PPV=[0.67021978 0.75144044 0.6807031  0.60787336 0.73576649], NPV=[0.98719691 0.92066652 0.92787432 0.93238071 0.84428159], FPR=[0.01802021 0.11078231 0.06603943 0.04557624 0.15166727], FNR=[0.25494505 0.18723276 0.33942857 0.49680672 0.27367501], FDR=[0.32978022 0.24855956 0.3192969  0.39212664 0.26423351], ACC=[0.97067994 0.86701305 0.88557763 0.89923362 0.80404626], F1_micro=0.7132752506255767, F1_macro=0.6866716494882873, F1_weighted=0.7105323911765684
# [[ 49.  10.   0.   4.   3.]
#  [  7. 330.  27.   4.  38.]
#  [  4.  25. 164.  13.  42.]
#  [  9.   5.  19.  86.  52.]
#  [  4.  70.  30.  35. 369.]]
#                          precision    recall  f1-score   support
#
#   Melanoma_like_lesions       0.67      0.74      0.71        66
#        Pigmented_benign       0.75      0.81      0.78       406
#         Keratin_lesions       0.68      0.66      0.67       248
# Nonmelanoma_skin_cancer       0.61      0.50      0.55       171
#                   Other       0.73      0.73      0.73       508
#
#                accuracy                           0.71      1399
#               macro avg       0.69      0.69      0.69      1399
#            weighted avg       0.71      0.71      0.71      1399
#
# --------------------------------
# Melanoma-like lesions vs. all other:
# TPR=[0.74505495 0.98197979], TNR=[0.98197979 0.74505495], PPV=[0.67021978 0.98719691], NPV=[0.98719691 0.67021978], FPR=[0.01802021 0.25494505], FNR=[0.25494505 0.01802021], FDR=[0.32978022 0.01280309], ACC=[0.97067994 0.97067994], F1_micro=0.9706799449190122, F1_macro=0.8443583214738497, F1_weighted=0.9712662055526422
# [[  49.   17.]
#  [  24. 1309.]]
#                     precision    recall  f1-score   support
#
#                MLL       0.67      0.74      0.71        66
# PB+KL+NonMSC+Other       0.99      0.98      0.98      1333
#
#           accuracy                           0.97      1399
#          macro avg       0.83      0.86      0.84      1399
#       weighted avg       0.97      0.97      0.97      1399
#
# --------------------------------
# Melanoma-like lesions+non-melanoma skin cancers vs. pigmented benign lesions + keratin lesions:
# TPR=[0.62475033 0.9423362 ], TNR=[0.9423362  0.62475033], PPV=[0.68846459 0.9248593 ], NPV=[0.9248593  0.68846459], FPR=[0.0576638  0.37524967], FNR=[0.37524967 0.0576638 ], FDR=[0.31153541 0.0751407 ], ACC=[0.88847556 0.88847556], F1_micro=0.8884755570593553, F1_macro=0.7940459152219341, F1_weighted=0.8862008969707889
# [[ 148.   89.]
#  [  67. 1095.]]
#               precision    recall  f1-score   support
#
#   MLL+NonMSC       0.69      0.62      0.65       237
#  PB+KL+Other       0.92      0.94      0.93      1162
#
#     accuracy                           0.89      1399
#    macro avg       0.81      0.78      0.79      1399
# weighted avg       0.88      0.89      0.89      1399
#
# --------------------------------
# --------------------------------
# --------------------------------
# Training:
# TPR=[0.99622642 0.98953656 0.98993452 0.97367969 0.97195386], TNR=[0.99925058 0.98867002 0.99695935 0.99694791 0.99298972], PPV=[0.98518519 0.9728532  0.98604433 0.97823073 0.98764423], NPV=[0.99981256 0.99569673 0.9978303  0.99634759 0.98422814], FPR=[0.00074942 0.01132998 0.00304065 0.00305209 0.00701028], FNR=[0.00377358 0.01046344 0.01006548 0.02632031 0.02804614], FDR=[0.01481481 0.0271468  0.01395567 0.02176927 0.01235577], ACC=[0.99910762 0.98892089 0.995713   0.99410554 0.98534961], F1_micro=0.981598327943184, F1_macro=0.9830218117414212, F1_weighted=0.9815793245268771
# [[2.630e+02 1.000e+00 0.000e+00 0.000e+00 0.000e+00]
#  [0.000e+00 1.607e+03 5.000e+00 5.000e+00 7.000e+00]
#  [0.000e+00 2.000e+00 9.820e+02 3.000e+00 5.000e+00]
#  [3.000e+00 1.000e+00 1.000e+00 6.660e+02 1.300e+01]
#  [1.000e+00 4.100e+01 8.000e+00 7.000e+00 1.975e+03]]
#                          precision    recall  f1-score   support
#
#   Melanoma_like_lesions       0.99      1.00      0.99       264
#        Pigmented_benign       0.97      0.99      0.98      1624
#         Keratin_lesions       0.99      0.99      0.99       992
# Nonmelanoma_skin_cancer       0.98      0.97      0.98       684
#                   Other       0.99      0.97      0.98      2032
#
#                accuracy                           0.98      5596
#               macro avg       0.98      0.98      0.98      5596
#            weighted avg       0.98      0.98      0.98      5596
#
# --------------------------------
# Melanoma-like lesions vs. all other:
# TPR=[0.99622642 0.99925058], TNR=[0.99925058 0.99622642], PPV=[0.98518519 0.99981256], NPV=[0.99981256 0.98518519], FPR=[0.00074942 0.00377358], FNR=[0.00377358 0.00074942], FDR=[0.01481481 0.00018744], ACC=[0.99910762 0.99910762], F1_micro=0.9991076204620699, F1_macro=0.995092822848093, F1_weighted=0.99911158139316
# [[2.630e+02 1.000e+00]
#  [4.000e+00 5.328e+03]]
#                     precision    recall  f1-score   support
#
#                MLL       0.99      1.00      0.99       264
# PB+KL+NonMSC+Other       1.00      1.00      1.00      5332
#
#           accuracy                           1.00      5596
#          macro avg       0.99      1.00      1.00      5596
#       weighted avg       1.00      1.00      1.00      5596
#
# --------------------------------
# Melanoma-like lesions+non-melanoma skin cancers vs. pigmented benign lesions + keratin lesions:
# TPR=[0.9831131  0.99655983], TNR=[0.99655983 0.9831131 ], PPV=[0.98330249 0.99656646], NPV=[0.99656646 0.98330249], FPR=[0.00344017 0.0168869 ], FNR=[0.0168869  0.00344017], FDR=[0.01669751 0.00343354], ACC=[0.99428427 0.99428427], F1_micro=0.9942842663590051, F1_macro=0.9898406647802472, F1_weighted=0.9942846080648738
# [[ 932.   16.]
#  [  16. 4632.]]
#               precision    recall  f1-score   support
#
#   MLL+NonMSC       0.98      0.98      0.98       948
#  PB+KL+Other       1.00      1.00      1.00      4648
#
#     accuracy                           0.99      5596
#    macro avg       0.99      0.99      0.99      5596
# weighted avg       0.99      0.99      0.99      5596
#
# --------------------------------
# ================================
# --------------------------------

# %% [markdown]
# ### 2 - layers have best TPR for clas MLL

# %%
data = np.array([[ 49.,   6.,   1.,   5.,   5.],
                 [  4., 327.,  22.,   8.,  45.],
                 [  0.,  27., 153.,  18.,  50.],
                 [  6.,   3.,  14., 100.,  48.],
                 [  4.,  62.,  33.,  33., 376.]])
if False:
    data = data.astype('float') / data.sum(axis=1)[:, np.newaxis]
df_cm = pd.DataFrame(data, columns=['MLL', 'PBL', 'KL', 'NonMSC', 'OBL'], index = ['MLL', 'PBL', 'KL', 'NonMSC', 'OBL'])
df_cm.index.name = 'Actual'
df_cm.columns.name = 'Predicted'
plt.figure(figsize = (10,7), dpi=50)
sn.set(font_scale=1.4)#for label size
sn.heatmap(df_cm, cmap="Blues", annot=True, annot_kws={"size": 16}, fmt='g')# font size .2%

# %%
data = np.array([[ 49.,   6.,   1.,   5.,   5.],
                 [  4., 327.,  22.,   8.,  45.],
                 [  0.,  27., 153.,  18.,  50.],
                 [  6.,   3.,  14., 100.,  48.],
                 [  4.,  62.,  33.,  33., 376.]])
if True:
    data = data.astype('float') / data.sum(axis=1)[:, np.newaxis]
df_cm = pd.DataFrame(data, columns=['MLL', 'PBL', 'KL', 'NonMSC', 'OBL'], index = ['MLL', 'PBL', 'KL', 'NonMSC', 'OBL'])
df_cm.index.name = 'Actual'
df_cm.columns.name = 'Predicted'
plt.figure(figsize = (10,7), dpi=50)
sn.set(font_scale=1.4)#for label size
sn.heatmap(df_cm, cmap="Blues", annot=True, annot_kws={"size": 16}, fmt='.2%')# font size .2%

# %% [markdown]
# ## ClassSet8 - NonMSC vs rest

# %%
layers = [1,2,3,4,5]
sets = [8]

folds_n = 5
classes_n = 5

for l in layers:
    for set_id in sets:
        
        print('Layers-{}, Set-{}'.format(l, set_id))
        
        print('Validation:')
#         val_file_template = "/mnt/models/darts_retrained/6ch_128x128_no_metainfo_registered_10Fold/XV2_SGD_orig_02DropChannel_{}lrs_2oct_ClassSet{}_ManCorected_registered_fold-{}/validation2_logits_predictions.csv"
        multi_class_folds_metrics = build_multi_class_metrics_list(val_file_template, l, set_id, folds_n, classes_n)
        
#         classes_map_dict = None
#         multi_class_folds_metrics.calc_scores(classes_map_dict, classes_n)
#         multi_class_folds_metrics.print_scores()
#         multi_class_folds_metrics.print_mean_classification_report(classes_map_dict, target_names=['Melanoma_like_lesions', 'Pigmented_benign', 'Keratin_lesions', 'Nonmelanoma_skin_cancer', 'Other'])
          
#         multi_class_folds_metrics = build_multi_class_metrics_list(val_file_template, l, set_id, folds_n, classes_n)
    
        print('--------------------------------')    
        print('NonMSC vs MLL+PB+KL+Other:')
        classes_map_dict={0:0, 1:0, 2:0, 3:1, 4:0}
        multi_class_folds_metrics.calc_scores(classes_map_dict, classes_n=2)
        multi_class_folds_metrics.print_scores()
        multi_class_folds_metrics.print_mean_classification_report(classes_map_dict, target_names=['MLL+PB+KL+Other', 'NonMSC'])
        
        
        print('--------------------------------')
        print('--------------------------------')
        print('--------------------------------')
        
        print('Training:')
#         val_file_template = "/mnt/models/darts_retrained/6ch_128x128_no_metainfo_registered_10Fold/XV2_SGD_orig_02DropChannel_{}lrs_2oct_ClassSet{}_ManCorected_registered_fold-{}/train2_logits_predictions.csv"
        multi_class_folds_metrics = build_multi_class_metrics_list(train_file_template, l, set_id, folds_n, classes_n)
        
#         classes_map_dict = None
#         multi_class_folds_metrics.calc_scores(classes_map_dict, classes_n)
#         multi_class_folds_metrics.print_scores()
#         multi_class_folds_metrics.print_mean_classification_report(classes_map_dict, target_names=['Melanoma_like_lesions', 'Pigmented_benign', 'Keratin_lesions', 'Nonmelanoma_skin_cancer', 'Other'])
        
        print('--------------------------------')    
        print('NonMSC vs MLL+PB+KL+Other:')
        classes_map_dict={0:0, 1:0, 2:0, 3:1, 4:0}
        multi_class_folds_metrics.calc_scores(classes_map_dict, classes_n=2)
        multi_class_folds_metrics.print_scores()
        multi_class_folds_metrics.print_mean_classification_report(classes_map_dict, target_names=['MLL+PB+KL+Other', 'NonMSC'])
        print('--------------------------------')
        print('================================')
        print('--------------------------------')
# Out:
# Layers-1, Set-8
# Validation:
# --------------------------------
# NonMSC vs MLL+PB+KL+Other:
# TPR=[0.96668248 0.41529412], TNR=[0.41529412 0.96668248], PPV=[0.92253066 0.65051527], NPV=[0.65051527 0.92253066], FPR=[0.58470588 0.03331752], FNR=[0.03331752 0.58470588], FDR=[0.07746934 0.34948473], ACC=[0.8992364 0.8992364], F1_micro=0.8992364018551624, F1_macro=0.7191605511195915, F1_weighted=0.8889482451410806
# [[1187.   41.]
#  [ 100.   71.]]
#                  precision    recall  f1-score   support
#
# MLL+PB+KL+Other       0.92      0.97      0.94      1228
#          NonMSC       0.63      0.42      0.50       171
#
#        accuracy                           0.90      1399
#       macro avg       0.78      0.69      0.72      1399
#    weighted avg       0.89      0.90      0.89      1399
#
# --------------------------------
# --------------------------------
# --------------------------------
# Training:
# --------------------------------
# NonMSC vs MLL+PB+KL+Other:
# TPR=[0.98717482 0.69602834], TNR=[0.69602834 0.98717482], PPV=[0.95898441 0.88510212], NPV=[0.88510212 0.95898441], FPR=[0.30397166 0.01282518], FNR=[0.01282518 0.30397166], FDR=[0.04101559 0.11489788], ACC=[0.95157769 0.95157769], F1_micro=0.9515776906063232, F1_macro=0.8746878670939026, F1_weighted=0.9488391189720498
# [[4849.   63.]
#  [ 208.  476.]]
#                  precision    recall  f1-score   support
#
# MLL+PB+KL+Other       0.96      0.99      0.97      4912
#          NonMSC       0.88      0.70      0.78       684
#
#        accuracy                           0.95      5596
#       macro avg       0.92      0.84      0.88      5596
#    weighted avg       0.95      0.95      0.95      5596
#
# --------------------------------
# ================================
# --------------------------------
# Layers-2, Set-8
# Validation:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:117: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:118: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# --------------------------------
# NonMSC vs MLL+PB+KL+Other:
# TPR=[0.94790966 0.58504202], TNR=[0.58504202 0.94790966], PPV=[0.94258253 0.60817227], NPV=[0.60817227 0.94258253], FPR=[0.41495798 0.05209034], FNR=[0.05209034 0.41495798], FDR=[0.05741747 0.39182773], ACC=[0.90352213 0.90352213], F1_micro=0.9035221341688345, F1_macro=0.7703781131565044, F1_weighted=0.902442804249284
# [[1164.   64.]
#  [  71.  100.]]
#                  precision    recall  f1-score   support
#
# MLL+PB+KL+Other       0.94      0.95      0.95      1228
#          NonMSC       0.61      0.58      0.60       171
#
#        accuracy                           0.90      1399
#       macro avg       0.78      0.77      0.77      1399
#    weighted avg       0.90      0.90      0.90      1399
#
# --------------------------------
# --------------------------------
# --------------------------------
# Training:
# --------------------------------
# NonMSC vs MLL+PB+KL+Other:
# TPR=[0.99430128 0.97219837], TNR=[0.97219837 0.99430128], PPV=[0.99612722 0.95976589], NPV=[0.95976589 0.99612722], FPR=[0.02780163 0.00569872], FNR=[0.00569872 0.02780163], FDR=[0.00387278 0.04023411], ACC=[0.99160058 0.99160058], F1_micro=0.9916005834739915, F1_macro=0.9805280263721675, F1_weighted=0.9916220647975968
# [[4884.   28.]
#  [  19.  665.]]
#                  precision    recall  f1-score   support
#
# MLL+PB+KL+Other       1.00      0.99      1.00      4912
#          NonMSC       0.96      0.97      0.97       684
#
#        accuracy                           0.99      5596
#       macro avg       0.98      0.98      0.98      5596
#    weighted avg       0.99      0.99      0.99      5596
#
# --------------------------------
# ================================
# --------------------------------
# Layers-3, Set-8
# Validation:
# --------------------------------
# NonMSC vs MLL+PB+KL+Other:
# TPR=[0.96664587 0.46756303], TNR=[0.46756303 0.96664587], PPV=[0.92881987 0.66563389], NPV=[0.66563389 0.92881987], FPR=[0.53243697 0.03335413], FNR=[0.03335413 0.53243697], FDR=[0.07118013 0.33436611], ACC=[0.90565248 0.90565248], F1_micro=0.9056524814653788, F1_macro=0.7471760169285808, F1_weighted=0.8984008961033773
# [[1187.   41.]
#  [  91.   80.]]
#                  precision    recall  f1-score   support
#
# MLL+PB+KL+Other       0.93      0.97      0.95      1228
#          NonMSC       0.66      0.47      0.55       171
#
#        accuracy                           0.91      1399
#       macro avg       0.79      0.72      0.75      1399
#    weighted avg       0.90      0.91      0.90      1399
#
# --------------------------------
# --------------------------------
# --------------------------------
# Training:
# --------------------------------
# NonMSC vs MLL+PB+KL+Other:
# TPR=[0.99368987 0.89045728], TNR=[0.89045728 0.99368987], PPV=[0.98490016 0.95124429], NPV=[0.95124429 0.98490016], FPR=[0.10954272 0.00631013], FNR=[0.00631013 0.10954272], FDR=[0.01509984 0.04875571], ACC=[0.98106581 0.98106581], F1_micro=0.98106581385843, F1_macro=0.9544072707199511, F1_weighted=0.9807438640698403
# [[4881.   31.]
#  [  75.  609.]]
#                  precision    recall  f1-score   support
#
# MLL+PB+KL+Other       0.98      0.99      0.99      4912
#          NonMSC       0.95      0.89      0.92       684
#
#        accuracy                           0.98      5596
#       macro avg       0.97      0.94      0.95      5596
#    weighted avg       0.98      0.98      0.98      5596
#
# --------------------------------
# ================================
# --------------------------------
# Layers-4, Set-8
# Validation:
# --------------------------------
# NonMSC vs MLL+PB+KL+Other:
# TPR=[0.96747887 0.49092437], TNR=[0.49092437 0.96747887], PPV=[0.93207497 0.69284773], NPV=[0.69284773 0.93207497], FPR=[0.50907563 0.03252113], FNR=[0.03252113 0.50907563], FDR=[0.06792503 0.30715227], ACC=[0.9092238 0.9092238], F1_micro=0.9092238010908756, F1_macro=0.7555608071846651, F1_weighted=0.9018835183911976
# [[1188.   40.]
#  [  87.   84.]]
#                  precision    recall  f1-score   support
#
# MLL+PB+KL+Other       0.93      0.97      0.95      1228
#          NonMSC       0.68      0.49      0.57       171
#
#        accuracy                           0.91      1399
#       macro avg       0.80      0.73      0.76      1399
#    weighted avg       0.90      0.91      0.90      1399
#
# --------------------------------
# --------------------------------
# --------------------------------
# Training:
# --------------------------------
# NonMSC vs MLL+PB+KL+Other:
# TPR=[0.99674237 0.91671318], TNR=[0.91671318 0.99674237], PPV=[0.98855025 0.97509719], NPV=[0.97509719 0.98855025], FPR=[0.08328682 0.00325763], FNR=[0.00325763 0.08328682], FDR=[0.01144975 0.02490281], ACC=[0.98696091 0.98696091], F1_micro=0.9869609085546884, F1_macro=0.9684391688351542, F1_weighted=0.9867064825603377
# [[4896.   16.]
#  [  57.  627.]]
#                  precision    recall  f1-score   support
#
# MLL+PB+KL+Other       0.99      1.00      0.99      4912
#          NonMSC       0.98      0.92      0.94       684
#
#        accuracy                           0.99      5596
#       macro avg       0.98      0.96      0.97      5596
#    weighted avg       0.99      0.99      0.99      5596
#
# --------------------------------
# ================================
# --------------------------------
# Layers-5, Set-8
# Validation:
# --------------------------------
# NonMSC vs MLL+PB+KL+Other:
# TPR=[0.95442376 0.50319328], TNR=[0.50319328 0.95442376], PPV=[0.93238071 0.60787336], NPV=[0.60787336 0.93238071], FPR=[0.49680672 0.04557624], FNR=[0.04557624 0.49680672], FDR=[0.06761929 0.39212664], ACC=[0.89923362 0.89923362], F1_micro=0.8992336224369272, F1_macro=0.74654589390061, F1_weighted=0.8951286183309017
# [[1172.   56.]
#  [  85.   86.]]
#                  precision    recall  f1-score   support
#
# MLL+PB+KL+Other       0.93      0.95      0.94      1228
#          NonMSC       0.61      0.50      0.55       171
#
#        accuracy                           0.90      1399
#       macro avg       0.77      0.73      0.75      1399
#    weighted avg       0.89      0.90      0.90      1399
#
# --------------------------------
# --------------------------------
# --------------------------------
# Training:
# --------------------------------
# NonMSC vs MLL+PB+KL+Other:
# TPR=[0.99694791 0.97367969], TNR=[0.97367969 0.99694791], PPV=[0.99634759 0.97823073], NPV=[0.97823073 0.99634759], FPR=[0.02632031 0.00305209], FNR=[0.00305209 0.02632031], FDR=[0.00365241 0.02176927], ACC=[0.99410554 0.99410554], F1_micro=0.994105535349175, F1_macro=0.9862124585542196, F1_weighted=0.9940955076714971
# [[4897.   15.]
#  [  18.  666.]]
#                  precision    recall  f1-score   support
#
# MLL+PB+KL+Other       1.00      1.00      1.00      4912
#          NonMSC       0.98      0.97      0.98       684
#
#        accuracy                           0.99      5596
#       macro avg       0.99      0.99      0.99      5596
#    weighted avg       0.99      0.99      0.99      5596
#
# --------------------------------
# ================================
# --------------------------------

# %%
data = np.array([[572.,  35.],
                 [ 34.,  52.]])
if False:
    data = data.astype('float') / data.sum(axis=1)[:, np.newaxis]
df_cm = pd.DataFrame(data, columns=['NonMSC', 'MLL+PBL+KL+OBL'], index = ['NonMSC', 'MLL+PBL+KL+OBL'])
df_cm.index.name = 'Actual'
df_cm.columns.name = 'Predicted'
plt.figure(figsize = (10,7), dpi=50)
sn.set(font_scale=1.4)#for label size
sn.heatmap(df_cm, cmap="Blues", annot=True, annot_kws={"size": 16}, fmt='g')# font size .2%

# %%
data = np.array([[572.,  35.],
                 [ 34.,  52.]])
if True:
    data = data.astype('float') / data.sum(axis=1)[:, np.newaxis]
df_cm = pd.DataFrame(data, columns=['NonMSC', 'MLL+PBL+KL+OBL'], index = ['NonMSC', 'MLL+PBL+KL+OBL'])
df_cm.index.name = 'Actual'
df_cm.columns.name = 'Predicted'
plt.figure(figsize = (10,7), dpi=50)
sn.set(font_scale=1.4)#for label size
sn.heatmap(df_cm, cmap="Blues", annot=True, annot_kws={"size": 16}, fmt='.2%')# font size .2%

# %% [markdown]
# # Playground

# %%
def plot_confusion_matrix(cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=True):
    """
    given a sklearn confusion matrix (cm), make a nice plot

    Arguments
    ---------
    cm:           confusion matrix from sklearn.metrics.confusion_matrix

    target_names: given classification classes such as [0, 1, 2]
                  the class names, for example: ['high', 'medium', 'low']

    title:        the text to display at the top of the matrix

    cmap:         the gradient of the values displayed from matplotlib.pyplot.cm
                  see http://matplotlib.org/examples/color/colormaps_reference.html
                  plt.get_cmap('jet') or plt.cm.Blues

    normalize:    If False, plot the raw numbers
                  If True, plot the proportions

    Usage
    -----
    plot_confusion_matrix(cm           = cm,                  # confusion matrix created by
                                                              # sklearn.metrics.confusion_matrix
                          normalize    = True,                # show proportions
                          target_names = y_labels_vals,       # list of names of the classes
                          title        = best_estimator_name) # title of graph

    Citiation
    ---------
    http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html

    """
    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(8, 6), dpi=100)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()

# %%
# plot_confusion_matrix(cm           = np.array([[ 32.,   7.,   1.,   5.,   2.],
#                                              [  5., 327.,  25.,   8.,  42.],
#                                              [  1.,  32., 161.,  13.,  41.],
#                                              [  7.,   4.,  17., 100.,  43.],
#                                              [  7.,  63.,  28.,  35., 375.]]), 
#                       normalize    = False,
#                       target_names = ['MLL', 'PBL', 'KL', 'NonMSC', 'Other'],
#                       title        = "Confusion Matrix")

# %%
# fig = plt.figure(figsize=(6, 6), dpi=300)
plot_confusion_matrix(cm           = np.array([[ 32.,   7.,   1.,   5.,   2.],
                                             [  5., 327.,  25.,   8.,  42.],
                                             [  1.,  32., 161.,  13.,  41.],
                                             [  7.,   4.,  17., 100.,  43.],
                                             [  7.,  63.,  28.,  35., 375.]]), 
                      normalize    = True,
                      target_names = ['MLL', 'PBL', 'KL', 'NonMSC', 'Other'],
                      title        = "Confusion Matrix")
