# %% [markdown]
# # Data set gathering

# %% [markdown]
# -----------------------
#
# ### This notebook is version 2 of the previous. Main distinction is that for Checkyourskin we are using manually composed excel with LesionCodes.
#
#
# -----------------------

# %% [markdown]
# This notebook aims at preparing checkyourskin and LOC datasets.
#
# The problems are:
#
# For LOC - we don't have info about channels in early images. Only starting from around 2018 images have R / IR /G / UV in their names - which allows to determine their channels.
#
# For Checkyourskin - there are no diagnoze - but there is a file from Dmitry Bliznyuk, with (unfortunately) non-aligned diagnozes (there are no strikt matching :()

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import os
import pandas as pd
import ntpath
import struct
from PIL import Image
import numpy as np
import scipy
import scipy.misc
import scipy.cluster
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
from PIL import Image
from os import listdir
from os.path import isfile, join
from IPython.display import HTML
import io
import base64
import re
import json
from imutils import paths
import argparse
import cv2
from tqdm import tqdm_notebook
from pathlib import Path

# %matplotlib inline

# %%
os.getcwd()
# Out:
# '/mnt/notebooks/3_Images_sequence__extended_wtih_checkyourskin'

# %%
raw_data_folder_name = '_melanoma'

data_folder = os.path.abspath(os.path.join('../../data/raw', raw_data_folder_name))
data_folder
# Out:
# '/mnt/data/raw/_melanoma'

# %%
melanoma_folder = os.path.abspath(os.path.join(os.getcwd(), '..', '..', 'data', 'raw', '_melanoma'))

# %% [markdown]
# ## Let's see excel files

# %% [markdown]
# ### HungaryResults.xlsx

# %%
hungary_results_xlsx_path =  os.path.join(melanoma_folder, 'HungaryResults.xlsx')
hungary_results = pd.read_excel(hungary_results_xlsx_path, header=1)
# hungary_results.head(5)

# %% [markdown]
# ### LOC_ERAF2017_sakartots.xlsx

# %%
loc_eraf2017_xlsx_path =  os.path.join(melanoma_folder, 'LOC_ERAF2017_sakartots.xlsx')
loc_eraf2017 = pd.read_excel(loc_eraf2017_xlsx_path, header=0)
# loc_eraf2017.head(5)

# %% [markdown]
# ### LOC_class_2020_04_15b_DB_OK.xlsx --> this is replaced by Ilze_Whatsup_df_checkyrskin_2020_07_28.xlsx
# File name is a bit misleading - these are diagnosis codes for the patients from Hungary

# %%
df_checkyrskin_2020_07_28_xlsx_path =  os.path.join(melanoma_folder, 'Ilze_Whatsup_df_checkyrskin_2020_07_28.xlsx')
loc_df_checkyrskin_2020_07_28 = pd.read_excel(df_checkyrskin_2020_07_28_xlsx_path, header=0)
loc_df_checkyrskin_2020_07_28.head(15)
# Out:
#     patient_id  measurementId                  measurementSetId  \
# 0         1685           1685  2049752a10138492ccf5e46dbea078ff
# 1         3753           3753  593e38ee6500a5f8ad36390293e94351
# 2         1367           1367  06634b2a1ff268294a25f1d5e3408746
# 3          309            309  30f589534eed314b2bdbcd41925ab015
# 4         2162           2162  aace78ffb3981205230d53632804c270
# 5         2858           2858  eb323d8e0ed8ecc1a29df654b45aa964
# 6         1713           1713  b20d87df92adf96f2503bb3d57b9ce18
# 7         2543           2543  03a276820640fb82b99b9f173a7e3381
# 8         3838           3838  32b2fc50d85338d8c773c01b0f8158a1
# 9         2604           2604  6c09c9751538deb857f93166166b17af
# 10         345            345  34df6a8d8b378471d7852a7c2b2c0430
# 11        2987           2987  fb4f111bcf9dc90dcf8b3f9be76dc69a
# 12        2617           2617  4d1aa33c4eef4593f245ae00fe2cd56c
# 13        3068           3068  5b1b244e5e088e97290e38c089842f83
# 14        1394           1394  94da4f751a78642a4fa299ecfa3b6bae
#
#    measurementComment measurementDateCreated measurementDateFinished  \
# 0                 NaN    2019-03-29 12:55:16     2019-03-29 10:55:16
# 1                 NaN    2019-12-06 10:15:07     2019-12-06 08:15:07
# 2                 NaN    2019-03-05 13:10:10     2019-03-05 11:10:10
# 3                 NaN    2018-12-12 18:42:29     2018-12-12 16:42:29
# 4                 NaN    2019-05-17 20:18:47     2019-05-17 17:18:47
# 5                 NaN    2019-09-06 10:32:37     2019-09-06 07:32:37
# 6                 NaN    2019-04-01 11:48:31     2019-04-01 08:48:31
# 7                 NaN    2019-07-10 09:59:48     2019-07-10 06:59:48
# 8                 NaN    2019-12-09 12:44:18     2019-12-09 10:44:18
# 9                 NaN    2019-07-19 11:50:24     2019-07-19 08:50:24
# 10                NaN    2018-12-17 14:05:25     2018-12-17 12:05:25
# 11                NaN    2019-09-20 12:05:27     2019-09-20 09:05:27
# 12                NaN    2019-07-22 10:23:09     2019-07-22 07:23:09
# 13                NaN    2019-10-10 13:50:35     2019-10-10 10:50:35
# 14                NaN    2019-03-07 13:42:29     2019-03-07 11:42:29
#
#     receivedImagesCount  deviceId deviceName  \
# 0                    20         4        LOC
# 1                     4         4        LOC
# 2                    10         2    Hungary
# 3                     3         2    Hungary
# 4                     3         4        LOC
# 5                     4         4        LOC
# 6                    10         2    Hungary
# 7                     3         4        LOC
# 8                    20         4        LOC
# 9                     3         4        LOC
# 10                    3         2    Hungary
# 11                    4         4        LOC
# 12                   20         4        LOC
# 13                    4         4        LOC
# 14                    3         2    Hungary
#
#                                     images_paths_list  ... is_uv_images  \
# 0   ['/mnt/data/raw/_melanoma/Checkyourskin/1685/i...  ...         True
# 1   ['/mnt/data/raw/_melanoma/Checkyourskin/3753/i...  ...         True
# 2   ['/mnt/data/raw/_melanoma/Checkyourskin/1367/i...  ...         True
# 3   ['/mnt/data/raw/_melanoma/Checkyourskin/309/in...  ...         True
# 4   ['/mnt/data/raw/_melanoma/Checkyourskin/2162/i...  ...         True
# 5   ['/mnt/data/raw/_melanoma/Checkyourskin/2858/i...  ...         True
# 6   ['/mnt/data/raw/_melanoma/Checkyourskin/1713/i...  ...         True
# 7   ['/mnt/data/raw/_melanoma/Checkyourskin/2543/i...  ...         True
# 8   ['/mnt/data/raw/_melanoma/Checkyourskin/3838/i...  ...         True
# 9   ['/mnt/data/raw/_melanoma/Checkyourskin/2604/i...  ...         True
# 10  ['/mnt/data/raw/_melanoma/Checkyourskin/345/in...  ...         True
# 11  ['/mnt/data/raw/_melanoma/Checkyourskin/2987/i...  ...         True
# 12  ['/mnt/data/raw/_melanoma/Checkyourskin/2617/i...  ...         True
# 13  ['/mnt/data/raw/_melanoma/Checkyourskin/3068/i...  ...         True
# 14  ['/mnt/data/raw/_melanoma/Checkyourskin/1394/i...  ...         True
#
#     analyzeId  numberInSequence  analyzeDateCreated analyzePatientId  \
# 0         NaN               NaN                 NaT              NaN
# 1         NaN               NaN                 NaT              NaN
# 2       522.0               1.0 2019-03-05 13:16:02            170.0
# 3       149.0               9.0 2019-01-22 09:53:25             59.0
# 4         NaN               NaN                 NaT              NaN
# 5         NaN               NaN                 NaT              NaN
# 6       741.0               1.0 2019-04-01 11:50:46            211.0
# 7         NaN               NaN                 NaT              NaN
# 8         NaN               NaN                 NaT              NaN
# 9         NaN               NaN                 NaT              NaN
# 10      149.0              32.0 2019-01-22 09:53:25             59.0
# 11        NaN               NaN                 NaT              NaN
# 12        NaN               NaN                 NaT              NaN
# 13        NaN               NaN                 NaT              NaN
# 14      550.0               1.0 2019-03-07 14:47:34            175.0
#
#     analyzeScannedBodyPartId                         analyzeDoctorComment  \
# 0                        NaN                                          NaN
# 1                        NaN                                          NaN
# 2                       16.0  solar keratosis, right side of the forehead
# 3                        5.0                    test pictures from Latvia
# 4                        NaN                                          NaN
# 5                        NaN                                          NaN
# 6                       26.0       dysplastic naevus on the left shoulder
# 7                        NaN                                          NaN
# 8                        NaN                                          NaN
# 9                        NaN                                          NaN
# 10                       5.0                    test pictures from Latvia
# 11                       NaN                                          NaN
# 12                       NaN                                          NaN
# 13                       NaN                                          NaN
# 14                      27.0                        pxe, axillar, lateral
#
#    analyzeDiagnosisComment LesionCode           Paskaidrojums
# 0                      NaN        NaN                     NaN
# 1                      NaN        NaN                     NaN
# 2                      NaN        L57  jeb aktīniskā keratoze
# 3                      NaN        NaN            testa bildes
# 4                      NaN        NaN                     NaN
# 5                      NaN        NaN                     NaN
# 6                      NaN        D48                     NaN
# 7                      NaN        NaN                     NaN
# 8                      NaN        NaN                     NaN
# 9                      NaN        NaN                     NaN
# 10                     NaN        NaN            testa bildes
# 11                     NaN        NaN                     NaN
# 12                     NaN        NaN                     NaN
# 13                     NaN        NaN                     NaN
# 14                     NaN        PXE                     NaN
#
# [15 rows x 21 columns]

# %% [markdown]
# ### extra_melanoma.xlsx
# Hand picked melanomas (c43 + c44) by Yuriy Chizhov

# %%
loc_extra_melanomas_xlsx_path =  os.path.join(melanoma_folder, 'extra_melanoma.xlsx')
loc_extra_melanomas = pd.read_excel(loc_extra_melanomas_xlsx_path, header=0)
# loc_extra_melanomas.head(5)

# %% [markdown]
# ## LOC images
# Let's gather all R/G/IR/UV images (paths) from within LOC along with their diagnoses.

# %%
melanoma_folder = os.path.abspath(os.path.join(os.getcwd(), '..', '..', 'data', 'raw', '_melanoma'))

merijumi_loc_folder =  os.path.join(melanoma_folder, 'Merijumi LOC')
print(merijumi_loc_folder)
# Out:
# /mnt/data/raw/_melanoma/Merijumi LOC

# %% [markdown]
# - First level can be skipped
# - Second level contains patient ID and exact date with per person data in subfolders
# 1) We are looking for subfolders with '.tar' in their names. (Starting with 2019-04, because these folders have R/IR/G/UV in files names and we can use them)

# %%
def load_metadata_csv(tar_folder_path: str):
    csv_path = os.path.join(tar_folder_path, 'metadata', 'metadata.csv')
    if os.path.exists(csv_path):
        df = pd.read_csv(csv_path)
#         return df.to_json()
        if len(df.to_dict('records')) > 1:
            print('Multi-row metadata.csv encountered:', csv_path)
            print(df.head())
            
        return df.to_dict('records')[0]
    else:
#         print('File not exists! ', csv_path)
        return {}

def collect_images(tar_folder_path: str):
    images_paths_list = []
    in_folder_path = os.path.join(tar_folder_path, 'in')
    
    uv_images = False
    if os.path.exists(in_folder_path):
        for in_folder_file in os.listdir(in_folder_path):
            img_file = os.path.join(in_folder_path, in_folder_file)
            if os.path.isfile(img_file):
                if '.png' in in_folder_file or '.jpg' in in_folder_file or '.jpeg' in in_folder_file or '.tiff' in in_folder_file:
                    
                    images_paths_list.append(img_file)
                    if uv_images == False and in_folder_file.startswith('UV'):
                        uv_images = True
                        
#                     print('Image found:', in_folder_file)
                else:
#                     print('Skipping file: ', in_folder_file)
                    pass
            else:
#                 print('Found folder in "in" subfolder: ', in_folder_path, in_folder_file)
                pass
    else:
#         print('"in" Folder not exists!', in_folder_path)
        pass
        
    return images_paths_list, uv_images
                    
            
def process_tar_folder(tar_folder_path: str, date: str, patient_id: str):
#     print('process_tar_folder', tar_folder_path)
    
    if 'kluda' in tar_folder_path or 'error' in tar_folder_path or 'analizei' in tar_folder_path:
        return []
    
    # We assume that above level contains "lesion_id"
    parent_folder_path = Path(tar_folder_path).parent
#     print('parent_folder_path', parent_folder_path)
    lesion_id = parent_folder_path.name
    
    metadata_json = load_metadata_csv(tar_folder_path)
    images_paths_list, is_uv_images = collect_images(tar_folder_path)
    metadata_json['images_paths_list'] = images_paths_list
    metadata_json['date'] = date
    metadata_json['patient_id'] = patient_id
    metadata_json['lesion_id'] = lesion_id
    metadata_json['is_uv_images'] = is_uv_images
    return [metadata_json]
    

def process_subfolders(root_folder_path: str, date: str, patient_id: str):
    if os.path.isdir(root_folder_path):
        if 'tar' in root_folder_path:
            return process_tar_folder(root_folder_path, date, patient_id)
        else:
            results_list = []
            for subfolder in os.listdir(root_folder_path):
                subfolder_path = os.path.join(root_folder_path, subfolder)
                subresults_list = process_subfolders(subfolder_path, date, patient_id)
                if len(subresults_list) > 0:
                    results_list.extend(subresults_list)
            return results_list
    else:
        return []
    
def process_loc_root_folder(_folder: str):
    full_rows_list = []
    for level1_folder in os.listdir(_folder):
        level1_subfolder = os.path.join(_folder, level1_folder)
        level1_date = level1_folder
        if os.path.isdir(level1_subfolder):
            for date_patient_id_folder in os.listdir(level1_subfolder):
                date_patient_id_folder_path = os.path.join(level1_subfolder, date_patient_id_folder)
                if os.path.isdir(date_patient_id_folder_path) \
                   and 'VISION' not in date_patient_id_folder \
                   and 'bonuss' not in date_patient_id_folder:
                    if len(date_patient_id_folder) >= 10: 
                        date = date_patient_id_folder[0:10]
                        patient_id = date_patient_id_folder[11:]
                    else:
                        date = level1_date
                        patient_id = date_patient_id_folder

                    print('folder:', date_patient_id_folder, ': date-', date, ': patient_id-', patient_id, '----')

                    rows_list = process_subfolders(date_patient_id_folder_path, date, patient_id) 
                    full_rows_list.extend(rows_list)
    return full_rows_list

# %%
full_rows_list = process_loc_root_folder(merijumi_loc_folder)
# Out:
# folder: 2018_02_09 : date- 2018_02_09 : patient_id-  ----
# folder: 2018_02_09_88 : date- 2018_02_09 : patient_id- 88 ----
# folder: 2018_02_12_90 : date- 2018_02_12 : patient_id- 90 ----
# folder: 2018_02_07_85 : date- 2018_02_07 : patient_id- 85 ----
# folder: 2018_02_07_87 : date- 2018_02_07 : patient_id- 87 ----
# folder: 84 : date- 2018_02 : patient_id- 84 ----
# folder: 2018_02_12_89 : date- 2018_02_12 : patient_id- 89 ----
# folder: 83 : date- 2018_02 : patient_id- 83 ----
# folder: 2018_02_07_86 : date- 2018_02_07 : patient_id- 86 ----
# folder: 82 : date- 2018_02 : patient_id- 82 ----
# folder: 2018-07-02_145 : date- 2018-07-02 : patient_id- 145 ----
# folder: 2018-07-27_150 : date- 2018-07-27 : patient_id- 150 ----
# folder: 2018-07-30_153 : date- 2018-07-30 : patient_id- 153 ----
# folder: 2018-07-02_143 : date- 2018-07-02 : patient_id- 143 ----
# folder: 2018-07-04_147 : date- 2018-07-04 : patient_id- 147 ----
# folder: 2018-07-02_144 : date- 2018-07-02 : patient_id- 144 ----
# folder: 2018-07-30_154 : date- 2018-07-30 : patient_id- 154 ----
# folder: 2018-07-11_140B : date- 2018-07-11 : patient_id- 140B ----
# folder: 2018-07-04_149 : date- 2018-07-04 : patient_id- 149 ----
# folder: 2018-07-02_142 : date- 2018-07-02 : patient_id- 142 ----
# folder: 2018-07-02_141 : date- 2018-07-02 : patient_id- 141 ----
# folder: 2018-07-03_146 : date- 2018-07-03 : patient_id- 146 ----
# folder: 2018-07-04_148 : date- 2018-07-04 : patient_id- 148 ----
# folder: 2018-07-27_152 : date- 2018-07-27 : patient_id- 152 ----
# folder: 2018-07-20_151 : date- 2018-07-20 : patient_id- 151 ----
# folder: 2018-12-05_56B : date- 2018-12-05 : patient_id- 56B ----
# folder: 2018-12-12_206 : date- 2018-12-12 : patient_id- 206 ----
# folder: 2018-12-10_204 : date- 2018-12-10 : patient_id- 204 ----
# folder: 2018-12-14_207 : date- 2018-12-14 : patient_id- 207 ----
# folder: 2018-12-07_202 : date- 2018-12-07 : patient_id- 202 ----
# folder: 2018-12-07_203 : date- 2018-12-07 : patient_id- 203 ----
# folder: 2018-12-10_204 (1) : date- 2018-12-10 : patient_id- 204 (1) ----
# folder: 2018-12-05_201 : date- 2018-12-05 : patient_id- 201 ----
# folder: 2018-12-03_200 : date- 2018-12-03 : patient_id- 200 ----
# folder: 2018-12-17_208 : date- 2018-12-17 : patient_id- 208 ----
# folder: 2018-12-12_205 : date- 2018-12-12 : patient_id- 205 ----
# folder: 2018-06-20_33B : date- 2018-06-20 : patient_id- 33B ----
# folder: 2018-06-01_131 : date- 2018-06-01 : patient_id- 131 ----
# folder: 2018-06-08_127 : date- 2018-06-08 : patient_id- 127 ----
# folder: 2018-06-25_138 : date- 2018-06-25 : patient_id- 138 ----
# folder: 2018-06-18_134 : date- 2018-06-18 : patient_id- 134 ----
# folder: 2018-06-20_136 : date- 2018-06-20 : patient_id- 136 ----
# folder: 2018-06-13_130 : date- 2018-06-13 : patient_id- 130 ----
# folder: 2018-06-18_135 : date- 2018-06-18 : patient_id- 135 ----
# folder: 2018-06-08_128 : date- 2018-06-08 : patient_id- 128 ----
# folder: 2018-06-01_126 : date- 2018-06-01 : patient_id- 126 ----
# folder: 2018-06-18_99 : date- 2018-06-18 : patient_id- 99 ----
# folder: 2018-06-18_133 : date- 2018-06-18 : patient_id- 133 ----
# folder: 2018-06-11_129 : date- 2018-06-11 : patient_id- 129 ----
# folder: 2018-06-15_73 : date- 2018-06-15 : patient_id- 73 ----
# folder: 2018-06-22_137 : date- 2018-06-22 : patient_id- 137 ----
# folder: 2018-06-29_140 : date- 2018-06-29 : patient_id- 140 ----
# folder: 2018-06-27_139 : date- 2018-06-27 : patient_id- 139 ----
# folder: 2018-06-15_132 : date- 2018-06-15 : patient_id- 132 ----
# folder: 2019-03-15_226 : date- 2019-03-15 : patient_id- 226 ----
# folder: 2019-03-22_230 : date- 2019-03-22 : patient_id- 230 ----
# folder: 2019-03-13_57B : date- 2019-03-13 : patient_id- 57B ----
# folder: 2019-03-11_225 : date- 2019-03-11 : patient_id- 225 ----
# folder: 2019-03-27_140D : date- 2019-03-27 : patient_id- 140D ----
# folder: 2019-03-11_224 : date- 2019-03-11 : patient_id- 224 ----
# folder: 2019-03-29_231 : date- 2019-03-29 : patient_id- 231 ----
# folder: 2019-03-11_223 : date- 2019-03-11 : patient_id- 223 ----
# folder: 2019-03-22_229 : date- 2019-03-22 : patient_id- 229 ----
# folder: 2019-03-04_222 : date- 2019-03-04 : patient_id- 222 ----
# folder: 2019-07-05_263 : date- 2019-07-05 : patient_id- 263 ----
# folder: 2019-07-22_272 : date- 2019-07-22 : patient_id- 272 ----
# folder: 2019-07-17_270 : date- 2019-07-17 : patient_id- 270 ----
# folder: 2019-07-26_275 : date- 2019-07-26 : patient_id- 275 ----
# folder: 2019-07-03_261 : date- 2019-07-03 : patient_id- 261 ----
# folder: 2019-07-03_260 : date- 2019-07-03 : patient_id- 260 ----
# folder: 2019-07-24_273 : date- 2019-07-24 : patient_id- 273 ----
# folder: 2019-07-10_267 : date- 2019-07-10 : patient_id- 267 ----
# folder: 2019-07-19_271 : date- 2019-07-19 : patient_id- 271 ----
# folder: 2019-07-31_276 : date- 2019-07-31 : patient_id- 276 ----
# folder: 2019-07-15_269 : date- 2019-07-15 : patient_id- 269 ----
# folder: 2019-07-24_274 : date- 2019-07-24 : patient_id- 274 ----
# folder: 2019-07-10_266 : date- 2019-07-10 : patient_id- 266 ----
# folder: 2019-07-22_125B : date- 2019-07-22 : patient_id- 125B ----
# folder: 2019-07-05_262 : date- 2019-07-05 : patient_id- 262 ----
# folder: 2019-07-05_265 : date- 2019-07-05 : patient_id- 265 ----
# folder: 2019-07-12_268 : date- 2019-07-12 : patient_id- 268 ----
# folder: 2019-07-05_264 : date- 2019-07-05 : patient_id- 264 ----
# folder: 2020-01-06_9B : date- 2020-01-06 : patient_id- 9B ----
# folder: 2020-01-13_326 : date- 2020-01-13 : patient_id- 326 ----
# folder: 2020-01-06_276B : date- 2020-01-06 : patient_id- 276B ----
# folder: 2020-01-10_56C : date- 2020-01-10 : patient_id- 56C ----
# folder: 2020-01-10_324 : date- 2020-01-10 : patient_id- 324 ----
# folder: 2020-01-10_325 : date- 2020-01-10 : patient_id- 325 ----
# folder: 79 : date- 2018_01 : patient_id- 79 ----
# folder: 78 : date- 2018_01 : patient_id- 78 ----
# folder: 81 : date- 2018_01 : patient_id- 81 ----
# folder: 2018_01_10_76 : date- 2018_01_10 : patient_id- 76 ----
# folder: 2018_01_08_73 : date- 2018_01_08 : patient_id- 73 ----
# folder: 2018_01_10_75 : date- 2018_01_10 : patient_id- 75 ----
# folder: 77 : date- 2018_01 : patient_id- 77 ----
# folder: 2018_01_08_74 : date- 2018_01_08 : patient_id- 74 ----
# folder: 2018_01_08_72 : date- 2018_01_08 : patient_id- 72 ----
# folder: 80 : date- 2018_01 : patient_id- 80 ----
# folder: 2018_01_08_71 : date- 2018_01_08 : patient_id- 71 ----
# folder: 2019-06-12_254 : date- 2019-06-12 : patient_id- 254 ----
# folder: 2019-06-14_255 : date- 2019-06-14 : patient_id- 255 ----
# folder: 2019-06-12_253 : date- 2019-06-12 : patient_id- 253 ----
# folder: 2019-06-28_259 : date- 2019-06-28 : patient_id- 259 ----
# folder: 2019-06-17_257 : date- 2019-06-17 : patient_id- 257 ----
# folder: 2019-06-10_250 : date- 2019-06-10 : patient_id- 250 ----
# folder: 2019-06-10_251 : date- 2019-06-10 : patient_id- 251 ----
# folder: 2019-06-17_256 : date- 2019-06-17 : patient_id- 256 ----
# folder: 2019-06-26_258 : date- 2019-06-26 : patient_id- 258 ----
# folder: 2019-06-17_115B : date- 2019-06-17 : patient_id- 115B ----
# folder: 2019-06-14_252 : date- 2019-06-14 : patient_id- 252 ----
# folder: 2019-06-10_249 : date- 2019-06-10 : patient_id- 249 ----
# folder: 2018-11-23_195 : date- 2018-11-23 : patient_id- 195 ----
# folder: 2018-11-05_187 : date- 2018-11-05 : patient_id- 187 ----
# folder: 2018-11-05_190 : date- 2018-11-05 : patient_id- 190 ----
# folder: 2018-11-02_186 : date- 2018-11-02 : patient_id- 186 ----
# folder: 2018-11-09_192 : date- 2018-11-09 : patient_id- 192 ----
# folder: 2018-11-28_197 : date- 2018-11-28 : patient_id- 197 ----
# folder: 2018-11-16_194_ : date- 2018-11-16 : patient_id- 194_ ----
# folder: 2018-11-30_199 : date- 2018-11-30 : patient_id- 199 ----
# folder: 2018-11-05_189 : date- 2018-11-05 : patient_id- 189 ----
# folder: 2018-11-05_188 : date- 2018-11-05 : patient_id- 188 ----
# folder: 2018-11-16_193 : date- 2018-11-16 : patient_id- 193 ----
# folder: 2018-11-28_198 : date- 2018-11-28 : patient_id- 198 ----
# folder: 2018-11-09_191 : date- 2018-11-09 : patient_id- 191 ----
# folder: 2018-11-26_196 : date- 2018-11-26 : patient_id- 196 ----
# folder: 2018-11-20_145B : date- 2018-11-20 : patient_id- 145B ----
# folder: 2017_12_06_57 : date- 2017_12_06 : patient_id- 57 ----
# folder: 2017_12_06_59 : date- 2017_12_06 : patient_id- 59 ----
# folder: 2017_12_06_56 : date- 2017_12_06 : patient_id- 56 ----
# folder: 2017_12_20_69 : date- 2017_12_20 : patient_id- 69 ----
# folder: 2017_12_04_54 : date- 2017_12_04 : patient_id- 54 ----
# folder: 2017_12_04_48 : date- 2017_12_04 : patient_id- 48 ----
# folder: 2017_12_06_58 : date- 2017_12_06 : patient_id- 58 ----
# folder: 2017_12_08_61 : date- 2017_12_08 : patient_id- 61 ----
# folder: 2017_12_04_51 : date- 2017_12_04 : patient_id- 51 ----
# folder: 2017_12_08_62 : date- 2017_12_08 : patient_id- 62 ----
# folder: 2017_12_18_66 : date- 2017_12_18 : patient_id- 66 ----
# folder: 2017_12_04_50 : date- 2017_12_04 : patient_id- 50 ----
# folder: 2017_12_18_67 : date- 2017_12_18 : patient_id- 67 ----
# folder: 2017_12_08_64 : date- 2017_12_08 : patient_id- 64 ----
# folder: Bonuss : date- 2017_12 : patient_id- Bonuss ----
# folder: 2017_12_04_49 : date- 2017_12_04 : patient_id- 49 ----
# folder: 2017_12_08_60 : date- 2017_12_08 : patient_id- 60 ----
# folder: 2017_12_18_68 : date- 2017_12_18 : patient_id- 68 ----
# folder: 2017_12_29_70 : date- 2017_12_29 : patient_id- 70 ----
# folder: 2017_12_08_63 : date- 2017_12_08 : patient_id- 63 ----
# folder: 2017_12_04_52 : date- 2017_12_04 : patient_id- 52 ----
# folder: 2017_12_06_55 : date- 2017_12_06 : patient_id- 55 ----
# folder: 2017_12_08_65 : date- 2017_12_08 : patient_id- 65 ----
# folder: 2017_12_04_53 : date- 2017_12_04 : patient_id- 53 ----
# folder: 2019-11-01_305 : date- 2019-11-01 : patient_id- 305 ----
# folder: 2019-11-29_310 : date- 2019-11-29 : patient_id- 310 ----
# folder: 2019-11-08_306 : date- 2019-11-08 : patient_id- 306 ----
# folder: 2019-11-25_308 : date- 2019-11-25 : patient_id- 308 ----
# folder: 2019-11-29_311 : date- 2019-11-29 : patient_id- 311 ----
# folder: 2019-11-29_309 : date- 2019-11-29 : patient_id- 309 ----
# folder: 2019-11-11_132B : date- 2019-11-11 : patient_id- 132B ----
# folder: 2019-11-25_307 : date- 2019-11-25 : patient_id- 307 ----
# folder: 2018_04_09_106 : date- 2018_04_09 : patient_id- 106 ----
# folder: 2018_04_06_103 : date- 2018_04_06 : patient_id- 103 ----
# folder: 2018-04-18-107 : date- 2018-04-18 : patient_id- 107 ----
# folder: 2018-04-25_112 : date- 2018-04-25 : patient_id- 112 ----
# folder: 2018-04-23_109 : date- 2018-04-23 : patient_id- 109 ----
# folder: 2018-04-25_113 : date- 2018-04-25 : patient_id- 113 ----
# folder: 2018-04-23_108 : date- 2018-04-23 : patient_id- 108 ----
# folder: 2018-04-18_47B : date- 2018-04-18 : patient_id- 47B ----
# folder: 2018_04_09_105 : date- 2018_04_09 : patient_id- 105 ----
# folder: 2018_04_06_104 : date- 2018_04_06 : patient_id- 104 ----
# folder: 2018-04-23_110 : date- 2018-04-23 : patient_id- 110 ----
# folder: 2019-12-02_199B : date- 2019-12-02 : patient_id- 199B ----
# folder: 2019-12-09_122B : date- 2019-12-09 : patient_id- 122B ----
# folder: 2019-12-06_313 : date- 2019-12-06 : patient_id- 313 ----
# folder: 2019-12-09_315 : date- 2019-12-09 : patient_id- 315 ----
# folder: 2019-12-23_323 : date- 2019-12-23 : patient_id- 323 ----
# folder: 2019-12-13_316 : date- 2019-12-13 : patient_id- 316 ----
# folder: 2019-12-06_312 : date- 2019-12-06 : patient_id- 312 ----
# folder: 2019-12-20_320 : date- 2019-12-20 : patient_id- 320 ----
# folder: 2019-12-20_321 : date- 2019-12-20 : patient_id- 321 ----
# folder: 2019-12-02_138B : date- 2019-12-02 : patient_id- 138B ----
# folder: 2019-12-16_319 : date- 2019-12-16 : patient_id- 319 ----
# folder: 2019-12-23_322 : date- 2019-12-23 : patient_id- 322 ----
# folder: 2019-12-16_318 : date- 2019-12-16 : patient_id- 318 ----
# folder: 2019-12-06_314 : date- 2019-12-06 : patient_id- 314 ----
# folder: 2019-12-16_317 : date- 2019-12-16 : patient_id- 317 ----
# folder: 2019-04-26_238 : date- 2019-04-26 : patient_id- 238 ----
# folder: 2019-04-17_234 : date- 2019-04-17 : patient_id- 234 ----
# folder: 2019-04-26_104B : date- 2019-04-26 : patient_id- 104B ----
# folder: 2019-04-15_233 : date- 2019-04-15 : patient_id- 233 ----
# folder: 2019-04-24_235 : date- 2019-04-24 : patient_id- 235 ----
# folder: Neapstradatie : date- Neapstrada : patient_id- ie ----
# folder: 2019-04-05_232 : date- 2019-04-05 : patient_id- 232 ----
# folder: 2019-04-24_236 : date- 2019-04-24 : patient_id- 236 ----
# folder: 2019-09-18_291 : date- 2019-09-18 : patient_id- 291 ----
# folder: 2019-09-30_297 : date- 2019-09-30 : patient_id- 297 ----
# folder: 2019-09-06_287 : date- 2019-09-06 : patient_id- 287 ----
# folder: 2019-09-02_284 : date- 2019-09-02 : patient_id- 284 ----
# folder: 2019-09-02_285 : date- 2019-09-02 : patient_id- 285 ----
# folder: 2019-09-25_296 : date- 2019-09-25 : patient_id- 296 ----
# folder: 2019-09-06_289 : date- 2019-09-06 : patient_id- 289 ----
# folder: 2019-09-20_294 : date- 2019-09-20 : patient_id- 294 ----
# folder: 2019-09-18_292 : date- 2019-09-18 : patient_id- 292 ----
# folder: 2019-09-06_286 : date- 2019-09-06 : patient_id- 286 ----
# folder: 2019-09-06_288 : date- 2019-09-06 : patient_id- 288 ----
# folder: 2019-09-23_295 : date- 2019-09-23 : patient_id- 295 ----
# folder: 2019-09-20_293 : date- 2019-09-20 : patient_id- 293 ----
# folder: 2019-09-16_290 : date- 2019-09-16 : patient_id- 290 ----
# folder: 2018_03_14_96 : date- 2018_03_14 : patient_id- 96 ----
# folder: 2018_03_12_93 : date- 2018_03_12 : patient_id- 93 ----
# folder: 2018_03_19_99 : date- 2018_03_19 : patient_id- 99 ----
# folder: 2018_03_26_25 : date- 2018_03_26 : patient_id- 25 ----
# folder: 2018_03_21_100 : date- 2018_03_21 : patient_id- 100 ----
# folder: 2018_03_12_95 : date- 2018_03_12 : patient_id- 95 ----
# folder: 2018_03_12_94 : date- 2018_03_12 : patient_id- 94 ----
# folder: 2018-03-26-102 : date- 2018-03-26 : patient_id- 102 ----
# folder: 2018_03_26_101 : date- 2018_03_26 : patient_id- 101 ----
# folder: 2018_03_07_92 : date- 2018_03_07 : patient_id- 92 ----
# folder: 2018_03_07_91 : date- 2018_03_07 : patient_id- 91 ----
# folder: 2018_03_19_98 : date- 2018_03_19 : patient_id- 98 ----
# folder: 2018_03_14_97 : date- 2018_03_14 : patient_id- 97 ----
# folder: 2019-01-07_210 : date- 2019-01-07 : patient_id- 210 ----
# folder: 2019-01-07_212 : date- 2019-01-07 : patient_id- 212 ----
# folder: 2019-01-30_171B : date- 2019-01-30 : patient_id- 171B ----
# folder: 2019-01-14_213 : date- 2019-01-14 : patient_id- 213 ----
# folder: 2019-01-07_211 : date- 2019-01-07 : patient_id- 211 ----
# folder: 2019-01-04_209 : date- 2019-01-04 : patient_id- 209 ----
# folder: 2019-01-16_214 : date- 2019-01-16 : patient_id- 214 ----
# folder: 2017_11_17_34 : date- 2017_11_17 : patient_id- 34 ----
# folder: 2017_11_17_35 : date- 2017_11_17 : patient_id- 35 ----
# folder: 2017_11_17_36 : date- 2017_11_17 : patient_id- 36 ----
# folder: 2017_11_8_28 : date- 2017_11_8_ : patient_id- 8 ----
# folder: 2017_11_1_21 : date- 2017_11_1_ : patient_id- 1 ----
# folder: 2017_11_22_42 : date- 2017_11_22 : patient_id- 42 ----
# folder: 2017_11_8_26 : date- 2017_11_8_ : patient_id- 6 ----
# folder: 2017_11_24_46 : date- 2017_11_24 : patient_id- 46 ----
# folder: 2017_11_24_45 : date- 2017_11_24 : patient_id- 45 ----
# folder: 2017_11_22_44 : date- 2017_11_22 : patient_id- 44 ----
# folder: 2017_11_1_17 : date- 2017_11_1_ : patient_id- 7 ----
# folder: 2017_11_1_20 : date- 2017_11_1_ : patient_id- 0 ----
# folder: 2017_11_27_47 : date- 2017_11_27 : patient_id- 47 ----
# folder: 2017_11_22_40 : date- 2017_11_22 : patient_id- 40 ----
# folder: 2017_11_3_23 : date- 2017_11_3_ : patient_id- 3 ----
# folder: 2017_11_22_38 : date- 2017_11_22 : patient_id- 38 ----
# folder: 2017_11_15_33 : date- 2017_11_15 : patient_id- 33 ----
# folder: 2017_11_1_19 : date- 2017_11_1_ : patient_id- 9 ----
# folder: 2017_11_6_25 : date- 2017_11_6_ : patient_id- 5 ----
# folder: 2017_11_22_43 : date- 2017_11_22 : patient_id- 43 ----
# folder: 2017_11_8_29 : date- 2017_11_8_ : patient_id- 9 ----
# folder: 2017_11_22_41 : date- 2017_11_22 : patient_id- 41 ----
# folder: 2017_11_8_30 : date- 2017_11_8_ : patient_id- 0 ----
# folder: 2017_11_22_39 : date- 2017_11_22 : patient_id- 39 ----
# folder: 2017_11_8_27 : date- 2017_11_8_ : patient_id- 7 ----
# folder: 2017_11_22_37 : date- 2017_11_22 : patient_id- 37 ----
# folder: 2017_11_6_24 : date- 2017_11_6_ : patient_id- 4 ----
# folder: 2017_11_3_22 : date- 2017_11_3_ : patient_id- 2 ----
# folder: 2017_11_15_32 : date- 2017_11_15 : patient_id- 32 ----
# folder: 2017_11_1_18 : date- 2017_11_1_ : patient_id- 8 ----
# folder: 2017_11_15_31 : date- 2017_11_15 : patient_id- 31 ----
# folder: 2017_10_23_15 : date- 2017_10_23 : patient_id- 15 ----
# folder: 2017_10_18_2 : date- 2017_10_18 : patient_id- 2 ----
# folder: 2017_10_23_13 : date- 2017_10_23 : patient_id- 13 ----
# folder: 2017_10_23_10 : date- 2017_10_23 : patient_id- 10 ----
# folder: 2017_10_23_5 : date- 2017_10_23 : patient_id- 5 ----
# folder: 2017_10_23_12 : date- 2017_10_23 : patient_id- 12 ----
# folder: 2017_10_18_1 : date- 2017_10_18 : patient_id- 1 ----
# folder: 2017_10_23_16 : date- 2017_10_23 : patient_id- 16 ----
# folder: 2017_10_23_7 : date- 2017_10_23 : patient_id- 7 ----
# folder: 2017_10_23_8 : date- 2017_10_23 : patient_id- 8 ----
# folder: Bonuss : date- 2017_10 : patient_id- Bonuss ----
# folder: 2017_10_18_3 : date- 2017_10_18 : patient_id- 3 ----
# folder: 2017_10_23_9 : date- 2017_10_23 : patient_id- 9 ----
# folder: 2017_10_23_6 : date- 2017_10_23 : patient_id- 6 ----
# folder: 2017_10_23_14 : date- 2017_10_23 : patient_id- 14 ----
# folder: 2017_10_23_11 : date- 2017_10_23 : patient_id- 11 ----
# folder: 2017_10_23_4 : date- 2017_10_23 : patient_id- 4 ----
# folder: 2019-02-22_220 : date- 2019-02-22 : patient_id- 220 ----
# folder: 2019-02-20_218 : date- 2019-02-20 : patient_id- 218 ----
# folder: 2019-02-22_219 : date- 2019-02-22 : patient_id- 219 ----
# folder: 2019-02-04_215 : date- 2019-02-04 : patient_id- 215 ----
# folder: 2019-02-06_216 : date- 2019-02-06 : patient_id- 216 ----
# folder: 2019-02-13_217 : date- 2019-02-13 : patient_id- 217 ----
# folder: 2019-02-27_221 : date- 2019-02-27 : patient_id- 221 ----
# folder: 2018-09-12_167 : date- 2018-09-12 : patient_id- 167 ----
# folder: 2018-09-12_168 : date- 2018-09-12 : patient_id- 168 ----
# folder: 2018-09-03_163 : date- 2018-09-03 : patient_id- 163 ----
# folder: 2018-09-05_164 : date- 2018-09-05 : patient_id- 164 ----
# folder: 2018-09-14_170 : date- 2018-09-14 : patient_id- 170 ----
# folder: 2018-09-12_169 : date- 2018-09-12 : patient_id- 169 ----
# folder: 2018-09-05_165 : date- 2018-09-05 : patient_id- 165 ----
# folder: 2018-09-07_166 : date- 2018-09-07 : patient_id- 166 ----
# folder: 2019-05-10_240 : date- 2019-05-10 : patient_id- 240 ----
# folder: 2019-05-27_247 : date- 2019-05-27 : patient_id- 247 ----
# folder: 2019-05-24_244 : date- 2019-05-24 : patient_id- 244 ----
# folder: 2019-05-10_239 : date- 2019-05-10 : patient_id- 239 ----
# folder: 2019-05-20_242 : date- 2019-05-20 : patient_id- 242 ----
# folder: 2019-05-27_248 : date- 2019-05-27 : patient_id- 248 ----
# folder: 2019-05-24_246 : date- 2019-05-24 : patient_id- 246 ----
# folder: 2019-05-24_245 : date- 2019-05-24 : patient_id- 245 ----
# folder: 2019-05-13_241 : date- 2019-05-13 : patient_id- 241 ----
# folder: 2019-05-10_237 : date- 2019-05-10 : patient_id- 237 ----
# folder: 2019-05-22_243 : date- 2019-05-22 : patient_id- 243 ----
# folder: 2019-08-09_277 : date- 2019-08-09 : patient_id- 277 ----
# folder: 2019-08-14_94B : date- 2019-08-14 : patient_id- 94B ----
# folder: 2019-08-19_110B : date- 2019-08-19 : patient_id- 110B ----
# folder: 2019-08-14_279 : date- 2019-08-14 : patient_id- 279 ----
# folder: 2019-08-21_281 : date- 2019-08-21 : patient_id- 281 ----
# folder: 2019-08-05_206B : date- 2019-08-05 : patient_id- 206B ----
# folder: 2019-08-26_282 : date- 2019-08-26 : patient_id- 282 ----
# folder: 2019-08-19_280 : date- 2019-08-19 : patient_id- 280 ----
# folder: 2019-08-30_283 : date- 2019-08-30 : patient_id- 283 ----
# folder: 2019-08-09_278 : date- 2019-08-09 : patient_id- 278 ----
# folder: 2018-05-23_122 : date- 2018-05-23 : patient_id- 122 ----
# folder: 2018-05-14_117 : date- 2018-05-14 : patient_id- 117 ----
# folder: 2018-05-07_114 : date- 2018-05-07 : patient_id- 114 ----
# folder: 2018-05-23_120 : date- 2018-05-23 : patient_id- 120 ----
# folder: 2018-05-23_121 : date- 2018-05-23 : patient_id- 121 ----
# folder: 2018-05-30_125 : date- 2018-05-30 : patient_id- 125 ----
# folder: 2018-05-07_111 : date- 2018-05-07 : patient_id- 111 ----
# folder: 2018-05-21_118 : date- 2018-05-21 : patient_id- 118 ----
# folder: 2018-05-23_119 : date- 2018-05-23 : patient_id- 119 ----
# folder: 2018-05-14_116 : date- 2018-05-14 : patient_id- 116 ----
# folder: 2018-05-28_123 : date- 2018-05-28 : patient_id- 123 ----
# folder: 2018-05-09_115 : date- 2018-05-09 : patient_id- 115 ----
# folder: 2018-05-28_124 : date- 2018-05-28 : patient_id- 124 ----
# folder: 2018-08-24_93B : date- 2018-08-24 : patient_id- 93B ----
# folder: 2018-08-06_156 : date- 2018-08-06 : patient_id- 156 ----
# folder: 2018-08-29_160 : date- 2018-08-29 : patient_id- 160 ----
# folder: 2018-08-13_157 : date- 2018-08-13 : patient_id- 157 ----
# folder: 2018-08-24_158 : date- 2018-08-24 : patient_id- 158 ----
# folder: 2018-08-31_162 : date- 2018-08-31 : patient_id- 162 ----
# folder: 2018-08-01_155 : date- 2018-08-01 : patient_id- 155 ----
# folder: 2018-08-29_161 : date- 2018-08-29 : patient_id- 161 ----
# folder: 2018-08-27_159_ : date- 2018-08-27 : patient_id- 159_ ----
# folder: 2018-10-03_173 : date- 2018-10-03 : patient_id- 173 ----
# folder: 2018-10-26_180 : date- 2018-10-26 : patient_id- 180 ----
# folder: 2018-10-19_140C : date- 2018-10-19 : patient_id- 140C ----
# folder: 2018-10-26_183 : date- 2018-10-26 : patient_id- 183 ----
# folder: 2018-10-05_174 : date- 2018-10-05 : patient_id- 174 ----
# folder: 2018-10-26_182 : date- 2018-10-26 : patient_id- 182 ----
# folder: 2018-10-22_178 : date- 2018-10-22 : patient_id- 178 ----
# folder: 2018-10-26_96b : date- 2018-10-26 : patient_id- 96b ----
# folder: 2018-10-29_184 : date- 2018-10-29 : patient_id- 184 ----
# folder: 2018-10-15_175 : date- 2018-10-15 : patient_id- 175 ----
# folder: 2018-10-24_179 : date- 2018-10-24 : patient_id- 179 ----
# folder: 2018-10-01_171 : date- 2018-10-01 : patient_id- 171 ----
# folder: 2018-10-05_118 : date- 2018-10-05 : patient_id- 118 ----
# folder: 2018-10-05_beigu_cc : date- 2018-10-05 : patient_id- beigu_cc ----
# folder: 2018-10-26_181 : date- 2018-10-26 : patient_id- 181 ----
# folder: 2018-10-01_172 : date- 2018-10-01 : patient_id- 172 ----
# folder: 2018-10-31_185 : date- 2018-10-31 : patient_id- 185 ----
# folder: 2018-10-15_176 : date- 2018-10-15 : patient_id- 176 ----
# folder: 2018-10-17_177 : date- 2018-10-17 : patient_id- 177 ----
# folder: 2019-10-25_300 : date- 2019-10-25 : patient_id- 300 ----
# folder: 2019-10-18_299 : date- 2019-10-18 : patient_id- 299 ----
# folder: 2019-10-25_301 : date- 2019-10-25 : patient_id- 301 ----
# folder: 2019-10-25_303 : date- 2019-10-25 : patient_id- 303 ----
# folder: 2019-10-28_275B : date- 2019-10-28 : patient_id- 275B ----
# folder: 2019-10-25_304 : date- 2019-10-25 : patient_id- 304 ----
# folder: 2019-10-25_302 : date- 2019-10-25 : patient_id- 302 ----
# folder: 2019-10-14_298 : date- 2019-10-14 : patient_id- 298 ----

# %%
len(full_rows_list)
# Out:
# 1089

# %%
df_loc = pd.DataFrame(full_rows_list)

# %%
df_loc.head(4)
# Out:
#    measurementId                  measurementSetId  measurementComment  \
# 0         2643.0  49e43a7cf5fcb6a1244253894db4adcd                 NaN
# 1         2642.0  90c6d827c611acfc47aa828b301ad9da                 NaN
# 2         2640.0  f22f8bbe78a2c8e8fe4562237890e1dd                 NaN
# 3         2641.0  0673de7e1c166d00b7c45b27ebfda5b2                 NaN
#
#   measurementDateCreated measurementDateFinished  receivedImagesCount  \
# 0    2019-07-22 11:16:21     2019-07-22 08:16:21                  4.0
# 1    2019-07-22 11:16:19     2019-07-22 08:16:19                 20.0
# 2    2019-07-22 11:15:17     2019-07-22 08:15:17                  4.0
# 3    2019-07-22 11:15:20     2019-07-22 08:15:20                 20.0
#
#    deviceId deviceName                                  images_paths_list  \
# 0       4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 1       4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 2       4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 3       4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
#
#          date patient_id lesion_id  is_uv_images
# 0  2019-07-22        272         5         False
# 1  2019-07-22        272         5          True
# 2  2019-07-22        272         4         False
# 3  2019-07-22        272         4          True

# %% [markdown]
# #### LOC UV images - selection of most sharp image (with least amount of blur -> largest variance_of_laplacian coeficient)

# %%
# BLUR DETECTION - in case one will need to find imagge with lowest blur (highest variance of laplacian)
def variance_of_laplacian(image):
    # compute the Laplacian of the image and then return the focus
    # measure, which is simply the variance of the Laplacian
    return cv2.Laplacian(image, cv2.CV_64F).var()

# %%
def get_best_uv_file_path(images_paths_list):
    
    max_var_of_laplacian = -1
    sharpest_image = None
    for img_path in images_paths_list:
        try:
            cv2_img = cv2.imread(img_path)
            var_of_laplacian = variance_of_laplacian(cv2_img)
            if var_of_laplacian > max_var_of_laplacian:
                sharpest_image = img_path
        except Exception as e:
            print('Error occured! img_path=', img_path, 'Exception:', e)
            
    return sharpest_image, max_var_of_laplacian

def find_best_uv_images_paths(df_loc):
    df_loc['best_uv_file_path'] = ""
    
    for i in tqdm_notebook(df_loc.index):
        if df_loc.at[i, 'is_uv_images']:
            best_uv_file_path, _ = get_best_uv_file_path(df_loc.at[i, 'images_paths_list'])
            df_loc.at[i, 'best_uv_file_path'] = best_uv_file_path
        else:
            df_loc.at[i, 'best_uv_file_path'] = None
            
# find_best_uv_images_paths(df_loc)

# %%
# df_loc.head(10)

# %% [markdown]
# #### Merge df_loc with LOC_ERAF2017_sakartots.xlsx - diagnoses for our images.

# %%
loc_eraf2017.rename(columns={'Pacienta nr': 'patient_id', 'Veidojuma Nr': 'lesion_id'}, inplace=True)

# %%
loc_eraf2017['patient_id'] = pd.to_numeric(loc_eraf2017['patient_id'], errors='coerce', downcast='signed')
loc_eraf2017['lesion_id'] = pd.to_numeric(loc_eraf2017['lesion_id'], errors='coerce', downcast='signed')

# %%
df_loc['patient_id'] = pd.to_numeric(df_loc['patient_id'], errors='coerce', downcast='signed')
df_loc['lesion_id'] = pd.to_numeric(df_loc['lesion_id'], errors='coerce', downcast='signed')

# %%
df_loc_merged = pd.merge(df_loc, loc_eraf2017, how='inner', on=['patient_id', 'lesion_id'])

# %%
# df_loc_merged.loc[df_loc_merged['patient_id'] == 272][['date', 'patient_id', 'lesion_id', 'is_uv_images', 'best_uv_file_path', 'Ārsta diagnoze', 'Kods']]

# %%
# print(list(df_loc_merged.columns))

# %%
df_loc_merged.shape
# Out:
# (1115, 40)

# %%
# pd.set_option('display.max_columns', None)  
# pd.set_option('display.expand_frame_repr', False)
# pd.set_option('max_colwidth', -1)
df_loc_merged.head(50)
# Out:
#     measurementId                  measurementSetId  measurementComment  \
# 0          2643.0  49e43a7cf5fcb6a1244253894db4adcd                 NaN
# 1          2642.0  90c6d827c611acfc47aa828b301ad9da                 NaN
# 2          2640.0  f22f8bbe78a2c8e8fe4562237890e1dd                 NaN
# 3          2641.0  0673de7e1c166d00b7c45b27ebfda5b2                 NaN
# 4          2644.0  a25e8d6028098a91fcc4021fe013d2a4                 NaN
# 5          2645.0  14e2128a8e5b1ece23ffb7fa717ef6d1                 NaN
# 6          2646.0  5ad9b8be49e6ccfc88ca6992e4231c03                 NaN
# 7          2647.0  58a0dcd251e806755a8ece46fbc8773d                 NaN
# 8          2639.0  acf2324b0fdeb2a46ed09d3e5b7f6e15                 NaN
4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 1        4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 2        4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 3        4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 4        4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 5        4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 6        4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 7        4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 8        4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 9        4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 10       4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 11       4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 12       4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 13       4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 14       4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 15       4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 16       4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 17       4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 18       4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 19       4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 20       4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 21       4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 22       4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 23       4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 24       4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 25       4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 26       4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 27       4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 28       4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 29       4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 30       4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 31       4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 32       4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 33       4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 34       4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 35       4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 36       4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 37       4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 38       4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 39       4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 40       4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 41       4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 42       4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 43       4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 44       4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 45       4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 46       4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 47       4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 48       4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
# 49       4.0        LOC  [/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/...
#
#           date  ...  Unnamed: 19  Unnamed: 20  Fototips  \
# 0   2019-07-22  ...          NaN          NaN       NaN
# 1   2019-07-22  ...          NaN          NaN       NaN
# 2   2019-07-22  ...          NaN          NaN       NaN
# 3   2019-07-22  ...          NaN          NaN       NaN
# 4   2019-07-22  ...          NaN          NaN       NaN
# 5   2019-07-22  ...          NaN          NaN       NaN
# 6   2019-07-22  ...          NaN          NaN       NaN
# 7   2019-07-22  ...          NaN          NaN       NaN
# 8   2019-07-22  ...          NaN          NaN       NaN
# 9   2019-07-22  ...          NaN          NaN       NaN
# 10  2019-07-22  ...          NaN          NaN       NaN
# 11  2019-07-22  ...          NaN          NaN       NaN
# 12  2019-07-22  ...          NaN          NaN       NaN
# 13  2019-07-22  ...          NaN          NaN       NaN
# 14  2019-07-17  ...          NaN          NaN       NaN
# 15  2019-07-17  ...          NaN          NaN       NaN
# 16  2019-07-17  ...          NaN          NaN       NaN
# 17  2019-07-17  ...          NaN          NaN       NaN
# 18  2019-07-26  ...          NaN          NaN       NaN
# 19  2019-07-26  ...          NaN          NaN       NaN
# 20  2019-07-03  ...          NaN          NaN       NaN
# 21  2019-07-03  ...          NaN          NaN       NaN
# 22  2019-07-03  ...          NaN          NaN       NaN
# 23  2019-07-03  ...          NaN          NaN       NaN
# 24  2019-07-03  ...          NaN          NaN       NaN
# 25  2019-07-03  ...          NaN          NaN       NaN
# 26  2019-07-03  ...          NaN          NaN       NaN
# 27  2019-07-03  ...          NaN          NaN       NaN
# 28  2019-07-03  ...          NaN          NaN       NaN
# 29  2019-07-03  ...          NaN          NaN       NaN
# 30  2019-07-03  ...          NaN          NaN       NaN
# 31  2019-07-03  ...          NaN          NaN       NaN
# 32  2019-07-03  ...          NaN          NaN       NaN
# 33  2019-07-03  ...          NaN          NaN       NaN
# 34  2019-07-03  ...          NaN          NaN       NaN
# 35  2019-07-03  ...          NaN          NaN       NaN
# 36  2019-07-24  ...          NaN          NaN       NaN
# 37  2019-07-24  ...          NaN          NaN       NaN
# 38  2019-07-24  ...          NaN          NaN       NaN
# 39  2019-07-24  ...          NaN          NaN       NaN
# 40  2019-07-24  ...          NaN          NaN       NaN
# 41  2019-07-24  ...          NaN          NaN       NaN
# 42  2019-07-24  ...          NaN          NaN       NaN
# 43  2019-07-24  ...          NaN          NaN       NaN
# 44  2019-07-10  ...          NaN          NaN       NaN
# 45  2019-07-10  ...          NaN          NaN       NaN
# 46  2019-07-10  ...          NaN          NaN       NaN
# 47  2019-07-10  ...          NaN          NaN       NaN
# 48  2019-07-10  ...          NaN          NaN       NaN
# 49  2019-07-10  ...          NaN          NaN       NaN
#
#    Veidojuma izmērs: GarumsxPlatumsxAugstums, mm Unnamed: 23  \
# 0                                            NaN         NaN
# 1                                            NaN         NaN
# 2                                            NaN         NaN
# 3                                            NaN         NaN
# 4                                            NaN         NaN
# 5                                            NaN         NaN
# 6                                            NaN         NaN
# 7                                            NaN         NaN
# 8                                            NaN         NaN
# 9                                            NaN         NaN
# 10                                           NaN         NaN
# 11                                           NaN         NaN
# 12                                           NaN         NaN
# 13                                           NaN         NaN
# 14                                           NaN         NaN
# 15                                           NaN         NaN
# 16                                           NaN         NaN
# 17                                           NaN         NaN
# 18                                           NaN         NaN
# 19                                           NaN         NaN
# 20                                           NaN         NaN
# 21                                           NaN         NaN
# 22                                           NaN         NaN
# 23                                           NaN         NaN
# 24                                           NaN         NaN
# 25                                           NaN         NaN
# 26                                           NaN         NaN
# 27                                           NaN         NaN
# 28                                           NaN         NaN
# 29                                           NaN         NaN
# 30                                           NaN         NaN
# 31                                           NaN         NaN
# 32                                           NaN         NaN
# 33                                           NaN         NaN
# 34                                           NaN         NaN
# 35                                           NaN         NaN
# 36                                           NaN         NaN
# 37                                           NaN         NaN
# 38                                           NaN         NaN
# 39                                           NaN         NaN
# 40                                           NaN         NaN
# 41                                           NaN         NaN
# 42                                           NaN         NaN
# 43                                           NaN         NaN
# 44                                           NaN         NaN
# 45                                           NaN         NaN
# 46                                           NaN         NaN
# 47                                           NaN         NaN
# 48                                           NaN         NaN
# 49                                           NaN         NaN
#
#    Izmeklējuma veids (d-dermaskopija; s- siaskopija) Apzīmējumi: updated info  \
# 0                                                NaN         NaN          NaN
# 1                                                NaN         NaN          NaN
# 2                                                NaN         NaN          NaN
# 3                                                NaN         NaN          NaN
# 4                                                NaN         NaN          NaN
# 5                                                NaN         NaN          NaN
# 6                                                NaN         NaN          NaN
# 7                                                NaN         NaN          NaN
# 8                                                NaN         NaN          NaN
# 9                                                NaN         NaN          NaN
# 10                                               NaN         NaN          NaN
# 11                                               NaN         NaN          NaN
# 12                                               NaN         NaN          NaN
# 13                                               NaN         NaN          NaN
# 14                                               NaN         NaN          NaN
# 15                                               NaN         NaN          NaN
# 16                                               NaN         NaN          NaN
# 17                                               NaN         NaN          NaN
# 18                                               NaN         NaN          NaN
# 19                                               NaN         NaN          NaN
# 20                                               NaN         NaN          NaN
# 21                                               NaN         NaN          NaN
# 22                                               NaN         NaN          NaN
# 23                                               NaN         NaN          NaN
# 24                                               NaN         NaN          NaN
# 25                                               NaN         NaN          NaN
# 26                                               NaN         NaN          NaN
# 27                                               NaN         NaN          NaN
# 28                                               NaN         NaN          NaN
# 29                                               NaN         NaN          NaN
# 30                                               NaN         NaN          NaN
# 31                                               NaN         NaN          NaN
# 32                                               NaN         NaN          NaN
# 33                                               NaN         NaN          NaN
# 34                                               NaN         NaN          NaN
# 35                                               NaN         NaN          NaN
# 36                                               NaN         NaN          NaN
# 37                                               NaN         NaN          NaN
# 38                                               NaN         NaN          NaN
# 39                                               NaN         NaN          NaN
# 40                                               NaN         NaN          NaN
# 41                                               NaN         NaN          NaN
# 42                                               NaN         NaN          NaN
# 43                                               NaN         NaN          NaN
# 44                                               NaN         NaN          NaN
# 45                                               NaN         NaN          NaN
# 46                                               NaN         NaN          NaN
# 47                                               NaN         NaN          NaN
# 48                                               NaN         NaN          NaN
# 49                                               NaN         NaN          NaN
#
#    pārbaudīt analīzes C43
# 0                 NaN NaN
# 1                 NaN NaN
# 2                 NaN NaN
# 3                 NaN NaN
# 4                 NaN NaN
# 5                 NaN NaN
# 6                 NaN NaN
# 7                 NaN NaN
# 8                 NaN NaN
# 9                 NaN NaN
# 10                NaN NaN
# 11                NaN NaN
# 12                NaN NaN
# 13                NaN NaN
# 14                NaN NaN
# 15                NaN NaN
# 16                NaN NaN
# 17                NaN NaN
# 18                NaN NaN
# 19                NaN NaN
# 20                NaN NaN
# 21                NaN NaN
# 22                NaN NaN
# 23                NaN NaN
# 24                NaN NaN
# 25                NaN NaN
# 26                NaN NaN
# 27                NaN NaN
# 28                NaN NaN
# 29                NaN NaN
# 30                NaN NaN
# 31                NaN NaN
# 32                NaN NaN
# 33                NaN NaN
# 34                NaN NaN
# 35                NaN NaN
# 36                NaN NaN
# 37                NaN NaN
# 38                NaN NaN
# 39                NaN NaN
# 40                NaN NaN
# 41                NaN NaN
# 42                NaN NaN
# 43                NaN NaN
# 44                NaN NaN
# 45                NaN NaN
# 46                NaN NaN
# 47                NaN NaN
# 48                NaN NaN
# 49                NaN NaN
#
# [50 rows x 40 columns]

# %% [markdown]
# These 1115 images - should be divided by 2 to get real number of cases (because we have two records R/IR/G + UV for each case)

# %% [markdown]
# In addition in the old LOC pre-"2019-04" data - there are some melanomas. We would like to manually cherrypick them and include in our dataset.

# %% [markdown]
# ## Checkyourskin images

# %%
melanoma_folder = os.path.abspath(os.path.join(os.getcwd(), '..', '..', 'data', 'raw', '_melanoma'))

checkyourskin_folder =  os.path.join(melanoma_folder, 'Checkyourskin')
print(checkyourskin_folder)
# Out:
# /mnt/data/raw/_melanoma/Checkyourskin

# %%
def collect_images_cys(tar_folder_path: str):
    images_paths_list = []
    in_folder_path = os.path.join(tar_folder_path, 'in')
    
    uv_images = False
    if os.path.exists(in_folder_path):
        for in_folder_file in os.listdir(in_folder_path):
            img_file = os.path.join(in_folder_path, in_folder_file)
            if os.path.isfile(img_file):
                if '.png' in in_folder_file or '.jpg' in in_folder_file or '.jpeg' in in_folder_file or '.tiff' in in_folder_file:
                    
                    images_paths_list.append(img_file)
                    if uv_images == False and (not in_folder_file.startswith('R') or not in_folder_file.startswith('IR') or not in_folder_file.startswith('G')):
                        uv_images = True
                        
#                     print('Image found:', in_folder_file)
                else:
#                     print('Skipping file: ', in_folder_file)
                    pass
            else:
#                 print('Found folder in "in" subfolder: ', in_folder_path, in_folder_file)
                pass
    else:
#         print('"in" Folder not exists!', in_folder_path)
        pass
        
    return images_paths_list, uv_images

def process_tar_folder_cys(tar_folder_path: str, patient_id: str):
#     print('process_tar_folder_cys', tar_folder_path)
    
    # We assume that above level contains "lesion_id"
    parent_folder_path = Path(tar_folder_path).parent
#     print('parent_folder_path', parent_folder_path)
    lesion_id = parent_folder_path.name
    
    metadata_json = load_metadata_csv(tar_folder_path)
    images_paths_list, is_uv_images = collect_images_cys(tar_folder_path)
    metadata_json['images_paths_list'] = images_paths_list
    metadata_json['patient_id'] = patient_id
    metadata_json['lesion_id'] = lesion_id
    metadata_json['is_uv_images'] = is_uv_images
    return [metadata_json]

def process_cys_root_folder(_folder: str):
    full_rows_list = []
    for patient_id_folder in tqdm_notebook(os.listdir(_folder)):
#         print(patient_id_folder)
        patient_id_folder_path = os.path.join(_folder, patient_id_folder)
        if os.path.isdir(patient_id_folder_path):
            patient_id = patient_id_folder
#             print('folder:', patient_id_folder_path, ': patient_id-', patient_id, '----')
            rows_list = process_tar_folder_cys(patient_id_folder_path, patient_id)
            full_rows_list.extend(rows_list)
    return full_rows_list

# %%
checkyourskin_folder
# Out:
# '/mnt/data/raw/_melanoma/Checkyourskin'

# %%
full_rows_list_cys = process_cys_root_folder(checkyourskin_folder)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:47: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=2464.0), HTML(value='')))

# %%
# full_rows_list_cys[0:10]

# %%
df_cys = pd.DataFrame(full_rows_list_cys)

# %%
df_cys.head(5)
# Out:
#    measurementId                  measurementSetId measurementComment  \
# 0           1685  2049752a10138492ccf5e46dbea078ff                NaN
# 1           3753  593e38ee6500a5f8ad36390293e94351                NaN
# 2           1367  06634b2a1ff268294a25f1d5e3408746                NaN
# 3            309  30f589534eed314b2bdbcd41925ab015                NaN
# 4           2162  aace78ffb3981205230d53632804c270                NaN
#
#   measurementDateCreated measurementDateFinished  receivedImagesCount  \
# 0    2019-03-29 12:55:16     2019-03-29 10:55:16                   20
# 1    2019-12-06 10:15:07     2019-12-06 08:15:07                    4
# 2    2019-03-05 13:10:10     2019-03-05 11:10:10                   10
# 3    2018-12-12 18:42:29     2018-12-12 16:42:29                    3
# 4    2019-05-17 20:18:47     2019-05-17 17:18:47                    3
#
#    deviceId deviceName                                  images_paths_list  \
# 0         4        LOC  [/mnt/data/raw/_melanoma/Checkyourskin/1685/in...
# 1         4        LOC  [/mnt/data/raw/_melanoma/Checkyourskin/3753/in...
# 2         2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/1367/in...
# 3         2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/309/in/...
# 4         4        LOC  [/mnt/data/raw/_melanoma/Checkyourskin/2162/in...
#
#   patient_id      lesion_id  is_uv_images  analyzeId  numberInSequence  \
# 0       1685  Checkyourskin          True        NaN               NaN
# 1       3753  Checkyourskin          True        NaN               NaN
# 2       1367  Checkyourskin          True      522.0               1.0
# 3        309  Checkyourskin          True      149.0               9.0
# 4       2162  Checkyourskin          True        NaN               NaN
#
#     analyzeDateCreated  analyzePatientId  analyzeScannedBodyPartId  \
# 0                  NaN               NaN                       NaN
# 1                  NaN               NaN                       NaN
# 2  2019-03-05 13:16:02             170.0                      16.0
# 3  2019-01-22 09:53:25              59.0                       5.0
# 4                  NaN               NaN                       NaN
#
#                           analyzeDoctorComment analyzeDiagnosisComment
# 0                                          NaN                     NaN
# 1                                          NaN                     NaN
# 2  solar keratosis, right side of the forehead                     NaN
# 3                    test pictures from Latvia                     NaN
# 4                                          NaN                     NaN

# %%
# Save this dataframe to CSV file
df_cys.to_csv('/mnt/df_checkyrskin.csv', index=False)

# %%
# df_cys.loc[df_cys['analyzeDoctorComment']=='pigmented basalioma'].head(50)

# %%
loc_df_checkyrskin_2020_07_28.head()
# Out:
#    patient_id  measurementId                  measurementSetId  \
# 0        1685           1685  2049752a10138492ccf5e46dbea078ff
# 1        3753           3753  593e38ee6500a5f8ad36390293e94351
# 2        1367           1367  06634b2a1ff268294a25f1d5e3408746
# 3         309            309  30f589534eed314b2bdbcd41925ab015
# 4        2162           2162  aace78ffb3981205230d53632804c270
#
#   measurementComment measurementDateCreated measurementDateFinished  \
# 0                NaN    2019-03-29 12:55:16     2019-03-29 10:55:16
# 1                NaN    2019-12-06 10:15:07     2019-12-06 08:15:07
# 2                NaN    2019-03-05 13:10:10     2019-03-05 11:10:10
# 3                NaN    2018-12-12 18:42:29     2018-12-12 16:42:29
# 4                NaN    2019-05-17 20:18:47     2019-05-17 17:18:47
#
#    receivedImagesCount  deviceId deviceName  \
# 0                   20         4        LOC
# 1                    4         4        LOC
# 2                   10         2    Hungary
# 3                    3         2    Hungary
# 4                    3         4        LOC
#
#                                    images_paths_list  ... is_uv_images  \
# 0  ['/mnt/data/raw/_melanoma/Checkyourskin/1685/i...  ...         True
# 1  ['/mnt/data/raw/_melanoma/Checkyourskin/3753/i...  ...         True
# 2  ['/mnt/data/raw/_melanoma/Checkyourskin/1367/i...  ...         True
# 3  ['/mnt/data/raw/_melanoma/Checkyourskin/309/in...  ...         True
# 4  ['/mnt/data/raw/_melanoma/Checkyourskin/2162/i...  ...         True
#
#    analyzeId  numberInSequence  analyzeDateCreated analyzePatientId  \
# 0        NaN               NaN                 NaT              NaN
# 1        NaN               NaN                 NaT              NaN
# 2      522.0               1.0 2019-03-05 13:16:02            170.0
# 3      149.0               9.0 2019-01-22 09:53:25             59.0
# 4        NaN               NaN                 NaT              NaN
#
#    analyzeScannedBodyPartId                         analyzeDoctorComment  \
# 0                       NaN                                          NaN
# 1                       NaN                                          NaN
# 2                      16.0  solar keratosis, right side of the forehead
# 3                       5.0                    test pictures from Latvia
# 4                       NaN                                          NaN
#
#   analyzeDiagnosisComment LesionCode           Paskaidrojums
# 0                     NaN        NaN                     NaN
# 1                     NaN        NaN                     NaN
# 2                     NaN        L57  jeb aktīniskā keratoze
# 3                     NaN        NaN            testa bildes
# 4                     NaN        NaN                     NaN
#
# [5 rows x 21 columns]

# %%
# let us filter out LOC records
df_cys = df_cys.loc[df_cys['deviceName'] != 'LOC']

# %%
df_cys.shape
# Out:
# (971, 19)

# %%
def add_diagnose_codes(loc_df_checkyrskin_2020_07_28, df_cys):
    """
    get codes from loc_df_checkyrskin_2020_07_28 and put them into df_cys using comment as a matching thing
    """
    df_with_codes = loc_df_checkyrskin_2020_07_28.copy(deep=True)
    df_with_codes.dropna(subset = ['LesionCode'], inplace=True)
    df_with_codes = df_with_codes[~df_with_codes['LesionCode'].str.contains(',')]
    df_with_codes = df_with_codes[~df_with_codes['LesionCode'].str.contains('\?')]
    df_with_codes = df_with_codes[['analyzeId', 'LesionCode']]
    
    df_cys = df_cys.copy(deep=True)
    df_cys = df_cys.merge(df_with_codes, how='left', left_on='analyzeId', right_on='analyzeId')
    df_cys['code'] = df_cys['LesionCode']
    return df_cys
    
df_cys = add_diagnose_codes(loc_df_checkyrskin_2020_07_28, df_cys)

# %%
# drop rows with NaN codes
# df_cys = df_cys.dropna(subset = ['code'])

# %%
df_cys.head(15)
# Out:
#     measurementId                  measurementSetId measurementComment  \
# 0            1367  06634b2a1ff268294a25f1d5e3408746                NaN
# 1             309  30f589534eed314b2bdbcd41925ab015                NaN
# 2            1713  b20d87df92adf96f2503bb3d57b9ce18                NaN
# 3             345  34df6a8d8b378471d7852a7c2b2c0430                NaN
# 4            1394  94da4f751a78642a4fa299ecfa3b6bae                NaN
# 5            1729  a0bfd1f50d93ca9c75711b1492fd911b                NaN
# 6            1835  1cc0150b7e91da704fd6eb50998a7e4c                NaN
# 7             673  49da338725a504723b7b8ce535d41508                NaN
# 8            1709  1c0604df88c244e30f51d6bbaea08e51                NaN
# 9            1314  6a647e07187594bc5b40990d47c651d3                NaN
# 10           1782  00e2bac5507d44c25ca7b912f679e84e                NaN
# 11           1540  186163893ec32be23e5d0b99d888872b                NaN
# 12           1831  585d9bfe0bdff6f901f1529e80c1f2f4                NaN
# 13           1951  4f90ffa1e1fd275f1fa76969b47a8e35                NaN
# 14           1131  5584912da0320e800d937a444c3da06c                NaN
#
#    measurementDateCreated measurementDateFinished  receivedImagesCount  \
# 0     2019-03-05 13:10:10     2019-03-05 11:10:10                   10
# 1     2018-12-12 18:42:29     2018-12-12 16:42:29                    3
# 2     2019-04-01 11:48:31     2019-04-01 08:48:31                   10
# 3     2018-12-17 14:05:25     2018-12-17 12:05:25                    3
# 4     2019-03-07 13:42:29     2019-03-07 11:42:29                    3
# 5     2019-04-02 10:36:42     2019-04-02 07:36:42                   10
# 6     2019-04-08 13:10:10     2019-04-08 10:10:10                   10
# 7     2019-01-21 14:08:44     2019-01-21 12:08:44                    3
# 8     2019-04-01 11:15:47     2019-04-01 08:15:47                   10
# 9     2019-02-26 12:19:24     2019-02-26 10:19:24                    3
# 10    2019-04-08 11:48:40     2019-04-08 08:48:40                    3
# 11    2019-03-20 12:44:49     2019-03-20 10:44:49                    3
# 12    2019-04-08 13:07:16     2019-04-08 10:07:16                   10
# 13    2019-04-17 12:33:40     2019-04-17 09:33:40                   10
# 14    2019-02-12 12:25:57     2019-02-12 10:25:57                   10
#
#     deviceId deviceName                                  images_paths_list  \
# 0          2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/1367/in...
# 1          2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/309/in/...
# 2          2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/1713/in...
# 3          2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/345/in/...
# 4          2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/1394/in...
# 5          2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/1729/in...
# 6          2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/1835/in...
# 7          2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/673/in/...
# 8          2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/1709/in...
# 9          2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/1314/in...
# 10         2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/1782/in...
# 11         2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/1540/in...
# 12         2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/1831/in...
# 13         2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/1951/in...
# 14         2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/1131/in...
#
#    patient_id  ... is_uv_images  analyzeId  numberInSequence  \
# 0        1367  ...         True      522.0               1.0
# 1         309  ...         True      149.0               9.0
# 2        1713  ...         True      741.0               1.0
# 3         345  ...         True      149.0              32.0
# 4        1394  ...         True      550.0               1.0
# 5        1729  ...         True      759.0               1.0
# 6        1835  ...         True      841.0               1.0
# 7         673  ...         True      154.0              21.0
# 8        1709  ...         True      738.0               1.0
# 9        1314  ...         True      469.0               1.0
# 10       1782  ...         True      772.0               1.0
# 11       1540  ...         True      631.0               1.0
# 12       1831  ...         True      837.0               1.0
# 13       1951  ...         True      933.0               1.0
# 14       1131  ...         True      405.0               1.0
#
#      analyzeDateCreated analyzePatientId  analyzeScannedBodyPartId  \
# 0   2019-03-05 13:16:02            170.0                      16.0
# 1   2019-01-22 09:53:25             59.0                       5.0
# 2   2019-04-01 11:50:46            211.0                      26.0
# 3   2019-01-22 09:53:25             59.0                       5.0
# 4   2019-03-07 14:47:34            175.0                      27.0
# 5   2019-04-02 10:48:19            214.0                      68.0
# 6   2019-04-08 13:10:24            217.0                      27.0
# 7   2019-01-22 10:41:20             60.0                       2.0
# 8   2019-04-01 11:27:47            209.0                      25.0
# 9   2019-02-26 13:21:07            153.0                     232.0
# 10  2019-04-08 12:11:55            215.0                      23.0
# 11  2019-03-20 13:24:11            187.0                      17.0
# 12  2019-04-08 13:07:35            217.0                      68.0
# 13  2019-04-17 12:43:04            236.0                      72.0
# 14  2019-02-12 14:53:39            128.0                      44.0
#
#                                  analyzeDoctorComment analyzeDiagnosisComment  \
# 0         solar keratosis, right side of the forehead                     NaN
# 1                           test pictures from Latvia                     NaN
# 2              dysplastic naevus on the left shoulder                     NaN
# 3                           test pictures from Latvia                     NaN
# 4                               pxe, axillar, lateral                     NaN
# 5                                              BCC 9h                     NaN
# 6                                        pxe, axillar                     NaN
# 7                                                 NaN                     NaN
# 8                                 pigmented basalioma                     NaN
# 9   left side of the trunk,ulcerated melanoma mali...                     NaN
# 10                 PXE, right shoulder, anterior part                     NaN
# 11                               basalioma, left face                     NaN
# 12                                  pxe, trunk, lower                     NaN
# 13                                 scc? mm? posterior                     NaN
# 14    melanoma malignum/ dyspl. naevus ? on right leg                     NaN
#
#    LesionCode code
# 0         L57  L57
# 1         NaN  NaN
# 2         D48  D48
# 3         NaN  NaN
# 4         PXE  PXE
# 5         C44  C44
# 6         PXE  PXE
# 7         NaN  NaN
# 8         C44  C44
# 9         C43  C43
# 10        PXE  PXE
# 11        C44  C44
# 12        PXE  PXE
# 13        NaN  NaN
# 14        NaN  NaN
#
# [15 rows x 21 columns]

# %% [markdown]
# # Files copying

# %% [markdown]
# Target file structure:
#     DiagnozeCode1/R/*.png
#     DiagnozeCode1/IR/*.png
#     DiagnozeCode1/G/*.png
#     DiagnozeCode1/UV/*.png
#     DiagnozeCode1/UV/*.png
#     DiagnozeCode1/metadata.txt
#
# metadata.txt contains table:
#
#     measurementSetId                 | folder
#     -------------------------------------------
#     6a647e07187594bc5b40990d47c651d3 | R
#     6a647e07187594bc5b40990d47c651d3 | IR
#     6a647e07187594bc5b40990d47c651d3 | G
#     186163893ec32be23e5d0b99d888872b | UV

# %% [markdown]
# ### LOC files processing according to df_loc_merged copying

# %%
# Must be ZERO! records.
df_loc_merged.loc[df_loc_merged['Kods'] == None]
# Out:
# Empty DataFrame
# Columns: [measurementId, measurementSetId, measurementComment, measurementDateCreated, measurementDateFinished, receivedImagesCount, deviceId, deviceName, images_paths_list, date, patient_id, lesion_id, is_uv_images, Ārsta diagnoze, Kods, Statuss, Dzimums (s- sieviete, v- vīrietis), Dzimšanas gads, Vecums mērīšanas brīdī, gadi, Lokalizācija, Piezīmes, Vizītes Datums, Histoloģijas atbilde (diagnozes kods), Breslow dziļums, mm, Clark, Stadija, TNM, Histoloģija, Citoloģija, Piezīmes.1, Unnamed: 19, Unnamed: 20, Fototips, Veidojuma izmērs: GarumsxPlatumsxAugstums, mm, Unnamed: 23, Izmeklējuma veids (d-dermaskopija; s- siaskopija), Apzīmējumi:, updated info, pārbaudīt analīzes, C43]
# Index: []
#
# [0 rows x 40 columns]

# %%
df_loc.dtypes
# Out:
# measurementId              float64
# measurementSetId            object
# measurementComment         float64
# measurementDateCreated      object
# measurementDateFinished     object
# receivedImagesCount        float64
# deviceId                   float64
# deviceName                  object
# images_paths_list           object
# date                        object
# patient_id                 float64
# lesion_id                  float64
# is_uv_images                  bool
# dtype: object

# %%
def collect_grouped_file_paths(df_loc):
    
    from datetime import datetime
    date_time_format = '%Y-%m-%d %H:%M:%S'
    
    root_folders = dict()
    
    def __extract_rgir_uv_files_paths(files_list):
        d = dict()
        for f_path in files_list:
            f = os.path.basename(f_path)
            if f.lower().startswith('r'):
                d['r'] = f_path
            elif f.lower().startswith('ir'):
                d['ir'] = f_path
            elif f.lower().startswith('g'):
                d['g'] = f_path
            elif f.lower().startswith('white'):
                d['white'] = f_path
            elif f.lower().startswith('uv') or f[0].isdigit():
                if 'uv' not in d:
                    d['uv'] = []
                d['uv'].append(f_path)
            else:
                print('unknown file type (R/IR/G/UV/White):', f)
        return d

#     def __extract_non_uv_files_paths(files_list):
#         d = dict()
#         for f_path in files_list:
#             f = os.path.basename(f_path)
#             if f.startswith('R'):
#                 d['r'] = f_path
#             elif f.startswith('IR'):
#                 d['ir'] = f_path
#             elif f.startswith('G'):
#                 d['g'] = f_path
#             elif f.startswith('White'):
#                 d['white'] = f_path
#             else:
#                 print('unknown file type (R/IR/G):', f)
#         return d

    for index, row in df_loc.iterrows():
        orig_parent_folder = None
        is_uv = False
        if True == row['is_uv_images']:
            files_paths = row['images_paths_list']  #row['best_uv_file_path']
            orig_parent_folder = Path(Path(Path(files_paths[0]).parent).parent).parent
            is_uv = True
        else:
            if len(row['images_paths_list']) == 0:
                print('Empty images list!!! row=[{}]'.format(row))
                print('--'*20)
                continue
            else:
                file_path = row['images_paths_list'][0]
                orig_parent_folder = Path(Path(Path(file_path).parent).parent).parent

        if not orig_parent_folder in root_folders:
            root_folders[orig_parent_folder]= {'codes': []}
        
        if type(row['Kods']) is str:  # This will skip 'nan' & 'None'
            root_folders[orig_parent_folder]['codes'].append(row['Kods'])
        
        images_paths_dict = __extract_rgir_uv_files_paths(row['images_paths_list'])
        if 'uv' in images_paths_dict:
            root_folders[orig_parent_folder].update(**images_paths_dict, **{'uv_corr_id': row['measurementSetId']})
        else:
            root_folders[orig_parent_folder].update(**images_paths_dict, **{'non_uv_corr_id': row['measurementSetId']})
            
        created_date = datetime.strptime(row['measurementDateCreated'], date_time_format)  # sample datetime '2019-04-01 11:15:47'
        if datetime not in root_folders[orig_parent_folder]:
            root_folders[orig_parent_folder].update(**{'datetime': created_date.strftime(date_time_format)})
        else:
            root_folders[orig_parent_folder]['datetime'] = min(datetime.strptime(root_folders[orig_parent_folder]['datetime'], date_time_format), created_date).strftime(date_time_format)
#         if is_uv:
#             root_folders[orig_parent_folder].update(**{'uv': row['best_uv_file_path'], 'uv_corr_id': row['measurementSetId']})
#         else:
#             root_folders[orig_parent_folder].update(**__extract_non_uv_files_paths(row['images_paths_list']), **{'non_uv_corr_id': row['measurementSetId']})
        
    return root_folders

# %%
root_folders = collect_grouped_file_paths(df_loc_merged)
# Out:
# Empty images list!!! row=[measurementId                                                                        NaN
# measurementSetId                                                                     NaN
# measurementComment                                                                   NaN
# measurementDateCreated                                                               NaN
# measurementDateFinished                                                              NaN
# receivedImagesCount                                                                  NaN
# deviceId                                                                             NaN
# deviceName                                                                           NaN
# images_paths_list                                                                     []
# date                                                                          2019-10-28
# patient_id                                                                           NaN
# lesion_id                                                                            NaN
# is_uv_images                                                                       False
# Ārsta diagnoze                                       Rb, rēta pēc bazaliomas, ķirurģiska
# Kods                                                                                  Rb
# Statuss                                                                              NaN
# Dzimums (s- sieviete, v- vīrietis)                                                   NaN
# Dzimšanas gads                                                                       NaN
# Vecums mērīšanas brīdī, gadi                                                         NaN
# Lokalizācija                                                       dibena kreisais vaigs
# Piezīmes                                                Operācija bija 2018.gada 7.martā
# Vizītes Datums                                                                  15.06.18
# Histoloģijas atbilde (diagnozes kods)                                                NaN
# Breslow dziļums, mm                                                                  NaN
# Clark                                                                                NaN
# Stadija                                                                              NaN
# TNM                                                                                  NaN
# Histoloģija                                                                          NaN
# Citoloģija                                                                           NaN
# Piezīmes.1                                                                           NaN
# Unnamed: 19                                                                          NaN
# Unnamed: 20                                                                          NaN
# Fototips                                                                             NaN
# Veidojuma izmērs: GarumsxPlatumsxAugstums, mm                                        NaN
# Unnamed: 23                                                                          NaN
# Izmeklējuma veids (d-dermaskopija; s- siaskopija)                                    NaN
# Apzīmējumi:                                                                          NaN
# updated info                                                                         NaN
# pārbaudīt analīzes                                                                   NaN
# C43                                                                                  NaN
# Name: 320, dtype: object]
# ----------------------------------------
# Empty images list!!! row=[measurementId                                               NaN
# measurementSetId                                            NaN
# measurementComment                                          NaN
# measurementDateCreated                                      NaN
# measurementDateFinished                                     NaN
# receivedImagesCount                                         NaN
# deviceId                                                    NaN
# deviceName                                                  NaN
# images_paths_list                                            []
# date                                                 2019-10-28
# patient_id                                                  NaN
# lesion_id                                                   NaN
# is_uv_images                                              False
# Ārsta diagnoze                                              NaN
# Kods                                                        NaN
# Statuss                                                     NaN
# Dzimums (s- sieviete, v- vīrietis)                          NaN
# Dzimšanas gads                                              NaN
# Vecums mērīšanas brīdī, gadi                                NaN
# Lokalizācija                                                NaN
# Piezīmes                                                    NaN
# Vizītes Datums                                         24.04.18
# Histoloģijas atbilde (diagnozes kods)                       NaN
# Breslow dziļums, mm                                         NaN
# Clark                                                       NaN
# Stadija                                                     NaN
# TNM                                                         NaN
# Histoloģija                                                 NaN
# Citoloģija                                                  NaN
# Piezīmes.1                                                  NaN
# Unnamed: 19                                                 NaN
# Unnamed: 20                                                 NaN
# Fototips                                                    NaN
# Veidojuma izmērs: GarumsxPlatumsxAugstums, mm               NaN
# Unnamed: 23                                                 NaN
# Izmeklējuma veids (d-dermaskopija; s- siaskopija)           NaN
# Apzīmējumi:                                                 NaN
# updated info                                                NaN
# pārbaudīt analīzes                                          NaN
# C43                                                         NaN
# Name: 321, dtype: object]
# ----------------------------------------

# %%
len(root_folders)
# Out:
# 493

# %%
key = Path('/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/2019-07-22_272/5')
value = root_folders[key]
print(key, '->', value)
# Out:
# /mnt/data/raw/_melanoma/Merijumi LOC/2019_07/2019-07-22_272/5 -> {'codes': ['D48', 'D48'], 'r': '/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/2019-07-22_272/5/2643.tar/in/R_1ms.png', 'white': '/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/2019-07-22_272/5/2643.tar/in/White_6ms.png', 'g': '/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/2019-07-22_272/5/2643.tar/in/G_6ms.png', 'ir': '/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/2019-07-22_272/5/2643.tar/in/IR_3ms.png', 'non_uv_corr_id': '49e43a7cf5fcb6a1244253894db4adcd', 'datetime': '2019-07-22 11:16:19', 'uv': ['/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/2019-07-22_272/5/2642.tar/in/UV25_180ms.png', '/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/2019-07-22_272/5/2642.tar/in/UV15_180ms.png', '/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/2019-07-22_272/5/2642.tar/in/UV16_180ms.png', '/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/2019-07-22_272/5/2642.tar/in/UV19_180ms.png', '/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/2019-07-22_272/5/2642.tar/in/UV22_180ms.png', '/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/2019-07-22_272/5/2642.tar/in/UV27_180ms.png', '/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/2019-07-22_272/5/2642.tar/in/UV13_180ms.png', '/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/2019-07-22_272/5/2642.tar/in/UV12_180ms.png', '/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/2019-07-22_272/5/2642.tar/in/UV17_180ms.png', '/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/2019-07-22_272/5/2642.tar/in/UV11_180ms.png', '/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/2019-07-22_272/5/2642.tar/in/UV10_180ms.png', '/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/2019-07-22_272/5/2642.tar/in/UV21_180ms.png', '/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/2019-07-22_272/5/2642.tar/in/UV26_180ms.png', '/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/2019-07-22_272/5/2642.tar/in/UV29_180ms.png', '/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/2019-07-22_272/5/2642.tar/in/UV23_180ms.png', '/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/2019-07-22_272/5/2642.tar/in/UV18_180ms.png', '/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/2019-07-22_272/5/2642.tar/in/UV20_180ms.png', '/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/2019-07-22_272/5/2642.tar/in/UV14_180ms.png', '/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/2019-07-22_272/5/2642.tar/in/UV24_180ms.png', '/mnt/data/raw/_melanoma/Merijumi LOC/2019_07/2019-07-22_272/5/2642.tar/in/UV28_180ms.png'], 'uv_corr_id': '90c6d827c611acfc47aa828b301ad9da'}

# %%
for k, v in root_folders.items():
    vv = v['codes']
    if (len(set(vv)) > 1):
        print(k, '->', set(vv))

# %% [markdown]
# Now we have dictionary with:
# - code (there are lists, but previous cell printed nothing, thus lists contain single unique code)
# - and paths to image files (r, g, ir, uv, white)
# - uv_corr_id - measurmentId
# - non_uv_corr_id - measurementId
#
# Let's copy files :)

# %%
target_loc_img_folder = os.path.abspath('../../data/interim/_melanoma_20200728/loc')
target_loc_img_folder
# Out:
# '/mnt/data/interim/_melanoma_20200728/loc'

# %%
import uuid
import shutil
import os
from datetime import datetime

for k, v in root_folders.items():
    if len(v['codes']) == 0:
        code = 'benign'
    else:
        code = v['codes'][0].strip()
        
    src_r_path = v['r']
    src_ir_path = v['ir']
    src_g_path = v['g']
    folders_list = ['r', 'ir', 'g']
    measurements_list = [v['non_uv_corr_id'], v['non_uv_corr_id'], v['non_uv_corr_id']]
    if 'white' in v:
        src_white_path = v['white']
        folders_list.append('white')
        measurements_list.append(v['non_uv_corr_id'])
    else:
        src_white_path = None
        
    if 'uv' in v:
        src_uv_paths = v['uv']
        folders_list.append('uv')
        measurements_list.append(v['uv_corr_id'])
    else:
        src_uv_paths = None
    
    if src_white_path is None:
        print('White is missing!!!')
    if src_uv_paths is None:
        print('UV is missing!!!') 
    
    creation_date_time = v['datetime']
    last_folder = datetime.strptime(creation_date_time, '%Y-%m-%d %H:%M:%S').strftime('%Y-%m-%d_%H-%M-%S')
    target_parent_folder = os.path.join(target_loc_img_folder, code, last_folder)

    # prepare folders
    os.makedirs(os.path.join(target_parent_folder, 'r'))
    os.makedirs(os.path.join(target_parent_folder, 'ir'))
    os.makedirs(os.path.join(target_parent_folder, 'g'))

    shutil.copy(src_r_path, os.path.join(target_parent_folder, 'r', os.path.basename(src_r_path)))
    shutil.copy(src_ir_path, os.path.join(target_parent_folder, 'ir', os.path.basename(src_ir_path)))
    shutil.copy(src_g_path, os.path.join(target_parent_folder, 'g', os.path.basename(src_g_path)))
    if src_white_path is not None:
        os.makedirs(os.path.join(target_parent_folder, 'white'))
        shutil.copy(src_white_path, os.path.join(target_parent_folder, 'white', os.path.basename(src_white_path)))
    if src_uv_paths is not None:
        os.makedirs(os.path.join(target_parent_folder, 'uv'))
        for src_uv_file in src_uv_paths:
            shutil.copy(src_uv_file, os.path.join(target_parent_folder, 'uv', os.path.basename(src_uv_file)))
    
    df_meta = pd.DataFrame({'measurementSetId': measurements_list, 'folder': folders_list})
    df_meta.to_csv(os.path.join(target_parent_folder, 'correlations.csv'))
# Out:
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# UV is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# UV is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# UV is missing!!!
# White is missing!!!
# UV is missing!!!
# White is missing!!!
# UV is missing!!!
# White is missing!!!
# UV is missing!!!
# White is missing!!!
# UV is missing!!!
# White is missing!!!
# UV is missing!!!
# White is missing!!!
# UV is missing!!!
# White is missing!!!
# UV is missing!!!
# White is missing!!!
# UV is missing!!!
# White is missing!!!
# UV is missing!!!
# White is missing!!!
# UV is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# UV is missing!!!
# UV is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# UV is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# White is missing!!!
# UV is missing!!!

# %%
print('Done copying new (R/IR/G/UV/White) images!')
# Out:
# Done copying new (R/IR/G/UV/White) images!

# %% [markdown]
# ### LOC-old - manually picked C44/C43 copying

# %%
loc_extra_melanomas.head(5)
# Out:
#    Unnamed: 0 Histoloģijas atbilde (diagnozes kods) Vizītes Datums  \
# 0          27                                   C43       23.10.17
# 1          27                                   C43       23.10.17
# 2          27                                   C43       23.10.17
# 3          27                                   C43       23.10.17
# 4          29                                   C43       23.10.17
#
#    Pacienta nr  Veidojuma Nr  \
# 0           11           4.0
# 1           11           4.0
# 2           11           4.0
# 3           11           4.0
# 4           11           6.0
#
#                                             filepath color extra_key
# 0  /mnt/data/raw/_melanoma/Merijumi LOC/2017_10/2...     R      11X4
# 1  /mnt/data/raw/_melanoma/Merijumi LOC/2017_10/2...     G      11X4
# 2  /mnt/data/raw/_melanoma/Merijumi LOC/2017_10/2...    IR      11X4
# 3  /mnt/data/raw/_melanoma/Merijumi LOC/2017_10/2...    UV      11X4
# 4  /mnt/data/raw/_melanoma/Merijumi LOC/2017_10/2...     R      11X6

# %% [markdown]
# ## Copying loc_old_extra

# %%
# target_loc_old_img_folder = os.path.abspath('../../data/interim/_melanoma/loc_old_extra')
# target_loc_old_img_folder

# %%
# import glob
# from pathlib import Path
# # print(path.parent)

# loc_extra_melanomas_gr = loc_extra_melanomas.groupby(['extra_key'])
# i = 1
# for key, item in loc_extra_melanomas_gr:    
#     gr = loc_extra_melanomas_gr.get_group(key)
    
#     src_r_path = gr.loc[gr['color'] == 'R']['filepath'].tolist()[0]
#     src_ir_path = gr.loc[gr['color'] == 'IR']['filepath'].tolist()[0]
#     src_g_path = gr.loc[gr['color'] == 'G']['filepath'].tolist()[0]
#     src_uv_path = gr.loc[gr['color'] == 'UV']['filepath'].tolist()[0]
#     src_uv_allfiles_paths = glob.glob(str(Path(src_uv_path).parent) + "/*.png")
#     d = gr.loc[gr['color'] == 'R']['Vizītes Datums'].tolist()[0]
#     last_folder = datetime.strptime(d, '%d.%m.%y').strftime('%Y-%m-%d_%H-%M-%S')
    
#     code = gr.loc[gr['color'] == 'G']['Histoloģijas atbilde (diagnozes kods)'].tolist()[0]
    
#     target_parent_folder = os.path.join(target_loc_old_img_folder, code, last_folder) + '__' + str(i)
#     i = i + 1

#     os.makedirs(os.path.join(target_parent_folder, 'r'))
#     os.makedirs(os.path.join(target_parent_folder, 'ir'))
#     os.makedirs(os.path.join(target_parent_folder, 'g'))
#     os.makedirs(os.path.join(target_parent_folder, 'uv'))
    
#     shutil.copy(src_r_path, os.path.join(target_parent_folder, 'r', os.path.basename(src_r_path)))
#     shutil.copy(src_ir_path, os.path.join(target_parent_folder, 'ir', os.path.basename(src_ir_path)))
#     shutil.copy(src_g_path, os.path.join(target_parent_folder, 'g', os.path.basename(src_g_path)))
# #     shutil.copy(src_uv_path, os.path.join(target_parent_folder, 'uv', os.path.basename(src_uv_path)))
#     for uv_file in src_uv_allfiles_paths:
#         shutil.copy(uv_file, os.path.join(target_parent_folder, 'uv', os.path.basename(uv_file)))

# %%
# print('Done copying old LOC extra (C44+C43) (R/IR/G/UV) images')

# %% [markdown]
# ### Checkyourskin-Hungary files copying

# %%
def collect_grouped_file_paths(df_cys):

    root_folders = dict()

    def __extract_rgir_uv_files_paths(files_list):
        d = dict()
        for f_path in files_list:
            f = os.path.basename(f_path)
            if f.lower().startswith('r'):
                d['r'] = f_path
            elif f.lower().startswith('ir'):
                d['ir'] = f_path
            elif f.lower().startswith('g'):
                d['g'] = f_path
            elif f.lower().startswith('white'):
                d['white'] = f_path
            elif f.lower().startswith('uv') or f[0].isdigit():
                if 'uv' not in d:
                    d['uv'] = []
                d['uv'].append(f_path)
            else:
                print('unknown file type (R/IR/G/UV/White):', f)
        return d
    
#     def __extract_non_uv_files_paths(files_list):
#         d = dict()
#         for f_path in files_list:
#             f = os.path.basename(f_path)
#             if f.startswith('R'):
#                 d['r'] = f_path
#             elif f.startswith('IR'):
#                 d['ir'] = f_path
#             elif f.startswith('G'):
#                 d['g'] = f_path
#             elif f.startswith('White'):
#                 d['white'] = f_path
#             else:
#                 print('unknown file type (R/IR/G):', f)
#         return d

    for index, row in df_cys.iterrows():
        orig_parent_folder = None
        is_uv = False
        if True == row['is_uv_images']:
            files_paths = row['images_paths_list']  #row['best_uv_file_path']
            orig_parent_folder = Path(Path(Path(file_path).parent).parent).parent
            is_uv = True
        else:
            if len(row['images_paths_list']) == 0:
                print('Empty images list!!! row=[{}]'.format(row))
                print('--'*20)
                continue
            else:
                file_path = row['images_paths_list'][0]
                orig_parent_folder = Path(Path(Path(file_path).parent).parent).parent

        if not orig_parent_folder in root_folders:
            root_folders[orig_parent_folder]= {'codes': []}

        images_paths_dict = __extract_rgir_uv_files_paths(row['images_paths_list'])
        if 'uv' in images_paths_dict:
            root_folders[orig_parent_folder].update(**images_paths_dict, **{'uv_corr_id': row['measurementSetId']})
        else:
            root_folders[orig_parent_folder].update(**images_paths_dict, **{'non_uv_corr_id': row['measurementSetId']})
            
        created_date = datetime.strptime(row['measurementDateCreated'], date_time_format)  # sample datetime '2019-04-01 11:15:47'
        if datetime not in root_folders[orig_parent_folder]:
            root_folders[orig_parent_folder].update(**{'datetime': created_date.strftime(date_time_format)})
        else:
            root_folders[orig_parent_folder]['datetime'] = min(datetime.strptime(root_folders[orig_parent_folder]['datetime'], date_time_format), created_date).strftime(date_time_format)

######      
#         if type(row['Kods']) is str:  # This will skip 'nan' & 'None'
#             root_folders[orig_parent_folder]['codes'].append(row['Kods'])
#         if is_uv:
#             root_folders[orig_parent_folder].update(**{'uv': row['best_uv_file_path'], 'uv_corr_id': row['measurementSetId']})
#         else:
#             root_folders[orig_parent_folder].update(**__extract_non_uv_files_paths(row['images_paths_list']), **{'non_uv_corr_id': row['measurementSetId']})
        
    return root_folders

# %%
df_cys.head()
# Out:
#    measurementId                  measurementSetId measurementComment  \
# 0           1367  06634b2a1ff268294a25f1d5e3408746                NaN
# 1            309  30f589534eed314b2bdbcd41925ab015                NaN
# 2           1713  b20d87df92adf96f2503bb3d57b9ce18                NaN
# 3            345  34df6a8d8b378471d7852a7c2b2c0430                NaN
# 4           1394  94da4f751a78642a4fa299ecfa3b6bae                NaN
#
#   measurementDateCreated measurementDateFinished  receivedImagesCount  \
# 0    2019-03-05 13:10:10     2019-03-05 11:10:10                   10
# 1    2018-12-12 18:42:29     2018-12-12 16:42:29                    3
# 2    2019-04-01 11:48:31     2019-04-01 08:48:31                   10
# 3    2018-12-17 14:05:25     2018-12-17 12:05:25                    3
# 4    2019-03-07 13:42:29     2019-03-07 11:42:29                    3
#
#    deviceId deviceName                                  images_paths_list  \
# 0         2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/1367/in...
# 1         2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/309/in/...
# 2         2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/1713/in...
# 3         2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/345/in/...
# 4         2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/1394/in...
#
#   patient_id  ... is_uv_images  analyzeId  numberInSequence  \
# 0       1367  ...         True      522.0               1.0
# 1        309  ...         True      149.0               9.0
# 2       1713  ...         True      741.0               1.0
# 3        345  ...         True      149.0              32.0
# 4       1394  ...         True      550.0               1.0
#
#     analyzeDateCreated analyzePatientId  analyzeScannedBodyPartId  \
# 0  2019-03-05 13:16:02            170.0                      16.0
# 1  2019-01-22 09:53:25             59.0                       5.0
# 2  2019-04-01 11:50:46            211.0                      26.0
# 3  2019-01-22 09:53:25             59.0                       5.0
# 4  2019-03-07 14:47:34            175.0                      27.0
#
#                           analyzeDoctorComment analyzeDiagnosisComment  \
# 0  solar keratosis, right side of the forehead                     NaN
# 1                    test pictures from Latvia                     NaN
# 2       dysplastic naevus on the left shoulder                     NaN
# 3                    test pictures from Latvia                     NaN
# 4                        pxe, axillar, lateral                     NaN
#
#   LesionCode code
# 0        L57  L57
# 1        NaN  NaN
# 2        D48  D48
# 3        NaN  NaN
# 4        PXE  PXE
#
# [5 rows x 21 columns]

# %%
df_cys.shape
# Out:
# (1005, 21)

# %%
list(df_cys.columns)
# Out:
# ['measurementId',
#  'measurementSetId',
#  'measurementComment',
#  'measurementDateCreated',
#  'measurementDateFinished',
#  'receivedImagesCount',
#  'deviceId',
#  'deviceName',
#  'images_paths_list',
#  'patient_id',
#  'lesion_id',
#  'is_uv_images',
#  'analyzeId',
#  'numberInSequence',
#  'analyzeDateCreated',
#  'analyzePatientId',
#  'analyzeScannedBodyPartId',
#  'analyzeDoctorComment',
#  'analyzeDiagnosisComment',
#  'LesionCode',
#  'code']

# %%
df_cys.head(15)
# Out:
#     measurementId                  measurementSetId measurementComment  \
# 0            1367  06634b2a1ff268294a25f1d5e3408746                NaN
# 1             309  30f589534eed314b2bdbcd41925ab015                NaN
# 2            1713  b20d87df92adf96f2503bb3d57b9ce18                NaN
# 3             345  34df6a8d8b378471d7852a7c2b2c0430                NaN
# 4            1394  94da4f751a78642a4fa299ecfa3b6bae                NaN
# 5            1729  a0bfd1f50d93ca9c75711b1492fd911b                NaN
# 6            1835  1cc0150b7e91da704fd6eb50998a7e4c                NaN
# 7             673  49da338725a504723b7b8ce535d41508                NaN
# 8            1709  1c0604df88c244e30f51d6bbaea08e51                NaN
# 9            1314  6a647e07187594bc5b40990d47c651d3                NaN
# 10           1782  00e2bac5507d44c25ca7b912f679e84e                NaN
# 11           1540  186163893ec32be23e5d0b99d888872b                NaN
# 12           1831  585d9bfe0bdff6f901f1529e80c1f2f4                NaN
# 13           1951  4f90ffa1e1fd275f1fa76969b47a8e35                NaN
# 14           1131  5584912da0320e800d937a444c3da06c                NaN
#
#    measurementDateCreated measurementDateFinished  receivedImagesCount  \
# 0     2019-03-05 13:10:10     2019-03-05 11:10:10                   10
# 1     2018-12-12 18:42:29     2018-12-12 16:42:29                    3
# 2     2019-04-01 11:48:31     2019-04-01 08:48:31                   10
# 3     2018-12-17 14:05:25     2018-12-17 12:05:25                    3
# 4     2019-03-07 13:42:29     2019-03-07 11:42:29                    3
# 5     2019-04-02 10:36:42     2019-04-02 07:36:42                   10
# 6     2019-04-08 13:10:10     2019-04-08 10:10:10                   10
# 7     2019-01-21 14:08:44     2019-01-21 12:08:44                    3
# 8     2019-04-01 11:15:47     2019-04-01 08:15:47                   10
# 9     2019-02-26 12:19:24     2019-02-26 10:19:24                    3
# 10    2019-04-08 11:48:40     2019-04-08 08:48:40                    3
# 11    2019-03-20 12:44:49     2019-03-20 10:44:49                    3
# 12    2019-04-08 13:07:16     2019-04-08 10:07:16                   10
# 13    2019-04-17 12:33:40     2019-04-17 09:33:40                   10
# 14    2019-02-12 12:25:57     2019-02-12 10:25:57                   10
#
#     deviceId deviceName                                  images_paths_list  \
# 0          2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/1367/in...
# 1          2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/309/in/...
# 2          2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/1713/in...
# 3          2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/345/in/...
# 4          2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/1394/in...
# 5          2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/1729/in...
# 6          2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/1835/in...
# 7          2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/673/in/...
# 8          2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/1709/in...
# 9          2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/1314/in...
# 10         2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/1782/in...
# 11         2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/1540/in...
# 12         2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/1831/in...
# 13         2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/1951/in...
# 14         2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/1131/in...
#
#    patient_id  ... is_uv_images  analyzeId  numberInSequence  \
# 0        1367  ...         True      522.0               1.0
# 1         309  ...         True      149.0               9.0
# 2        1713  ...         True      741.0               1.0
# 3         345  ...         True      149.0              32.0
# 4        1394  ...         True      550.0               1.0
# 5        1729  ...         True      759.0               1.0
# 6        1835  ...         True      841.0               1.0
# 7         673  ...         True      154.0              21.0
# 8        1709  ...         True      738.0               1.0
# 9        1314  ...         True      469.0               1.0
# 10       1782  ...         True      772.0               1.0
# 11       1540  ...         True      631.0               1.0
# 12       1831  ...         True      837.0               1.0
# 13       1951  ...         True      933.0               1.0
# 14       1131  ...         True      405.0               1.0
#
#      analyzeDateCreated analyzePatientId  analyzeScannedBodyPartId  \
# 0   2019-03-05 13:16:02            170.0                      16.0
# 1   2019-01-22 09:53:25             59.0                       5.0
# 2   2019-04-01 11:50:46            211.0                      26.0
# 3   2019-01-22 09:53:25             59.0                       5.0
# 4   2019-03-07 14:47:34            175.0                      27.0
# 5   2019-04-02 10:48:19            214.0                      68.0
# 6   2019-04-08 13:10:24            217.0                      27.0
# 7   2019-01-22 10:41:20             60.0                       2.0
# 8   2019-04-01 11:27:47            209.0                      25.0
# 9   2019-02-26 13:21:07            153.0                     232.0
# 10  2019-04-08 12:11:55            215.0                      23.0
# 11  2019-03-20 13:24:11            187.0                      17.0
# 12  2019-04-08 13:07:35            217.0                      68.0
# 13  2019-04-17 12:43:04            236.0                      72.0
# 14  2019-02-12 14:53:39            128.0                      44.0
#
#                                  analyzeDoctorComment analyzeDiagnosisComment  \
# 0         solar keratosis, right side of the forehead                     NaN
# 1                           test pictures from Latvia                     NaN
# 2              dysplastic naevus on the left shoulder                     NaN
# 3                           test pictures from Latvia                     NaN
# 4                               pxe, axillar, lateral                     NaN
# 5                                              BCC 9h                     NaN
# 6                                        pxe, axillar                     NaN
# 7                                                 NaN                     NaN
# 8                                 pigmented basalioma                     NaN
# 9   left side of the trunk,ulcerated melanoma mali...                     NaN
# 10                 PXE, right shoulder, anterior part                     NaN
# 11                               basalioma, left face                     NaN
# 12                                  pxe, trunk, lower                     NaN
# 13                                 scc? mm? posterior                     NaN
# 14    melanoma malignum/ dyspl. naevus ? on right leg                     NaN
#
#    LesionCode code
# 0         L57  L57
# 1         NaN  NaN
# 2         D48  D48
# 3         NaN  NaN
# 4         PXE  PXE
# 5         C44  C44
# 6         PXE  PXE
# 7         NaN  NaN
# 8         C44  C44
# 9         C43  C43
# 10        PXE  PXE
# 11        C44  C44
# 12        PXE  PXE
# 13        NaN  NaN
# 14        NaN  NaN
#
# [15 rows x 21 columns]

# %%
df_cys.sort_values(by=['measurementDateCreated', 'measurementDateFinished'])[0:17]
# Out:
#      measurementId                  measurementSetId measurementComment  \
# 660            306  4f534c5035d6bc305cf222e3fc7c18b0                NaN
# 443        316  ...         True      149.0              16.0
# 289        317  ...         True      149.0              17.0
# 231        318  ...         True      149.0              18.0
# 300        319  ...         True      149.0              19.0
# 103        320  ...         True      149.0              20.0
# 508        321  ...         True      149.0              21.0
# 869        322  ...         True      149.0              22.0
#
#       analyzeDateCreated analyzePatientId  analyzeScannedBodyPartId  \
# 660  2019-01-22 09:53:25             59.0                       5.0
# 457  2019-01-22 09:53:25             59.0                       5.0
# 73   2019-01-22 09:53:25             59.0                       5.0
# 1    2019-01-22 09:53:25             59.0                       5.0
# 630  2019-01-22 09:53:25             59.0                       5.0
# 737  2019-01-22 09:53:25             59.0                       5.0
# 706  2019-01-22 09:53:25             59.0                       5.0
# 72   2019-01-22 09:53:25             59.0                       5.0
# 598  2019-01-22 09:53:25             59.0                       5.0
# 155  2019-01-22 09:53:25             59.0                       5.0
# 443  2019-01-22 09:53:25             59.0                       5.0
# 289  2019-01-22 09:53:25             59.0                       5.0
# 231  2019-01-22 09:53:25             59.0                       5.0
# 300  2019-01-22 09:53:25             59.0                       5.0
# 103  2019-01-22 09:53:25             59.0                       5.0
# 508  2019-01-22 09:53:25             59.0                       5.0
# 869  2019-01-22 09:53:25             59.0                       5.0
#
#           analyzeDoctorComment analyzeDiagnosisComment LesionCode code
# 660  test pictures from Latvia                     NaN        NaN  NaN
# 457  test pictures from Latvia                     NaN        NaN  NaN
# 73   test pictures from Latvia                     NaN        NaN  NaN
# 1    test pictures from Latvia                     NaN        NaN  NaN
# 630  test pictures from Latvia                     NaN        NaN  NaN
# 737  test pictures from Latvia                     NaN        NaN  NaN
# 706  test pictures from Latvia                     NaN        NaN  NaN
# 72   test pictures from Latvia                     NaN        NaN  NaN
# 598  test pictures from Latvia                     NaN        NaN  NaN
# 155  test pictures from Latvia                     NaN        NaN  NaN
# 443  test pictures from Latvia                     NaN        NaN  NaN
# 289  test pictures from Latvia                     NaN        NaN  NaN
# 231  test pictures from Latvia                     NaN        NaN  NaN
# 300  test pictures from Latvia                     NaN        NaN  NaN
# 103  test pictures from Latvia                     NaN        NaN  NaN
# 508  test pictures from Latvia                     NaN        NaN  NaN
# 869  test pictures from Latvia                     NaN        NaN  NaN
#
# [17 rows x 21 columns]

# %%
# NOw find differences in dates for datetime column
df_cys_sorted = df_cys.sort_values(by=['measurementDateCreated', 'measurementDateFinished'])
df_cys_sorted['difference_sec'] = pd.to_datetime(df_cys_sorted.sort_values(by=['measurementDateCreated', 'measurementDateFinished'])['measurementDateCreated']).diff() / np.timedelta64(1, 's')
df_cys_sorted['group'] = -1

# %%
difference_sec = df_cys_sorted['difference_sec']

import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"]=20,10
plt.hist(difference_sec.loc[difference_sec < 100], bins = 50)
plt.yscale("log")
plt.show()

# %% [markdown]
# Seems threshold 40 is a sweet spot.

# %%
group_id = 0
for i, row in df_cys_sorted.iterrows():
    diff_sec = row['difference_sec']
    if diff_sec > 40:
        group_id = group_id + 1
    df_cys_sorted.at[i, 'group'] = group_id

# %%
df_cys_sorted[130:155]
# Out:
#       measurementId                  measurementSetId measurementComment  \
2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/664/in/...
# 979          2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/665/in/...
# 797          2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/666/in/...
# 187          2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/671/in/...
# 452          2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/672/in/...
# 7            2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/673/in/...
# 993          2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/674/in/...
# 694          2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/675/in/...
# 464          2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/676/in/...
# 280          2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/681/in/...
# 873          2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/684/in/...
# 306          2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/685/in/...
# 958          2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/690/in/...
# 827          2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/691/in/...
# 291          2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/692/in/...
# 65           2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/693/in/...
# 405          2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/694/in/...
# 146          2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/695/in/...
# 467          2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/696/in/...
# 681          2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/697/in/...
# 606          2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/698/in/...
# 129          2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/699/in/...
# 318          2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/703/in/...
# 1000         2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/704/in/...
# 460          2    Hungary  [/mnt/data/raw/_melanoma/Checkyourskin/705/in/...
#
#      patient_id  ... numberInSequence   analyzeDateCreated  analyzePatientId  \
# 672         664  ...              NaN                  NaN               NaN
# 979         665  ...              NaN                  NaN               NaN
# 797         666  ...              NaN                  NaN               NaN
# 187         671  ...             19.0  2019-01-22 10:41:20              60.0
# 452         672  ...             20.0  2019-01-22 10:41:20              60.0
# 7           673  ...             21.0  2019-01-22 10:41:20              60.0
# 993         674  ...             22.0  2019-01-22 10:41:20              60.0
# 694         675  ...             23.0  2019-01-22 10:41:20              60.0
# 464         676  ...             24.0  2019-01-22 10:41:20              60.0
# 280         681  ...             25.0  2019-01-22 10:41:20              60.0
# 873         684  ...             26.0  2019-01-22 10:41:20              60.0
# 306         685  ...             27.0  2019-01-22 10:41:20              60.0
# 958         690  ...             28.0  2019-01-22 10:41:20              60.0
# 827         691  ...             29.0  2019-01-22 10:41:20              60.0
# 291         692  ...             30.0  2019-01-22 10:41:20              60.0
# 65          693  ...             31.0  2019-01-22 10:41:20              60.0
# 405         694  ...             32.0  2019-01-22 10:41:20              60.0
# 146         695  ...             33.0  2019-01-22 10:41:20              60.0
# 467         696  ...             34.0  2019-01-22 10:41:20              60.0
# 681         697  ...             35.0  2019-01-22 10:41:20              60.0
# 606         698  ...             36.0  2019-01-22 10:41:20              60.0
# 129         699  ...             37.0  2019-01-22 10:41:20              60.0
# 318         703  ...             38.0  2019-01-22 10:41:20              60.0
# 1000        704  ...              1.0  2019-01-22 10:56:13              61.0
# 460         705  ...              1.0  2019-01-22 10:56:42              61.0
#
#       analyzeScannedBodyPartId analyzeDoctorComment  analyzeDiagnosisComment  \
# 672                        NaN                  NaN                      NaN
# 979                        NaN                  NaN                      NaN
# 797                        NaN                  NaN                      NaN
# 187                        2.0                  NaN                      NaN
# 452                        2.0                  NaN                      NaN
# 7                          2.0                  NaN                      NaN
# 993                        2.0                  NaN                      NaN
# 694                        2.0                  NaN                      NaN
# 464                        2.0                  NaN                      NaN
# 280                        2.0                  NaN                      NaN
# 873                        2.0                  NaN                      NaN
# 306                        2.0                  NaN                      NaN
# 958                        2.0                  NaN                      NaN
# 827                        2.0                  NaN                      NaN
# 291                        2.0                  NaN                      NaN
# 65                         2.0                  NaN                      NaN
# 405                        2.0                  NaN                      NaN
# 146                        2.0                  NaN                      NaN
# 467                        2.0                  NaN                      NaN
# 681                        2.0                  NaN                      NaN
# 606                        2.0                  NaN                      NaN
# 129                        2.0                  NaN                      NaN
# 318                        2.0                  NaN                      NaN
# 1000                      71.0    melanoma malignum                      NaN
# 460                       71.0    melanoma malignum                      NaN
#
#       LesionCode code difference_sec group
# 672          NaN  NaN            7.0   102
# 979          NaN  NaN           61.0   103
# 797          NaN  NaN            3.0   103
# 187          NaN  NaN         7364.0   104
# 452          NaN  NaN            2.0   104
# 7            NaN  NaN          131.0   105
# 993          NaN  NaN            3.0   105
# 694          NaN  NaN          521.0   106
# 464          NaN  NaN            5.0   106
# 280          NaN  NaN         3072.0   107
# 873          NaN  NaN          707.0   108
# 306          NaN  NaN            4.0   108
# 958          NaN  NaN        10821.0   109
# 827          NaN  NaN            3.0   109
# 291          NaN  NaN        53183.0   110
# 65           NaN  NaN            4.0   110
# 405          NaN  NaN          195.0   111
# 146          NaN  NaN            1.0   111
# 467          NaN  NaN          269.0   112
# 681          NaN  NaN            6.0   112
# 606          NaN  NaN         1005.0   113
# 129          NaN  NaN            2.0   113
# 318          NaN  NaN          249.0   114
# 1000         C43  C43          304.0   115
# 460          C43  C43            5.0   115
#
# [25 rows x 23 columns]

# %% [markdown]
# ### COPY FILES (Checkyourskin)

# %%
# Let's see stats
df_cys_sorted_gr = df_cys_sorted.groupby(['analyzePatientId','group'])
freq_dict = {}

for key, item in df_cys_sorted_gr:
    print('KEY:', key)
    l = df_cys_sorted_gr.get_group(key)['images_paths_list'].tolist()
    print('LENGTH:', len(l))
    
    if str(len(l)) not in freq_dict:
        freq_dict[str(len(l))] = 0
    
    freq_dict[str(len(l))] = freq_dict[str(len(l))] + 1
    
    
    dates = df_cys_sorted_gr.get_group(key)['measurementDateCreated'].tolist()
    print(dates)
    
    comments = df_cys_sorted_gr.get_group(key)['analyzeDoctorComment'].tolist()
    print(comments)
    
    print(l, "\n\n")
    print('==============================================')
# Out:
# KEY: (49.0, 81)
# LENGTH: 1
# ['2019-01-10 16:59:51']
# [nan]
# [['/mnt/data/raw/_melanoma/Checkyourskin/517/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/517/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/517/in/G.png']]
#
#
# ==============================================
# KEY: (52.0, 92)
# LENGTH: 2
# ['2019-01-21 10:53:00', '2019-01-21 10:53:03']
# ['dysplasticus naevus', 'dysplasticus naevus']
# [['/mnt/data/raw/_melanoma/Checkyourskin/643/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/643/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/643/in/G.png'], ['/mnt/data/raw/_melanoma/Checkyourskin/644/in/16.png', '/mnt/data/raw/_melanoma/Checkyourskin/644/in/13.png', '/mnt/data/raw/_melanoma/Checkyourskin/644/in/12.png', '/mnt/data/raw/_melanoma/Checkyourskin/644/in/39.png', '/mnt/data/raw/_melanoma/Checkyourskin/644/in/11.png', '/mnt/data/raw/_melanoma/Checkyourskin/644/in/14.png', '/mnt/data/raw/_melanoma/Checkyourskin/644/in/38.png', '/mnt/data/raw/_melanoma/Checkyourskin/644/in/15.png', '/mnt/data/raw/_melanoma/Checkyourskin/644/in/10.png', '/mnt/data/raw/_melanoma/Checkyourskin/644/in/17.png']]
#
#
# ==============================================
# KEY: (53.0, 93)
# LENGTH: 2
# ['2019-01-21 11:15:30', '2019-01-21 11:15:37']
# ['seb kerat 1a', 'seb kerat 1b']
# [['/mnt/data/raw/_melanoma/Checkyourskin/645/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/645/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/645/in/G.png'], ['/mnt/data/raw/_melanoma/Checkyourskin/646/in/16.png', '/mnt/data/raw/_melanoma/Checkyourskin/646/in/13.png', '/mnt/data/raw/_melanoma/Checkyourskin/646/in/12.png', '/mnt/data/raw/_melanoma/Checkyourskin/646/in/39.png', '/mnt/data/raw/_melanoma/Checkyourskin/646/in/11.png', '/mnt/data/raw/_melanoma/Checkyourskin/646/in/14.png', '/mnt/data/raw/_melanoma/Checkyourskin/646/in/38.png', '/mnt/data/raw/_melanoma/Checkyourskin/646/in/15.png', '/mnt/data/raw/_melanoma/Checkyourskin/646/in/10.png', '/mnt/data/raw/_melanoma/Checkyourskin/646/in/17.png']]
#
#
# ==============================================
# KEY: (53.0, 94)
# LENGTH: 2
# ['2019-01-21 11:17:31', '2019-01-21 11:17:44']
# ['pigmentad bcc/ SK a', 'pigmentad bcc/ SK b']
# [['/mnt/data/raw/_melanoma/Checkyourskin/647/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/647/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/647/in/G.png'], ['/mnt/data/raw/_melanoma/Checkyourskin/648/in/16.png', '/mnt/data/raw/_melanoma/Checkyourskin/648/in/13.png', '/mnt/data/raw/_melanoma/Checkyourskin/648/in/12.png', '/mnt/data/raw/_melanoma/Checkyourskin/648/in/39.png', '/mnt/data/raw/_melanoma/Checkyourskin/648/in/11.png', '/mnt/data/raw/_melanoma/Checkyourskin/648/in/14.png', '/mnt/data/raw/_melanoma/Checkyourskin/648/in/38.png', '/mnt/data/raw/_melanoma/Checkyourskin/648/in/15.png', '/mnt/data/raw/_melanoma/Checkyourskin/648/in/10.png', '/mnt/data/raw/_melanoma/Checkyourskin/648/in/17.png']]
#
#
# ==============================================
# KEY: (53.0, 95)
# LENGTH: 2
# ['2019-01-21 11:18:41', '2019-01-21 11:18:48']
# ['basal cell cc a', 'basal cell cc b']
# [['/mnt/data/raw/_melanoma/Checkyourskin/649/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/649/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/649/in/G.png'], ['/mnt/data/raw/_melanoma/Checkyourskin/650/in/16.png', '/mnt/data/raw/_melanoma/Checkyourskin/650/in/13.png', '/mnt/data/raw/_melanoma/Checkyourskin/650/in/12.png', '/mnt/data/raw/_melanoma/Checkyourskin/650/in/39.png', '/mnt/data/raw/_melanoma/Checkyourskin/650/in/11.png', '/mnt/data/raw/_melanoma/Checkyourskin/650/in/14.png', '/mnt/data/raw/_melanoma/Checkyourskin/650/in/38.png', '/mnt/data/raw/_melanoma/Checkyourskin/650/in/15.png', '/mnt/data/raw/_melanoma/Checkyourskin/650/in/10.png', '/mnt/data/raw/_melanoma/Checkyourskin/650/in/17.png']]
#
#
# ==============================================
# KEY: (53.0, 96)
# LENGTH: 2
# ['2019-01-21 11:19:33', '2019-01-21 11:19:40']
# ['seb kerat 2a', 'seb kerat 2b']
# [['/mnt/data/raw/_melanoma/Checkyourskin/651/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/651/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/651/in/G.png'], ['/mnt/data/raw/_melanoma/Checkyourskin/652/in/16.png', '/mnt/data/raw/_melanoma/Checkyourskin/652/in/13.png', '/mnt/data/raw/_melanoma/Checkyourskin/652/in/12.png', '/mnt/data/raw/_melanoma/Checkyourskin/652/in/39.png', '/mnt/data/raw/_melanoma/Checkyourskin/652/in/11.png', '/mnt/data/raw/_melanoma/Checkyourskin/652/in/14.png', '/mnt/data/raw/_melanoma/Checkyourskin/652/in/38.png', '/mnt/data/raw/_melanoma/Checkyourskin/652/in/15.png', '/mnt/data/raw/_melanoma/Checkyourskin/652/in/10.png', '/mnt/data/raw/_melanoma/Checkyourskin/652/in/17.png']]
#
#
# ==============================================
# KEY: (54.0, 97)
# LENGTH: 2
# ['2019-01-21 11:27:55', '2019-01-21 11:28:01']
# ['solar lentigo a', 'solar lentigo b']
# [['/mnt/data/raw/_melanoma/Checkyourskin/653/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/653/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/653/in/G.png'], ['/mnt/data/raw/_melanoma/Checkyourskin/654/in/16.png', '/mnt/data/raw/_melanoma/Checkyourskin/654/in/13.png', '/mnt/data/raw/_melanoma/Checkyourskin/654/in/12.png', '/mnt/data/raw/_melanoma/Checkyourskin/654/in/39.png', '/mnt/data/raw/_melanoma/Checkyourskin/654/in/11.png', '/mnt/data/raw/_melanoma/Checkyourskin/654/in/14.png', '/mnt/data/raw/_melanoma/Checkyourskin/654/in/38.png', '/mnt/data/raw/_melanoma/Checkyourskin/654/in/15.png', '/mnt/data/raw/_melanoma/Checkyourskin/654/in/10.png', '/mnt/data/raw/_melanoma/Checkyourskin/654/in/17.png']]
#
#
# ==============================================
# KEY: (55.0, 98)
# LENGTH: 2
# ['2019-01-21 11:34:02', '2019-01-21 11:34:05']
# ['solar lentigo a', 'solar lentigo b']
# [['/mnt/data/raw/_melanoma/Checkyourskin/655/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/655/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/655/in/G.png'], ['/mnt/data/raw/_melanoma/Checkyourskin/656/in/16.png', '/mnt/data/raw/_melanoma/Checkyourskin/656/in/13.png', '/mnt/data/raw/_melanoma/Checkyourskin/656/in/12.png', '/mnt/data/raw/_melanoma/Checkyourskin/656/in/39.png', '/mnt/data/raw/_melanoma/Checkyourskin/656/in/11.png', '/mnt/data/raw/_melanoma/Checkyourskin/656/in/14.png', '/mnt/data/raw/_melanoma/Checkyourskin/656/in/38.png', '/mnt/data/raw/_melanoma/Checkyourskin/656/in/15.png', '/mnt/data/raw/_melanoma/Checkyourskin/656/in/10.png', '/mnt/data/raw/_melanoma/Checkyourskin/656/in/17.png']]
#
#
# ==============================================
# KEY: (56.0, 100)
# LENGTH: 2
# ['2019-01-21 11:48:08', '2019-01-21 11:48:10']
# ['intradermal nevus a', 'intradermal nevus b']
# [['/mnt/data/raw/_melanoma/Checkyourskin/659/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/659/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/659/in/G.png'], ['/mnt/data/raw/_melanoma/Checkyourskin/660/in/16.png', '/mnt/data/raw/_melanoma/Checkyourskin/660/in/13.png', '/mnt/data/raw/_melanoma/Checkyourskin/660/in/12.png', '/mnt/data/raw/_melanoma/Checkyourskin/660/in/39.png', '/mnt/data/raw/_melanoma/Checkyourskin/660/in/11.png', '/mnt/data/raw/_melanoma/Checkyourskin/660/in/14.png', '/mnt/data/raw/_melanoma/Checkyourskin/660/in/38.png', '/mnt/data/raw/_melanoma/Checkyourskin/660/in/15.png', '/mnt/data/raw/_melanoma/Checkyourskin/660/in/10.png', '/mnt/data/raw/_melanoma/Checkyourskin/660/in/17.png']]
#
#
# ==============================================
# KEY: (57.0, 101)
# LENGTH: 2
# ['2019-01-21 11:57:36', '2019-01-21 11:57:39']
# ['basal cell cc cruris ld a', 'basal cell cc cruris ld b']
# [['/mnt/data/raw/_melanoma/Checkyourskin/661/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/661/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/661/in/G.png'], ['/mnt/data/raw/_melanoma/Checkyourskin/662/in/16.png', '/mnt/data/raw/_melanoma/Checkyourskin/662/in/13.png', '/mnt/data/raw/_melanoma/Checkyourskin/662/in/12.png', '/mnt/data/raw/_melanoma/Checkyourskin/662/in/39.png', '/mnt/data/raw/_melanoma/Checkyourskin/662/in/11.png', '/mnt/data/raw/_melanoma/Checkyourskin/662/in/14.png', '/mnt/data/raw/_melanoma/Checkyourskin/662/in/38.png', '/mnt/data/raw/_melanoma/Checkyourskin/662/in/15.png', '/mnt/data/raw/_melanoma/Checkyourskin/662/in/10.png', '/mnt/data/raw/_melanoma/Checkyourskin/662/in/17.png']]
#
#
# ==============================================
# KEY: (59.0, 0)
# LENGTH: 1
# ['2018-12-12 18:11:57']
# ['test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/306/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/306/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/306/in/G.png']]
#
#
# ==============================================
# KEY: (59.0, 1)
# LENGTH: 1
# ['2018-12-12 18:39:23']
# ['test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/307/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/307/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/307/in/G.png']]
#
#
# ==============================================
# KEY: (59.0, 2)
# LENGTH: 2
# ['2018-12-12 18:42:08', '2018-12-12 18:42:29']
# ['test pictures from Latvia', 'test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/308/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/308/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/308/in/G.png'], ['/mnt/data/raw/_melanoma/Checkyourskin/309/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/309/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/309/in/G.png']]
#
#
# ==============================================
# KEY: (59.0, 3)
# LENGTH: 1
# ['2018-12-12 19:08:01']
# ['test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/310/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/310/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/310/in/G.png']]
#
#
# ==============================================
# KEY: (59.0, 4)
# LENGTH: 1
# ['2018-12-12 19:16:47']
# ['test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/311/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/311/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/311/in/G.png']]
#
#
# ==============================================
# KEY: (59.0, 5)
# LENGTH: 1
# ['2018-12-12 19:30:17']
# ['test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/312/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/312/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/312/in/G.png']]
#
#
# ==============================================
# KEY: (59.0, 6)
# LENGTH: 2
# ['2018-12-12 20:03:52', '2018-12-12 20:04:25']
# ['test pictures from Latvia', 'test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/313/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/313/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/313/in/G.png'], ['/mnt/data/raw/_melanoma/Checkyourskin/314/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/314/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/314/in/G.png']]
#
#
# ==============================================
# KEY: (59.0, 7)
# LENGTH: 1
# ['2018-12-12 20:13:50']
# ['test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/315/in/48.png', '/mnt/data/raw/_melanoma/Checkyourskin/315/in/16.png', '/mnt/data/raw/_melanoma/Checkyourskin/315/in/13.png', '/mnt/data/raw/_melanoma/Checkyourskin/315/in/12.png', '/mnt/data/raw/_melanoma/Checkyourskin/315/in/49.png', '/mnt/data/raw/_melanoma/Checkyourskin/315/in/11.png', '/mnt/data/raw/_melanoma/Checkyourskin/315/in/14.png', '/mnt/data/raw/_melanoma/Checkyourskin/315/in/15.png', '/mnt/data/raw/_melanoma/Checkyourskin/315/in/10.png', '/mnt/data/raw/_melanoma/Checkyourskin/315/in/17.png']]
#
#
# ==============================================
# KEY: (59.0, 8)
# LENGTH: 1
# ['2018-12-13 12:47:35']
# ['test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/316/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/316/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/316/in/G.png']]
#
#
# ==============================================
# KEY: (59.0, 9)
# LENGTH: 1
# ['2018-12-13 12:51:17']
# ['test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/317/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/317/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/317/in/G.png']]
#
#
# ==============================================
# KEY: (59.0, 10)
# LENGTH: 1
# ['2018-12-13 12:58:03']
# ['test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/318/in/48.png', '/mnt/data/raw/_melanoma/Checkyourskin/318/in/16.png', '/mnt/data/raw/_melanoma/Checkyourskin/318/in/13.png', '/mnt/data/raw/_melanoma/Checkyourskin/318/in/12.png', '/mnt/data/raw/_melanoma/Checkyourskin/318/in/49.png', '/mnt/data/raw/_melanoma/Checkyourskin/318/in/11.png', '/mnt/data/raw/_melanoma/Checkyourskin/318/in/14.png', '/mnt/data/raw/_melanoma/Checkyourskin/318/in/15.png', '/mnt/data/raw/_melanoma/Checkyourskin/318/in/10.png', '/mnt/data/raw/_melanoma/Checkyourskin/318/in/17.png']]
#
#
# ==============================================
# KEY: (59.0, 11)
# LENGTH: 1
# ['2018-12-13 13:01:32']
# ['test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/319/in/48.png', '/mnt/data/raw/_melanoma/Checkyourskin/319/in/16.png', '/mnt/data/raw/_melanoma/Checkyourskin/319/in/13.png', '/mnt/data/raw/_melanoma/Checkyourskin/319/in/12.png', '/mnt/data/raw/_melanoma/Checkyourskin/319/in/49.png', '/mnt/data/raw/_melanoma/Checkyourskin/319/in/11.png', '/mnt/data/raw/_melanoma/Checkyourskin/319/in/14.png', '/mnt/data/raw/_melanoma/Checkyourskin/319/in/15.png', '/mnt/data/raw/_melanoma/Checkyourskin/319/in/10.png', '/mnt/data/raw/_melanoma/Checkyourskin/319/in/17.png']]
#
#
# ==============================================
# KEY: (59.0, 12)
# LENGTH: 1
# ['2018-12-13 14:54:39']
# ['test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/320/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/320/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/320/in/G.png']]
#
#
# ==============================================
# KEY: (59.0, 13)
# LENGTH: 1
# ['2018-12-13 14:55:24']
# ['test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/321/in/48.png', '/mnt/data/raw/_melanoma/Checkyourskin/321/in/16.png', '/mnt/data/raw/_melanoma/Checkyourskin/321/in/13.png', '/mnt/data/raw/_melanoma/Checkyourskin/321/in/12.png', '/mnt/data/raw/_melanoma/Checkyourskin/321/in/49.png', '/mnt/data/raw/_melanoma/Checkyourskin/321/in/11.png', '/mnt/data/raw/_melanoma/Checkyourskin/321/in/14.png', '/mnt/data/raw/_melanoma/Checkyourskin/321/in/15.png', '/mnt/data/raw/_melanoma/Checkyourskin/321/in/10.png', '/mnt/data/raw/_melanoma/Checkyourskin/321/in/17.png']]
#
#
# ==============================================
# KEY: (59.0, 14)
# LENGTH: 1
# ['2018-12-13 14:57:29']
# ['test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/322/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/322/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/322/in/G.png']]
#
#
# ==============================================
# KEY: (59.0, 15)
# LENGTH: 1
# ['2018-12-13 15:16:35']
# ['test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/324/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/324/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/324/in/G.png']]
#
#
# ==============================================
# KEY: (59.0, 16)
# LENGTH: 1
# ['2018-12-13 15:49:34']
# ['test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/325/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/325/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/325/in/G.png']]
#
#
# ==============================================
# KEY: (59.0, 17)
# LENGTH: 1
# ['2018-12-13 15:53:27']
# ['test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/326/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/326/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/326/in/G.png']]
#
#
# ==============================================
# KEY: (59.0, 18)
# LENGTH: 1
# ['2018-12-13 15:56:15']
# ['test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin
in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/424/in/G.png'], ['/mnt/data/raw/_melanoma/Checkyourskin/425/in/16.png', '/mnt/data/raw/_melanoma/Checkyourskin/425/in/13.png', '/mnt/data/raw/_melanoma/Checkyourskin/425/in/12.png', '/mnt/data/raw/_melanoma/Checkyourskin/425/in/11.png', '/mnt/data/raw/_melanoma/Checkyourskin/425/in/14.png', '/mnt/data/raw/_melanoma/Checkyourskin/425/in/58.png', '/mnt/data/raw/_melanoma/Checkyourskin/425/in/59.png', '/mnt/data/raw/_melanoma/Checkyourskin/425/in/15.png', '/mnt/data/raw/_melanoma/Checkyourskin/425/in/10.png', '/mnt/data/raw/_melanoma/Checkyourskin/425/in/17.png']]
#
#
# ==============================================
# KEY: (59.0, 53)
# LENGTH: 1
# ['2019-01-04 15:33:44']
# ['test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/426/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/426/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/426/in/G.png']]
#
#
# ==============================================
# KEY: (59.0, 54)
# LENGTH: 1
# ['2019-01-04 15:37:21']
# ['test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/428/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/428/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/428/in/G.png']]
#
#
# ==============================================
# KEY: (59.0, 55)
# LENGTH: 2
# ['2019-01-04 16:04:55', '2019-01-04 16:05:12']
# ['test pictures from Latvia', 'test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/431/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/431/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/431/in/G.png'], ['/mnt/data/raw/_melanoma/Checkyourskin/432/in/16.png', '/mnt/data/raw/_melanoma/Checkyourskin/432/in/13.png', '/mnt/data/raw/_melanoma/Checkyourskin/432/in/12.png', '/mnt/data/raw/_melanoma/Checkyourskin/432/in/11.png', '/mnt/data/raw/_melanoma/Checkyourskin/432/in/14.png', '/mnt/data/raw/_melanoma/Checkyourskin/432/in/58.png', '/mnt/data/raw/_melanoma/Checkyourskin/432/in/59.png', '/mnt/data/raw/_melanoma/Checkyourskin/432/in/15.png', '/mnt/data/raw/_melanoma/Checkyourskin/432/in/10.png', '/mnt/data/raw/_melanoma/Checkyourskin/432/in/17.png']]
#
#
# ==============================================
# KEY: (59.0, 56)
# LENGTH: 1
# ['2019-01-04 16:08:20']
# ['test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/433/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/433/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/433/in/G.png']]
#
#
# ==============================================
# KEY: (59.0, 57)
# LENGTH: 1
# ['2019-01-06 00:07:50']
# ['test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/481/in/a_09-32-07_936.png', '/mnt/data/raw/_melanoma/Checkyourskin/481/in/a_09-32-29_942.png', '/mnt/data/raw/_melanoma/Checkyourskin/481/in/a_09-32-40_946.png']]
#
#
# ==============================================
# KEY: (59.0, 58)
# LENGTH: 1
# ['2019-01-06 00:09:09']
# ['test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/482/in/a_09-32-07_936.png', '/mnt/data/raw/_melanoma/Checkyourskin/482/in/a_09-32-29_942.png', '/mnt/data/raw/_melanoma/Checkyourskin/482/in/a_09-32-40_946.png']]
#
#
# ==============================================
# KEY: (59.0, 59)
# LENGTH: 1
# ['2019-01-06 00:13:33']
# ['test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/483/in/a_11-17-04_6779.png', '/mnt/data/raw/_melanoma/Checkyourskin/483/in/a_11-16-53_6775.png', '/mnt/data/raw/_melanoma/Checkyourskin/483/in/a_11-16-58_6776.png']]
#
#
# ==============================================
# KEY: (59.0, 60)
# LENGTH: 1
# ['2019-01-06 00:28:59']
# ['test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/484/in/a_11-17-04_6779.png', '/mnt/data/raw/_melanoma/Checkyourskin/484/in/a_11-16-53_6775.png', '/mnt/data/raw/_melanoma/Checkyourskin/484/in/a_11-16-58_6776.png']]
#
#
# ==============================================
# KEY: (59.0, 61)
# LENGTH: 1
# ['2019-01-06 00:33:08']
# ['test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/485/in/R - Copy.png', '/mnt/data/raw/_melanoma/Checkyourskin/485/in/IR - Copy.png', '/mnt/data/raw/_melanoma/Checkyourskin/485/in/G - Copy.png']]
#
#
# ==============================================
# KEY: (59.0, 62)
# LENGTH: 1
# ['2019-01-06 00:36:28']
# ['test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/486/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/486/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/486/in/G.png']]
#
#
# ==============================================
# KEY: (59.0, 63)
# LENGTH: 1
# ['2019-01-06 00:59:54']
# ['test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/487/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/487/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/487/in/G.png']]
#
#
# ==============================================
# KEY: (59.0, 64)
# LENGTH: 1
# ['2019-01-06 01:10:05']
# ['test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/488/in/a_11-39-13_4907 - Copy.png', '/mnt/data/raw/_melanoma/Checkyourskin/488/in/a_11-38-20_4888 - Copy.png', '/mnt/data/raw/_melanoma/Checkyourskin/488/in/a_11-38-48_4901 - Copy.png']]
#
#
# ==============================================
# KEY: (59.0, 65)
# LENGTH: 1
# ['2019-01-06 01:12:42']
# ['test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/489/in/a_11-38-48_4901.png', '/mnt/data/raw/_melanoma/Checkyourskin/489/in/a_11-38-20_4888.png', '/mnt/data/raw/_melanoma/Checkyourskin/489/in/a_11-39-13_4907.png']]
#
#
# ==============================================
# KEY: (59.0, 66)
# LENGTH: 1
# ['2019-01-06 01:23:27']
# ['test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/490/in/ir0.png', '/mnt/data/raw/_melanoma/Checkyourskin/490/in/r0.png', '/mnt/data/raw/_melanoma/Checkyourskin/490/in/g0.png']]
#
#
# ==============================================
# KEY: (59.0, 67)
# LENGTH: 1
# ['2019-01-06 01:24:43']
# ['test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/491/in/r1.png', '/mnt/data/raw/_melanoma/Checkyourskin/491/in/ir1.png', '/mnt/data/raw/_melanoma/Checkyourskin/491/in/g1.png']]
#
#
# ==============================================
# KEY: (59.0, 68)
# LENGTH: 1
# ['2019-01-06 01:29:07']
# ['test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/492/in/g2.png', '/mnt/data/raw/_melanoma/Checkyourskin/492/in/r2.png', '/mnt/data/raw/_melanoma/Checkyourskin/492/in/ir2.png']]
#
#
# ==============================================
# KEY: (59.0, 69)
# LENGTH: 1
# ['2019-01-06 23:33:44']
# ['test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/493/in/IR1.png', '/mnt/data/raw/_melanoma/Checkyourskin/493/in/R1.png', '/mnt/data/raw/_melanoma/Checkyourskin/493/in/G1.png']]
#
#
# ==============================================
# KEY: (59.0, 70)
# LENGTH: 1
# ['2019-01-07 01:36:07']
# ['test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/494/in/r1.jpg', '/mnt/data/raw/_melanoma/Checkyourskin/494/in/ir1.jpg', '/mnt/data/raw/_melanoma/Checkyourskin/494/in/g1.jpg']]
#
#
# ==============================================
# KEY: (59.0, 71)
# LENGTH: 1
# ['2019-01-07 15:15:02']
# ['test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/495/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/495/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/495/in/G.png']]
#
#
# ==============================================
# KEY: (59.0, 72)
# LENGTH: 1
# ['2019-01-07 15:16:17']
# ['test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/496/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/496/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/496/in/G.png']]
#
#
# ==============================================
# KEY: (59.0, 73)
# LENGTH: 1
# ['2019-01-07 15:21:23']
# ['test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/497/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/497/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/497/in/G.png']]
#
#
# ==============================================
# KEY: (59.0, 74)
# LENGTH: 1
# ['2019-01-07 15:22:25']
# ['test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/498/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/498/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/498/in/G.png']]
#
#
# ==============================================
# KEY: (59.0, 75)
# LENGTH: 1
# ['2019-01-07 15:25:20']
# ['test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/499/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/499/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/499/in/G.png']]
#
#
# ==============================================
# KEY: (59.0, 76)
# LENGTH: 2
# ['2019-01-07 15:28:34', '2019-01-07 15:29:02']
# ['test pictures from Latvia', 'test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/500/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/500/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/500/in/G.png'], ['/mnt/data/raw/_melanoma/Checkyourskin/501/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/501/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/501/in/G.png']]
#
#
# ==============================================
# KEY: (59.0, 77)
# LENGTH: 1
# ['2019-01-07 15:35:36']
# ['test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/502/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/502/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/502/in/G.png']]
#
#
# ==============================================
# KEY: (59.0, 78)
# LENGTH: 1
# ['2019-01-07 15:36:20']
# ['test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/503/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/503/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/503/in/G.png']]
#
#
# ==============================================
# KEY: (59.0, 79)
# LENGTH: 1
# ['2019-01-07 23:43:39']
# ['test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/504/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/504/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/504/in/G.png']]
#
#
# ==============================================
# KEY: (59.0, 80)
# LENGTH: 1
# ['2019-01-07 23:53:05']
# ['test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/505/in/a_16-47-39_1461.png', '/mnt/data/raw/_melanoma/Checkyourskin/505/in/a_16-48-00_1465.png', '/mnt/data/raw/_melanoma/Checkyourskin/505/in/a_16-47-51_1463.png']]
#
#
# ==============================================
# KEY: (59.0, 82)
# LENGTH: 1
# ['2019-01-21 09:19:18']
# ['test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/623/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/623/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/623/in/G.png']]
#
#
# ==============================================
# KEY: (59.0, 83)
# LENGTH: 2
# ['2019-01-21 09:24:13', '2019-01-21 09:24:18']
# ['test pictures from Latvia', 'test pictures from Latvia']
# [['/mnt/data/raw/_melanoma/Checkyourskin/625/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/625/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/625/in/G.png'], ['/mnt/data/raw/_melanoma/Checkyourskin/626/in/16.png', '/mnt/data/raw/_melanoma/Checkyourskin/626/in/13.png', '/mnt/data/raw/_melanoma/Checkyourskin/626/in/12.png', '/mnt/data/raw/_melanoma/Checkyourskin/626/in/39.png', '/mnt/data/raw/_melanoma/Checkyourskin/626/in/11.png', '/mnt/data/raw/_melanoma/Checkyourskin/626/in/14.png', '/mnt/data/raw/_melanoma/Checkyourskin/626/in/38.png', '/mnt/data/raw/_melanoma/Checkyourskin/626/in/15.png', '/mnt/data/raw/_melanoma/Checkyourskin/626/in/10.png', '/mnt/data/raw/_melanoma/Checkyourskin/626/in/17.png']]
#
#
# ==============================================
# KEY: (60.0, 84)
# LENGTH: 2
# ['2019-01-21 09:28:10', '2019-01-21 09:28:16']
# [nan, nan]
# [['/mnt/data/raw/_melanoma/Checkyourskin/627/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/627/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/627/in/G.png'], ['/mnt/data/raw/_melanoma/Checkyourskin/628/in/16.png', '/mnt/data/raw/_melanoma/Checkyourskin/628/in/13.png', '/mnt/data/raw/_melanoma/Checkyourskin/628/in/12.png', '/mnt/data/raw/_melanoma/Checkyourskin/628/in/39.png', '/mnt/data/raw/_melanoma/Checkyourskin/628/in/11.png', '/mnt/data/raw/_melanoma/Checkyourskin/628/in/14.png', '/mnt/data/raw/_melanoma/Checkyourskin/628/in/38.png', '/mnt/data/raw/_melanoma/Checkyourskin/628/in/15.png', '/mnt/data/raw/_melanoma/Checkyourskin/628/in/10.png', '/mnt/data/raw/_melanoma/Checkyourskin/628/in/17.png']]
#
#
# ==============================================
# KEY: (60.0, 85)
# LENGTH: 2
# ['2019-01-21 09:31:44', '2019-01-21 09:31:51']
# [nan, nan]
# [['/mnt/data/raw/_melanoma/Checkyourskin/629/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/629/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/629/in/G.png'], ['/mnt/data/raw/_melanoma/Checkyourskin/630/in/16.png', '/mnt/data/raw/_melanoma/Checkyourskin/630/in/13.png', '/mnt/data/raw/_melanoma/Checkyourskin/630/in/12.png', '/mnt/data/raw/_melanoma/Checkyourskin/630/in/39.png', '/mnt/data/raw/_melanoma/Checkyourskin/630/in/11.png', '/mnt/data/raw/_melanoma/Checkyourskin/630/in/14.png', '/mnt/data/raw/_melanoma/Checkyourskin/630/in/38.png', '/mnt/data/raw/_melanoma/Checkyourskin/630/in/15.png', '/mnt/data/raw/_melanoma/Checkyourskin/630/in/10.png', '/mnt/data/raw/_melanoma/Checkyourskin/630/in/17.png']]
#
#
# ==============================================
# KEY: (60.0, 86)
# LENGTH: 2
# ['2019-01-21 09:32:45', '2019-01-21 09:32:49']
# [nan, nan]
# [['/mnt/data/raw/_melanoma/Checkyourskin/631/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/631/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/631/in/G.png'], ['/mnt/data/raw/_melanoma/Checkyourskin/632/in/16.png', '/mnt/data/raw/_melanoma/Checkyourskin/632/in/13.png', '/mnt/data/raw/_melanoma/Checkyourskin/632/in/12.png', '/mnt/data/raw/_melanoma/Checkyourskin/632/in/39.png', '/mnt/data/raw/_melanoma/Checkyourskin/632/in/11.png', '/mnt/data/raw/_melanoma/Checkyourskin/632/in/14.png', '/mnt/data/raw/_melanoma/Checkyourskin/632/in/38.png', '/mnt/data/raw/_melanoma/Checkyourskin/632/in/15.png', '/mnt/data/raw/_melanoma/Checkyourskin/632/in/10.png', '/mnt/data/raw/_melanoma/Checkyourskin/632/in/17.png']]
#
#
# ==============================================
# KEY: (60.0, 87)
# LENGTH: 2
# ['2019-01-21 09:35:05', '2019-01-21 09:35:09']
# [nan, nan]
# [['/mnt/data/raw/_melanoma/Checkyourskin/633/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/633/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/633/in/G.png'], ['/mnt/data/raw/_melanoma/Checkyourskin/634/in/16.png', '/mnt/data/raw/_melanoma/Checkyourskin/634/in/13.png', '/mnt/data/raw/_melanoma/Checkyourskin/634/in/12.png', '/mnt/data/raw/_melanoma/Checkyourskin/634/in/39.png', '/mnt/data/raw/_melanoma/Checkyourskin/634/in/11.png', '/mnt/data/raw/_melanoma/Checkyourskin/634/in/14.png', '/mnt/data/raw/_melanoma/Checkyourskin/634/in/38.png', '/mnt/data/raw/_melanoma/Checkyourskin/634/in/15.png', '/mnt/data/raw/_melanoma/Checkyourskin/634/in/10.png', '/mnt/data/raw/_melanoma/Checkyourskin/634/in/17.png']]
#
#
# ==============================================
# KEY: (60.0, 88)
# LENGTH: 2
# ['2019-01-21 09:37:26', '2019-01-21 09:37:31']
# [nan, nan]
# [['/mnt/data/raw/_melanoma/Checkyourskin/635/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/635/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/635/in/G.png'], ['/mnt/data/raw/_melanoma/Checkyourskin/636/in/16.png', '/mnt/data/raw/_melanoma/Checkyourskin/636/in/13.png', '/mnt/data/raw/_melanoma/Checkyourskin/636/in/12.png', '/mnt/data/raw/_melanoma/Checkyourskin/636/in/39.png', '/mnt/data/raw/_melanoma/Checkyourskin/636/in/11.png', '/mnt/data/raw/_melanoma/Checkyourskin/636/in/14.png', '/mnt/data/raw/_melanoma/Checkyourskin/636/in/38.png', '/mnt/data/raw/_melanoma/Checkyourskin/636/in/15.png', '/mnt/data/raw/_melanoma/Checkyourskin/636/in/10.png', '/mnt/data/raw/_melanoma/Checkyourskin/636/in/17.png']]
#
#
# ==============================================
# KEY: (60.0, 89)
# LENGTH: 2
# ['2019-01-21 09:48:05', '2019-01-21 09:48:07']
# [nan, nan]
# [['/mnt/data/raw/_melanoma/Checkyourskin/637/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/637/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/637/in/G.png'], ['/mnt/data/raw/_melanoma/Checkyourskin/638/in/16.png', '/mnt/data/raw/_melanoma/Checkyourskin/638/in/13.png', '/mnt/data/raw/_melanoma/Checkyourskin/638/in/12.png', '/mnt/data/raw/_melanoma/Checkyourskin/638/in/39.png', '/mnt/data/raw/_melanoma/Checkyourskin/638/in/11.png', '/mnt/data/raw/_melanoma/Checkyourskin/638/in/14.png', '/mnt/data/raw/_melanoma/Checkyourskin/638/in/38.png', '/mnt/data/raw/_melanoma/Checkyourskin/638/in/15.png', '/mnt/data/raw/_melanoma/Checkyourskin/638/in/10.png', '/mnt/data/raw/_melanoma/Checkyourskin/638/in/17.png']]
#
#
# ==============================================
# KEY: (60.0, 90)
# LENGTH: 2
# ['2019-01-21 09:51:05', '2019-01-21 09:51:12']
# [nan, nan]
# [['/mnt/data/raw/_melanoma/Checkyourskin/639/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/639/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/639/in/G.png'], ['/mnt/data/raw/_melanoma/Checkyourskin/640/in/16.png', '/mnt/data/raw/_melanoma/Checkyourskin/640/in/13.png', '/mnt/data/raw/_melanoma/Checkyourskin/640/in/12.png', '/mnt/data/raw/_melanoma/Checkyourskin/640/in/39.png', '/mnt/data/raw/_melanoma/Checkyourskin/640/in/11.png', '/mnt/data/raw/_melanoma/Checkyourskin/640/in/14.png', '/mnt/data/raw/_melanoma/Checkyourskin/640/in/38.png', '/mnt/data/raw/_melanoma/Checkyourskin/640/in/15.png', '/mnt/data/raw/_melanoma/Checkyourskin/640/in/10.png', '/mnt/data/raw/_melanoma/Checkyourskin/640/in/17.png']]
#
#
# ==============================================
# KEY: (60.0, 91)
# LENGTH: 2
# ['2019-01-21 09:52:32', '2019-01-21 09:52:39']
# [nan, nan]
# [['/mnt/data/raw/_melanoma/Checkyourskin/641/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/641/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/641/in/G.png'], ['/mnt/data/raw/_melanoma/Checkyourskin/642/in/16.png', '/mnt/data/raw/_melanoma/Checkyourskin/642/in/13.png', '/mnt/data/raw/_melanoma/Checkyourskin/642/in/12.png', '/mnt/data/raw/_melanoma/Checkyourskin/642/in/39.png', '/mnt/data/raw/_melanoma/Checkyourskin/642/in/11.png', '/mnt/data/raw/_melanoma/Checkyourskin/642/in/14.png', '/mnt/data/raw/_melanoma/Checkyourskin/642/in/38.png', '/mnt/data/raw/_melanoma/Checkyourskin/642/in/15.png', '/mnt/data/raw/_melanoma/Checkyourskin/642/in/10.png', '/mnt/data/raw/_melanoma/Checkyourskin/642/in/17.png']]
#
#
# ==============================================
# KEY: (60.0, 99)
# LENGTH: 2
# ['2019-01-21 11:35:01', '2019-01-21 11:35:07']
# [nan, nan]
# [['/mnt/data/raw/_melanoma/Checkyourskin/657/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/657/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/657/in/G.png'], ['/mnt/data/raw/_melanoma/Checkyourskin/658/in/16.png', '/mnt/data/raw/_melanoma/Checkyourskin/658/in/13.png', '/mnt/data/raw/_melanoma/Checkyourskin/658/in/12.png', '/mnt/data/raw/_melanoma/Checkyourskin/658/in/39.png', '/mnt/data/raw/_melanoma/Checkyourskin/658/in/11.png', '/mnt/data/raw/_melanoma/Checkyourskin/658/in/14.png', '/mnt/data/raw/_melanoma/Checkyourskin/658/in/38.png', '/mnt/data/raw/_melanoma/Checkyourskin/658/in/15.png', '/mnt/data/raw/_melanoma/Checkyourskin/658/in/10.png', '/mnt/data/raw/_melanoma/Checkyourskin/658/in/17.png']]
#
#
# ==============================================
# KEY: (60.0, 104)
# LENGTH: 2
# ['2019-01-21 14:06:31', '2019-01-21 14:06:33']
# [nan, nan]
# ...
#
#
# ==============================================
# KEY: (229.0, 507)
# LENGTH: 2
# ['2019-04-12 10:29:44', '2019-04-12 10:29:51']
# ['multiple myxoma, right lumbal', 'multiple myxoma, right lumbal']
# [['/mnt/data/raw/_melanoma/Checkyourskin/1899/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/1899/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/1899/in/G.png'], ['/mnt/data/raw/_melanoma/Checkyourskin/1900/in/16.png', '/mnt/data/raw/_melanoma/Checkyourskin/1900/in/13.png', '/mnt/data/raw/_melanoma/Checkyourskin/1900/in/12.png', '/mnt/data/raw/_melanoma/Checkyourskin/1900/in/39.png', '/mnt/data/raw/_melanoma/Checkyourskin/1900/in/11.png', '/mnt/data/raw/_melanoma/Checkyourskin/1900/in/14.png', '/mnt/data/raw/_melanoma/Checkyourskin/1900/in/38.png', '/mnt/data/raw/_melanoma/Checkyourskin/1900/in/15.png', '/mnt/data/raw/_melanoma/Checkyourskin/1900/in/10.png', '/mnt/data/raw/_melanoma/Checkyourskin/1900/in/17.png']]
#
#
# ==============================================
# KEY: (229.0, 508)
# LENGTH: 2
# ['2019-04-12 10:45:44', '2019-04-12 10:45:52']
# ['blue naevus, left arm', 'blue naevus, left arm']
# [['/mnt/data/raw/_melanoma/Checkyourskin/1901/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/1901/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/1901/in/G.png'], ['/mnt/data/raw/_melanoma/Checkyourskin/1902/in/16.png', '/mnt/data/raw/_melanoma/Checkyourskin/1902/in/13.png', '/mnt/data/raw/_melanoma/Checkyourskin/1902/in/12.png', '/mnt/data/raw/_melanoma/Checkyourskin/1902/in/39.png', '/mnt/data/raw/_melanoma/Checkyourskin/1902/in/11.png', '/mnt/data/raw/_melanoma/Checkyourskin/1902/in/14.png', '/mnt/data/raw/_melanoma/Checkyourskin/1902/in/38.png', '/mnt/data/raw/_melanoma/Checkyourskin/1902/in/15.png', '/mnt/data/raw/_melanoma/Checkyourskin/1902/in/10.png', '/mnt/data/raw/_melanoma/Checkyourskin/1902/in/17.png']]
#
#
# ==============================================
# KEY: (230.0, 509)
# LENGTH: 2
# ['2019-04-12 12:10:40', '2019-04-12 12:10:41']
# ['aquagenic keratoderma, right hand', 'aquagenic keratoderma, right hand']
# [['/mnt/data/raw/_melanoma/Checkyourskin/1903/in/16.png', '/mnt/data/raw/_melanoma/Checkyourskin/1903/in/13.png', '/mnt/data/raw/_melanoma/Checkyourskin/1903/in/12.png', '/mnt/data/raw/_melanoma/Checkyourskin/1903/in/39.png', '/mnt/data/raw/_melanoma/Checkyourskin/1903/in/11.png', '/mnt/data/raw/_melanoma/Checkyourskin/1903/in/14.png', '/mnt/data/raw/_melanoma/Checkyourskin/1903/in/38.png', '/mnt/data/raw/_melanoma/Checkyourskin/1903/in/15.png', '/mnt/data/raw/_melanoma/Checkyourskin/1903/in/10.png', '/mnt/data/raw/_melanoma/Checkyourskin/1903/in/17.png'], ['/mnt/data/raw/_melanoma/Checkyourskin/1904/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/1904/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/1904/in/G.png']]
#
#
# ==============================================
# KEY: (230.0, 510)
# LENGTH: 2
# ['2019-04-12 12:11:45', '2019-04-12 12:11:49']
# ['aquagenic keratoderma, right hand', 'aquagenic keratoderma, right hand']
# [['/mnt/data/raw/_melanoma/Checkyourskin/1905/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/1905/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/1905/in/G.png'], ['/mnt/data/raw/_melanoma/Checkyourskin/1906/in/16.png', '/mnt/data/raw/_melanoma/Checkyourskin/1906/in/13.png', '/mnt/data/raw/_melanoma/Checkyourskin/1906/in/12.png', '/mnt/data/raw/_melanoma/Checkyourskin/1906/in/39.png', '/mnt/data/raw/_melanoma/Checkyourskin/1906/in/11.png', '/mnt/data/raw/_melanoma/Checkyourskin/1906/in/14.png', '/mnt/data/raw/_melanoma/Checkyourskin/1906/in/38.png', '/mnt/data/raw/_melanoma/Checkyourskin/1906/in/15.png', '/mnt/data/raw/_melanoma/Checkyourskin/1906/in/10.png', '/mnt/data/raw/_melanoma/Checkyourskin/1906/in/17.png']]
#
#
# ==============================================
# KEY: (230.0, 511)
# LENGTH: 2
# ['2019-04-12 12:13:20', '2019-04-12 12:13:28']
# ['aquagenic keratoderma, left hand,CONTROL', 'aquagenic keratoderma, left hand,CONTROL']
# [['/mnt/data/raw/_melanoma/Checkyourskin/1907/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/1907/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/1907/in/G.png'], ['/mnt/data/raw/_melanoma/Checkyourskin/1908/in/16.png', '/mnt/data/raw/_melanoma/Checkyourskin/1908/in/13.png', '/mnt/data/raw/_melanoma/Checkyourskin/1908/in/12.png', '/mnt/data/raw/_melanoma/Checkyourskin/1908/in/39.png', '/mnt/data/raw/_melanoma/Checkyourskin/1908/in/11.png', '/mnt/data/raw/_melanoma/Checkyourskin/1908/in/14.png', '/mnt/data/raw/_melanoma/Checkyourskin/1908/in/38.png', '/mnt/data/raw/_melanoma/Checkyourskin/1908/in/15.png', '/mnt/data/raw/_melanoma/Checkyourskin/1908/in/10.png', '/mnt/data/raw/_melanoma/Checkyourskin/1908/in/17.png']]
#
#
# ==============================================
# KEY: (231.0, 512)
# LENGTH: 2
# ['2019-04-12 12:58:36', '2019-04-12 12:58:40']
# ['albinismus, right arm, flexor surface', 'albinismus, right arm, flexor surface']
# [['/mnt/data/raw/_melanoma/Checkyourskin/1909/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/1909/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/1909/in/G.png'], ['/mnt/data/raw/_melanoma/Checkyourskin/1910/in/16.png', '/mnt/data/raw/_melanoma/Checkyourskin/1910/in/13.png', '/mnt/data/raw/_melanoma/Checkyourskin/1910/in/12.png', '/mnt/data/raw/_melanoma/Checkyourskin/1910/in/39.png', '/mnt/data/raw/_melanoma/Checkyourskin/1910/in/11.png', '/mnt/data/raw/_melanoma/Checkyourskin/1910/in/14.png', '/mnt/data/raw/_melanoma/Checkyourskin/1910/in/38.png', '/mnt/data/raw/_melanoma/Checkyourskin/1910/in/15.png', '/mnt/data/raw/_melanoma/Checkyourskin/1910/in/10.png', '/mnt/data/raw/_melanoma/Checkyourskin/1910/in/17.png']]
#
#
# ==============================================
# KEY: (231.0, 513)
# LENGTH: 2
# ['2019-04-12 13:00:13', '2019-04-12 13:00:17']
# ['albinismus, right arm, extensor', 'albinismus, right arm, extensor']
# [['/mnt/data/raw/_melanoma/Checkyourskin/1911/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/1911/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/1911/in/G.png'], ['/mnt/data/raw/_melanoma/Checkyourskin/1912/in/16.png', '/mnt/data/raw/_melanoma/Checkyourskin/1912/in/13.png', '/mnt/data/raw/_melanoma/Checkyourskin/1912/in/12.png', '/mnt/data/raw/_melanoma/Checkyourskin/1912/in/39.png', '/mnt/data/raw/_melanoma/Checkyourskin/1912/in/11.png', '/mnt/data/raw/_melanoma/Checkyourskin/1912/in/14.png', '/mnt/data/raw/_melanoma/Checkyourskin/1912/in/38.png', '/mnt/data/raw/_melanoma/Checkyourskin/1912/in/15.png', '/mnt/data/raw/_melanoma/Checkyourskin/1912/in/10.png', '/mnt/data/raw/_melanoma/Checkyourskin/1912/in/17.png']]
#
#
# ==============================================
# KEY: (232.0, 514)
# LENGTH: 2
# ['2019-04-15 10:22:09', '2019-04-15 10:22:10']
# ['melanoma left scapula (5h)', 'melanoma left scapula (5h)']
# [['/mnt/data/raw/_melanoma/Checkyourskin/1913/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/1913/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/1913/in/G.png'], ['/mnt/data/raw/_melanoma/Checkyourskin/1914/in/16.png', '/mnt/data/raw/_melanoma/Checkyourskin/1914/in/13.png', '/mnt/data/raw/_melanoma/Checkyourskin/1914/in/12.png', '/mnt/data/raw/_melanoma/Checkyourskin/1914/in/39.png', '/mnt/data/raw/_melanoma/Checkyourskin/1914/in/11.png', '/mnt/data/raw/_melanoma/Checkyourskin/1914/in/14.png', '/mnt/data/raw/_melanoma/Checkyourskin/1914/in/38.png', '/mnt/data/raw/_melanoma/Checkyourskin/1914/in/15.png', '/mnt/data/raw/_melanoma/Checkyourskin/1914/in/10.png', '/mnt/data/raw/_melanoma/Checkyourskin/1914/in/17.png']]
#
#
# ==============================================
# KEY: (232.0, 515)
# LENGTH: 2
# ['2019-04-15 10:24:18', '2019-04-15 10:24:19']
# ['melanoma, satellite,  left scapula (3h)', 'melanoma, satellite,  left scapula (3h)']
# [['/mnt/data/raw/_melanoma/Checkyourskin/1915/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/1915/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/1915/in/G.png'], ['/mnt/data/raw/_melanoma/Checkyourskin/1916/in/16.png', '/mnt/data/raw/_melanoma/Checkyourskin/1916/in/13.png', '/mnt/data/raw/_melanoma/Checkyourskin/1916/in/12.png', '/mnt/data/raw/_melanoma/Checkyourskin/1916/in/39.png', '/mnt/data/raw/_melanoma/Checkyourskin/1916/in/11.png', '/mnt/data/raw/_melanoma/Checkyourskin/1916/in/14.png', '/mnt/data/raw/_melanoma/Checkyourskin/1916/in/38.png', '/mnt/data/raw/_melanoma/Checkyourskin/1916/in/15.png', '/mnt/data/raw/_melanoma/Checkyourskin/1916/in/10.png', '/mnt/data/raw/_melanoma/Checkyourskin/1916/in/17.png']]
#
#
# ==============================================
# KEY: (232.0, 516)
# LENGTH: 2
# ['2019-04-15 10:25:21', '2019-04-15 10:25:24']
# ['melanoma left scapula (11h)', 'melanoma left scapula (11h)']
# [['/mnt/data/raw/_melanoma/Checkyourskin/1917/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/1917/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/1917/in/G.png'], ['/mnt/data/raw/_melanoma/Checkyourskin/1918/in/16.png', '/mnt/data/raw/_melanoma/Checkyourskin/1918/in/13.png', '/mnt/data/raw/_melanoma/Checkyourskin/1918/in/12.png', '/mnt/data/raw/_melanoma/Checkyourskin/1918/in/39.png', '/mnt/data/raw/_melanoma/Checkyourskin/1918/in/11.png', '/mnt/data/raw/_melanoma/Checkyourskin/1918/in/14.png', '/mnt/data/raw/_melanoma/Checkyourskin/1918/in/38.png', '/mnt/data/raw/_melanoma/Checkyourskin/1918/in/15.png', '/mnt/data/raw/_melanoma/Checkyourskin/1918/in/10.png', '/mnt/data/raw/_melanoma/Checkyourskin/1918/in/17.png']]
#
#
# ==============================================
# KEY: (233.0, 517)
# LENGTH: 2
# ['2019-04-15 11:05:11', '2019-04-15 11:05:13']
# ['melanoma, thoracis (8h)', 'melanoma']
# [['/mnt/data/raw/_melanoma/Checkyourskin/1929/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/1929/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/1929/in/G.png'], ['/mnt/data/raw/_melanoma/Checkyourskin/1930/in/16.png', '/mnt/data/raw/_melanoma/Checkyourskin/1930/in/13.png', '/mnt/data/raw/_melanoma/Checkyourskin/1930/in/12.png', '/mnt/data/raw/_melanoma/Checkyourskin/1930/in/39.png', '/mnt/data/raw/_melanoma/Checkyourskin/1930/in/11.png', '/mnt/data/raw/_melanoma/Checkyourskin/1930/in/14.png', '/mnt/data/raw/_melanoma/Checkyourskin/1930/in/38.png', '/mnt/data/raw/_melanoma/Checkyourskin/1930/in/15.png', '/mnt/data/raw/_melanoma/Checkyourskin/1930/in/10.png', '/mnt/data/raw/_melanoma/Checkyourskin/1930/in/17.png']]
#
#
# ==============================================
# KEY: (233.0, 518)
# LENGTH: 2
# ['2019-04-15 11:06:06', '2019-04-15 11:06:06']
# ['melanoma, thoracis (2h)', 'melanoma, thoracis (2h)']
# [['/mnt/data/raw/_melanoma/Checkyourskin/1931/in/16.png', '/mnt/data/raw/_melanoma/Checkyourskin/1931/in/13.png', '/mnt/data/raw/_melanoma/Checkyourskin/1931/in/12.png', '/mnt/data/raw/_melanoma/Checkyourskin/1931/in/39.png', '/mnt/data/raw/_melanoma/Checkyourskin/1931/in/11.png', '/mnt/data/raw/_melanoma/Checkyourskin/1931/in/14.png', '/mnt/data/raw/_melanoma/Checkyourskin/1931/in/38.png', '/mnt/data/raw/_melanoma/Checkyourskin/1931/in/15.png', '/mnt/data/raw/_melanoma/Checkyourskin/1931/in/10.png', '/mnt/data/raw/_melanoma/Checkyourskin/1931/in/17.png'], ['/mnt/data/raw/_melanoma/Checkyourskin/1932/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/1932/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/1932/in/G.png']]
#
#
# ==============================================
# KEY: (234.0, 519)
# LENGTH: 2
# ['2019-04-15 12:38:53', '2019-04-15 12:38:54']
# ['subungualis suffusion (/melanoma?), right toe', 'subungualis suffusion (/melanoma?), right toe']
# [['/mnt/data/raw/_melanoma/Checkyourskin/1935/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/1935/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/1935/in/G.png'], ['/mnt/data/raw/_melanoma/Checkyourskin/1936/in/16.png', '/mnt/data/raw/_melanoma/Checkyourskin/1936/in/13.png', '/mnt/data/raw/_melanoma/Checkyourskin/1936/in/12.png', '/mnt/data/raw/_melanoma/Checkyourskin/1936/in/39.png', '/mnt/data/raw/_melanoma/Checkyourskin/1936/in/11.png', '/mnt/data/raw/_melanoma/Checkyourskin/1936/in/14.png', '/mnt/data/raw/_melanoma/Checkyourskin/1936/in/38.png', '/mnt/data/raw/_melanoma/Checkyourskin/1936/in/15.png', '/mnt/data/raw/_melanoma/Checkyourskin/1936/in/10.png', '/mnt/data/raw/_melanoma/Checkyourskin/1936/in/17.png']]
#
#
# ==============================================
# KEY: (235.0, 520)
# LENGTH: 2
# ['2019-04-15 13:36:23', '2019-04-15 13:36:24']
# ['Lentigo solaris', 'Lentigo solaris']
# [['/mnt/data/raw/_melanoma/Checkyourskin/1937/in/16.png', '/mnt/data/raw/_melanoma/Checkyourskin/1937/in/13.png', '/mnt/data/raw/_melanoma/Checkyourskin/1937/in/12.png', '/mnt/data/raw/_melanoma/Checkyourskin/1937/in/39.png', '/mnt/data/raw/_melanoma/Checkyourskin/1937/in/11.png', '/mnt/data/raw/_melanoma/Checkyourskin/1937/in/14.png', '/mnt/data/raw/_melanoma/Checkyourskin/1937/in/38.png', '/mnt/data/raw/_melanoma/Checkyourskin/1937/in/15.png', '/mnt/data/raw/_melanoma/Checkyourskin/1937/in/10.png', '/mnt/data/raw/_melanoma/Checkyourskin/1937/in/17.png'], ['/mnt/data/raw/_melanoma/Checkyourskin/1938/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/1938/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/1938/in/G.png']]
#
#
# ==============================================
# KEY: (236.0, 521)
# LENGTH: 2
# ['2019-04-17 12:33:40', '2019-04-17 12:33:40']
# ['scc? mm? posterior', 'mm? scc? posterior']
# [['/mnt/data/raw/_melanoma/Checkyourskin/1951/in/16.png', '/mnt/data/raw/_melanoma/Checkyourskin/1951/in/13.png', '/mnt/data/raw/_melanoma/Checkyourskin/1951/in/12.png', '/mnt/data/raw/_melanoma/Checkyourskin/1951/in/39.png', '/mnt/data/raw/_melanoma/Checkyourskin/1951/in/11.png', '/mnt/data/raw/_melanoma/Checkyourskin/1951/in/14.png', '/mnt/data/raw/_melanoma/Checkyourskin/1951/in/38.png', '/mnt/data/raw/_melanoma/Checkyourskin/1951/in/15.png', '/mnt/data/raw/_melanoma/Checkyourskin/1951/in/10.png', '/mnt/data/raw/_melanoma/Checkyourskin/1951/in/17.png'], ['/mnt/data/raw/_melanoma/Checkyourskin/1952/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/1952/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/1952/in/G.png']]
#
#
# ==============================================
# KEY: (236.0, 522)
# LENGTH: 2
# ['2019-04-17 12:35:22', '2019-04-17 12:35:23']
# ['scc? mm?', 'scc? mm? anterior']
# [['/mnt/data/raw/_melanoma/Checkyourskin/1953/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/1953/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/1953/in/G.png'], ['/mnt/data/raw/_melanoma/Checkyourskin/1954/in/16.png', '/mnt/data/raw/_melanoma/Checkyourskin/1954/in/13.png', '/mnt/data/raw/_melanoma/Checkyourskin/1954/in/12.png', '/mnt/data/raw/_melanoma/Checkyourskin/1954/in/39.png', '/mnt/data/raw/_melanoma/Checkyourskin/1954/in/11.png', '/mnt/data/raw/_melanoma/Checkyourskin/1954/in/14.png', '/mnt/data/raw/_melanoma/Checkyourskin/1954/in/38.png', '/mnt/data/raw/_melanoma/Checkyourskin/1954/in/15.png', '/mnt/data/raw/_melanoma/Checkyourskin/1954/in/10.png', '/mnt/data/raw/_melanoma/Checkyourskin/1954/in/17.png']]
#
#
# ==============================================
# KEY: (237.0, 523)
# LENGTH: 2
# ['2019-04-17 13:00:52', '2019-04-17 13:00:52']
# ['mm? on the trunk', 'mm? on the trunk']
# [['/mnt/data/raw/_melanoma/Checkyourskin/1955/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/1955/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/1955/in/G.png'], ['/mnt/data/raw/_melanoma/Checkyourskin/1956/in/16.png', '/mnt/data/raw/_melanoma/Checkyourskin/1956/in/13.png', '/mnt/data/raw/_melanoma/Checkyourskin/1956/in/12.png', '/mnt/data/raw/_melanoma/Checkyourskin/1956/in/39.png', '/mnt/data/raw/_melanoma/Checkyourskin/1956/in/11.png', '/mnt/data/raw/_melanoma/Checkyourskin/1956/in/14.png', '/mnt/data/raw/_melanoma/Checkyourskin/1956/in/38.png', '/mnt/data/raw/_melanoma/Checkyourskin/1956/in/15.png', '/mnt/data/raw/_melanoma/Checkyourskin/1956/in/10.png', '/mnt/data/raw/_melanoma/Checkyourskin/1956/in/17.png']]
#
#
# ==============================================

# %%
freq_dict
# Out:
# {'1': 82, '2': 411, '4': 17, '3': 3}

# %% [markdown]
# {'1': 82, '2': 429, '3': 1, '4': 1}
# Means that we have 82 sets of photos taken either in UV or in R+G+IR
# and 429 sets of photos taken both in UV and R+G+IR
#
# Let's check that among those 429 there are always UV and R+G+IR sets.

# %%
df_cys_sorted_gr = df_cys_sorted.groupby(['analyzePatientId','group'])


def get_colors(list_of_paths):
    '''
    this function just gets list of paths, extracts pure filenames
    and then looks for files starting with R / IR / G / UV or number / white and counts them
    other filenames are just printed.
    
    It basically returns frequencies of images colors based on files names.
    '''
    freq_dict = {'r': 0, 'g': 0, 'ir': 0, 'uv':0}
    for l in list_of_paths:
        name = os.path.basename(l)
        if name.lower().startswith('r'):
            freq_dict['r'] = freq_dict['r'] + 1
        elif name.lower().startswith('g'):
            freq_dict['g'] = freq_dict['g'] + 1
        elif name.lower().startswith('ir'):
            freq_dict['ir'] = freq_dict['ir'] + 1
        elif name.lower().startswith('uv'):
            freq_dict['uv'] = freq_dict['uv'] + 1
        elif name[0:1].isnumeric():
            freq_dict['uv'] = freq_dict['uv'] + 1
            
    return freq_dict

dicts_list = []
for key, item in df_cys_sorted_gr:
    l = df_cys_sorted_gr.get_group(key)['images_paths_list'].tolist()
    if len(l) == 2:
        colors_freq = {}
        for key2, item2 in df_cys_sorted_gr.get_group(key).iterrows():
            files_paths = item2['images_paths_list']
            colors_freq.update(get_colors(files_paths))
        dicts_list.append(colors_freq)

# %%
if '2' in str(dicts_list) or '3' in str(dicts_list) or '4' in str(dicts_list) or '5' in str(dicts_list):
    print('We have a problem - multiple UV or R/IR/G images!!!!')
else:
    print('All good!')
# Out:
# All good!

# %%
from tqdm.notebook import tqdm
    
def collect_grouped_file_paths_cys(df_cys_sorted):
    from datetime import datetime
    date_time_format = '%Y-%m-%d %H:%M:%S'
    
    def get_colors(list_of_lists_of_paths):
        '''
        this function just gets list of paths, extracts pure filenames
        and then looks for files starting with R / IR / G / UV or number / white and counts them
        other filenames are just printed.

        It basically returns frequencies of images colors based on files names.
        '''
        full_freq = {'r': 0, 'g': 0, 'ir': 0, 'uv':0, 'white': 0}
        dict_list = []
        bad_list_flag = False
        for lst in list_of_lists_of_paths:
            freq_dict = {'r': 0, 'g': 0, 'ir': 0, 'uv':0, 'white': 0}
            for l in lst:
                name = os.path.basename(l)
                if name.lower().startswith('r'):
                    freq_dict['r'] = freq_dict['r'] + 1
                    full_freq['r'] = full_freq['r'] + 1
                elif name.lower().startswith('g'):
                    freq_dict['g'] = freq_dict['g'] + 1
                    full_freq['g'] = full_freq['g'] + 1
                elif name.lower().startswith('ir'):
                    freq_dict['ir'] = freq_dict['ir'] + 1
                    full_freq['ir'] = full_freq['ir'] + 1
                elif name.lower().startswith('white'):
                    freq_dict['white'] = freq_dict['white'] + 1
                    full_freq['white'] = full_freq['white'] + 1
                elif name.lower().startswith('uv'):
                    freq_dict['uv'] = freq_dict['uv'] + 1
                    full_freq['uv'] = full_freq['uv'] + 1
                elif name[0:1].isnumeric():
                    freq_dict['uv'] = freq_dict['uv'] + 1
                    full_freq['uv'] = full_freq['uv'] + 1
                else:
                    print('no match! ', l)
                    bad_list_flag = True
            dict_list.append(freq_dict)
        return full_freq, dict_list, bad_list_flag
    
    def __extract_non_uv_files_paths(files_list):
        d = dict()
        for f_path in files_list:
#             print('2', l)
            f = os.path.basename(f_path)
            if f.lower().startswith('r'):
                d['r'] = f_path
            elif f.lower().startswith('ir'):
                d['ir'] = f_path
            elif f.lower().startswith('g'):
                d['g'] = f_path
            elif f.lower().startswith('white'):
                d['white'] = f_path
            else:
                print('unknown file type (R/IR/G):', f)
        return d

    root_folders = dict()
    group_from = df_cys_sorted['group'].min()
    group_to = df_cys_sorted['group'].max() + 1
    for i in tqdm(range(group_from, group_to)):
        group = df_cys_sorted.loc[df_cys_sorted['group'] == i]
        print('group.shape', group.shape)
        try:
            files_list = group['images_paths_list'].tolist()
#             print(files_list)
            print('files_list', files_list)
            col_freq, dict_list, bad_list_flag = get_colors(files_list)

            if bad_list_flag == False:

                i = 0

                non_uv_files_paths = None
                non_uv_correlation_id = None
                uv_files_paths = None
                uv_correlation_id = None
                code = None
                orig_parent_folder = None
                created_date = None

                for i in range(len(files_list)):
                    file_group = files_list[i]
                    file_group_col_freq = dict_list[i]
                    group_index = group.index[i] 
                    if file_group_col_freq['r'] > 0 and file_group_col_freq['g'] > 0 and file_group_col_freq['ir'] > 0:
                        non_uv_files_paths = __extract_non_uv_files_paths(file_group)
                        non_uv_correlation_id = group.at[group_index, 'measurementSetId']
                        orig_parent_folder = Path(Path(file_group[0]).parent).parent
                    else:
                        print('file_group', file_group)
                        uv_files_paths = file_group
                        uv_correlation_id = group.at[group_index, 'measurementSetId']
                        orig_parent_folder = Path(Path(file_group[0]).parent).parent

                    code_series = group['code'].unique().tolist()
                    print('code_series', code_series)

                    if ('') in code_series: 
                        code_series.remove('')
                    if ('-') in code_series: 
                        code_series.remove('-')

                    if len(code_series) == 0:
                        code = 'benign'
                    elif len(code_series) == 1:
                        code = code_series[0]
                    else:
                        print('ERROR Multiple codes!!!!', code_series)
                    i = i + 1
                    
                    new_created_date = datetime.strptime(group['measurementDateCreated'].tolist()[0], date_time_format)
                    if created_date is None:
                        created_date = new_created_date
                    else:
                        created_date = min(created_date, new_created_date)

in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/1953/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/1953/in/G.png'], ['/mnt/data/raw/_melanoma/Checkyourskin/1954/in/16.png', '/mnt/data/raw/_melanoma/Checkyourskin/1954/in/13.png', '/mnt/data/raw/_melanoma/Checkyourskin/1954/in/12.png', '/mnt/data/raw/_melanoma/Checkyourskin/1954/in/39.png', '/mnt/data/raw/_melanoma/Checkyourskin/1954/in/11.png', '/mnt/data/raw/_melanoma/Checkyourskin/1954/in/14.png', '/mnt/data/raw/_melanoma/Checkyourskin/1954/in/38.png', '/mnt/data/raw/_melanoma/Checkyourskin/1954/in/15.png', '/mnt/data/raw/_melanoma/Checkyourskin/1954/in/10.png', '/mnt/data/raw/_melanoma/Checkyourskin/1954/in/17.png']]
# code_series [nan]
# file_group ['/mnt/data/raw/_melanoma/Checkyourskin/1954/in/16.png', '/mnt/data/raw/_melanoma/Checkyourskin/1954/in/13.png', '/mnt/data/raw/_melanoma/Checkyourskin/1954/in/12.png', '/mnt/data/raw/_melanoma/Checkyourskin/1954/in/39.png', '/mnt/data/raw/_melanoma/Checkyourskin/1954/in/11.png', '/mnt/data/raw/_melanoma/Checkyourskin/1954/in/14.png', '/mnt/data/raw/_melanoma/Checkyourskin/1954/in/38.png', '/mnt/data/raw/_melanoma/Checkyourskin/1954/in/15.png', '/mnt/data/raw/_melanoma/Checkyourskin/1954/in/10.png', '/mnt/data/raw/_melanoma/Checkyourskin/1954/in/17.png']
# code_series [nan]
# group.shape (2, 23)
# files_list [['/mnt/data/raw/_melanoma/Checkyourskin/1955/in/R.png', '/mnt/data/raw/_melanoma/Checkyourskin/1955/in/IR.png', '/mnt/data/raw/_melanoma/Checkyourskin/1955/in/G.png'], ['/mnt/data/raw/_melanoma/Checkyourskin/1956/in/16.png', '/mnt/data/raw/_melanoma/Checkyourskin/1956/in/13.png', '/mnt/data/raw/_melanoma/Checkyourskin/1956/in/12.png', '/mnt/data/raw/_melanoma/Checkyourskin/1956/in/39.png', '/mnt/data/raw/_melanoma/Checkyourskin/1956/in/11.png', '/mnt/data/raw/_melanoma/Checkyourskin/1956/in/14.png', '/mnt/data/raw/_melanoma/Checkyourskin/1956/in/38.png', '/mnt/data/raw/_melanoma/Checkyourskin/1956/in/15.png', '/mnt/data/raw/_melanoma/Checkyourskin/1956/in/10.png', '/mnt/data/raw/_melanoma/Checkyourskin/1956/in/17.png']]
# code_series [nan]
# file_group ['/mnt/data/raw/_melanoma/Checkyourskin/1956/in/16.png', '/mnt/data/raw/_melanoma/Checkyourskin/1956/in/13.png', '/mnt/data/raw/_melanoma/Checkyourskin/1956/in/12.png', '/mnt/data/raw/_melanoma/Checkyourskin/1956/in/39.png', '/mnt/data/raw/_melanoma/Checkyourskin/1956/in/11.png', '/mnt/data/raw/_melanoma/Checkyourskin/1956/in/14.png', '/mnt/data/raw/_melanoma/Checkyourskin/1956/in/38.png', '/mnt/data/raw/_melanoma/Checkyourskin/1956/in/15.png', '/mnt/data/raw/_melanoma/Checkyourskin/1956/in/10.png', '/mnt/data/raw/_melanoma/Checkyourskin/1956/in/17.png']
# code_series [nan]

# %%
# root_folders

# %%
target_cys_img_folder = os.path.abspath('../../data/interim/_melanoma_20200728/checkyourskin')
target_cys_img_folder
# Out:
# '/mnt/data/interim/_melanoma_20200728/checkyourskin'

# %%
root_folders
# Out:
# {PosixPath('/mnt/data/raw/_melanoma/Checkyourskin/306'): {'codes': [nan],
#   'r': '/mnt/data/raw/_melanoma/Checkyourskin/306/in/R.png',
#   'ir': '/mnt/data/raw/_melanoma/Checkyourskin/306/in/IR.png',
#   'g': '/mnt/data/raw/_melanoma/Checkyourskin/306/in/G.png',
#   'non_uv_corr_id': '4f534c5035d6bc305cf222e3fc7c18b0',
#   'datetime': '2018-12-12_18-11-57'},
#  PosixPath('/mnt/data/raw/_melanoma/Checkyourskin/307'): {'codes': [nan],
#   'r': '/mnt/data/raw/_melanoma/Checkyourskin/307/in/R.png',
#   'ir': '/mnt/data/raw/_melanoma/Checkyourskin/307/in/IR.png',
#   'g': '/mnt/data/raw/_melanoma/Checkyourskin/307/in/G.png',
#   'non_uv_corr_id': '40f41941019f92bdc34cc324026fe831',
#   'datetime': '2018-12-12_18-39-23'},
#  PosixPath('/mnt/data/raw/_melanoma/Checkyourskin/309'): {'codes': [nan],
#   'r': '/mnt/data/raw/_melanoma/Checkyourskin/309/in/R.png',
#   'ir': '/mnt/data/raw/_melanoma/Checkyourskin/309/in/IR.png',
#   'g': '/mnt/data/raw/_melanoma/Checkyourskin/309/in/G.png',
#   'non_uv_corr_id': '30f589534eed314b2bdbcd41925ab015',
#   'datetime': '2018-12-12_18-42-08'},
#  PosixPath('/mnt/data/raw/_melanoma/Checkyourskin/310'): {'codes': [nan],
#   'r': '/mnt/data/raw/_melanoma/Checkyourskin/310/in/R.png',
#   'ir': '/mnt/data/raw/_melanoma/Checkyourskin/310/in/IR.png',
#   'g': '/mnt/data/raw/_melanoma/Checkyourskin/310/in/G.png',
#   'non_uv_corr_id': '0b021da605d6f50141ed77575d9c07a3',
#   'datetime': '2018-12-12_19-08-01'},
#  PosixPath('/mnt/data/raw/_melanoma/Checkyourskin/311'): {'codes': [nan],
#   'r': '/mnt/data/raw/_melanoma/Checkyourskin/311/in/R.png',
#   'ir': '/mnt/data/raw/_melanoma/Checkyourskin/311/in/IR.png',
#   'g': '/mnt/data/raw/_melanoma/Checkyourskin/311/in/G.png',
#   'non_uv_corr_id': '8859f02a10097a6bd9bdb0e6beadc5b4',
#   'datetime': '2018-12-12_19-16-47'},
#  PosixPath('/mnt/data/raw/_melanoma/Checkyourskin/312'): {'codes': [nan],
#   'r': '/mnt/data/raw/_melanoma/Checkyourskin/312/in/R.png',
#   'ir': '/mnt/data/raw/_melanoma/Checkyourskin/312/in/IR.png',
#   'g': '/mnt/data/raw/_melanoma/Checkyourskin/312/in/G.png',
#   'non_uv_corr_id': '4bb233991e962d6aa463e732abde04a0',
#   'datetime': '2018-12-12_19-30-17'},
#  PosixPath('/mnt/data/raw/_melanoma/Checkyourskin/314'): {'codes': [nan],
#   'r': '/mnt/data/raw/_melanoma/Checkyourskin/314/in/R.png',
#   'ir': '/mnt/data/raw/_melanoma/Checkyourskin/314/in/IR.png',
#   'g': '/mnt/data/raw/_melanoma/Checkyourskin/314/in/G.png',
#   'non_uv_corr_id': '04165715a2273d182a0f097f8a280b5b',
#   'datetime': '2018-12-12_20-03-52'},
#  PosixPath('/mnt/data/raw/_melanoma/Checkyourskin/315'): {'codes': [nan],
#   'uv': ['/mnt/data/raw/_melanoma/Checkyourskin/315/in/48.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/315/in/16.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/315/in/13.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/315/in/12.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/315/in/49.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/315/in/11.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/315/in/14.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/315/in/15.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/315/in/10.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/315/in/17.png'],
#   'uv_corr_id': '08f51968700f25f3dc29904cfdd058c0',
#   'datetime': '2018-12-12_20-13-50'},
#  PosixPath('/mnt/data/raw/_melanoma/Checkyourskin/316'): {'codes': [nan],
#   'r': '/mnt/data/raw/_melanoma/Checkyourskin/316/in/R.png',
#   'ir': '/mnt/data/raw/_melanoma/Checkyourskin/316/in/IR.png',
#   'g': '/mnt/data/raw/_melanoma/Checkyourskin/316/in/G.png',
#   'non_uv_corr_id': 'd51ac75a457662820318dd287a7db9a5',
#   'datetime': '2018-12-13_12-47-35'},
#  PosixPath('/mnt/data/raw/_melanoma/Checkyourskin/317'): {'codes': [nan],
#   'r': '/mnt/data/raw/_melanoma/Checkyourskin/317/in/R.png',
#   'ir': '/mnt/data/raw/_melanoma/Checkyourskin/317/in/IR.png',
#   'g': '/mnt/data/raw/_melanoma/Checkyourskin/317/in/G.png',
#   'non_uv_corr_id': '982782eaa4a1a65c10e39e0cdffc9d91',
#   'datetime': '2018-12-13_12-51-17'},
#  PosixPath('/mnt/data/raw/_melanoma/Checkyourskin/318'): {'codes': [nan],
#   'uv': ['/mnt/data/raw/_melanoma/Checkyourskin/318/in/48.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/318/in/16.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/318/in/13.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/318/in/12.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/318/in/49.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/318/in/11.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/318/in/14.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/318/in/15.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/318/in/10.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/318/in/17.png'],
#   'uv_corr_id': 'ef2c5251d0b2d94ee645815be7f5d9e2',
#   'datetime': '2018-12-13_12-58-03'},
#  PosixPath('/mnt/data/raw/_melanoma/Checkyourskin/319'): {'codes': [nan],
#   'uv': ['/mnt/data/raw/_melanoma/Checkyourskin/319/in/48.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/319/in/16.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/319/in/13.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/319/in/12.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/319/in/49.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/319/in/11.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/319/in/14.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/319/in/15.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/319/in/10.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/319/in/17.png'],
#   'uv_corr_id': 'c9d2946efa512756766085e219ae60bc',
#   'datetime': '2018-12-13_13-01-32'},
#  PosixPath('/mnt/data/raw/_melanoma/Checkyourskin/320'): {'codes': [nan],
#   'r': '/mnt/data/raw/_melanoma/Checkyourskin/320/in/R.png',
#   'ir': '/mnt/data/raw/_melanoma/Checkyourskin/320/in/IR.png',
#   'g': '/mnt/data/raw/_melanoma/Checkyourskin/320/in/G.png',
#   'non_uv_corr_id': '7b5e2c498d65a187bad167e3d93381dd',
#   'datetime': '2018-12-13_14-54-39'},
#  PosixPath('/mnt/data/raw/_melanoma/Checkyourskin/321'): {'codes': [nan],
#   'uv': ['/mnt/data/raw/_melanoma/Checkyourskin/321/in/48.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/321/in/16.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/321/in/13.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/321/in/12.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/321/in/49.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/321/in/11.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/321/in/14.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/321/in/15.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/321/in/10.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/321/in/17.png'],
#   'uv_corr_id': '49fb8f4e3007f91a98c6795e701c6626',
#   'datetime': '2018-12-13_14-55-24'},
#  PosixPath('/mnt/data/raw/_melanoma/Checkyourskin/322'): {'codes': [nan],
#   'r': '/mnt/data/raw/_melanoma/Checkyourskin/322/in/R.png',
#   'ir': '/mnt/data/raw/_melanoma/Checkyourskin/322/in/IR.png',
#   'g': '/mnt/data/raw/_melanoma/Checkyourskin/322/in/G.png',
#   'non_uv_corr_id': 'c1de4f646b6d9e3c7dab4c4d03bd9b62',
#   'datetime': '2018-12-13_14-57-29'},
#  PosixPath('/mnt/data/raw/_melanoma/Checkyourskin/324'): {'codes': [nan],
#   'r': '/mnt/data/raw/_melanoma/Checkyourskin/324/in/R.png',
#   'ir': '/mnt/data/raw/_melanoma/Checkyourskin/324/in/IR.png',
#   'g': '/mnt/data/raw/_melanoma/Checkyourskin/324/in/G.png',
#   'non_uv_corr_id': 'fe3a8a775d8bb5786f8dda57c7add649',
#   'datetime': '2018-12-13_15-16-35'},
#  PosixPath('/mnt/data/raw/_melanoma/Checkyourskin/325'): {'codes': [nan],
#   'r': '/mnt/data/raw/_melanoma/Checkyourskin/325/in/R.png',
#   'ir': '/mnt/data/raw/_melanoma/Checkyourskin/325/in/IR.png',
#   'g': '/mnt/data/raw/_melanoma/Checkyourskin/325/in/G.png',
#   'non_uv_corr_id': '01dc306d0e63023aab69589680e798ba',
#   'datetime': '2018-12-13_15-49-34'},
#  PosixPath('/mnt/data/raw/_melanoma/Checkyourskin/326'): {'codes': [nan],
#   'r': '/mnt/data/raw/_melanoma/Checkyourskin/326/in/R.png',
#   'ir': '/mnt/data/raw/_melanoma/Checkyourskin/326/in/IR.png',
#   'g': '/mnt/data/raw/_melanoma/Checkyourskin/326/in/G.png',
#   'non_uv_corr_id': '216ae48b685b57fcbd6a2a5ce3c7114a',
#   'datetime': '2018-12-13_15-53-27'},
#  PosixPath('/mnt/data/raw/_melanoma/Checkyourskin/327'): {'codes': [nan],
#   'r': '/mnt/data/raw/_melanoma/Checkyourskin/327/in/R.png',
#   'ir': '/mnt/data/raw/_melanoma/Checkyourskin/327/in/IR.png',
#   'g': '/mnt/data/raw/_melanoma/Checkyourskin/327/in/G.png',
#   'non_uv_corr_id': 'd6487014b6691fad79e1a6a67f66141c',
#   'datetime': '2018-12-13_15-56-15'},
#  PosixPath('/mnt/data/raw/_melanoma/Checkyourskin/328'): {'codes': [nan],
#   'r': '/mnt/data/raw/_melanoma/Checkyourskin/328/in/R.png',
#   'ir': '/mnt/data/raw/_melanoma/Checkyourskin/328/in/IR.png',
#   'g': '/mnt/data/raw/_melanoma/Checkyourskin/328/in/G.png',
#   'non_uv_corr_id': 'e232c79633122371273c72182617d0af',
#   'datetime': '2018-12-13_15-58-27'},
#  PosixPath('/mnt/data/raw/_melanoma/Checkyourskin/329'): {'codes': [nan],
#   'uv': ['/mnt/data/raw/_melanoma/Checkyourskin/329/in/48.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/329/in/16.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/329/in/13.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/329/in/12.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/329/in/49.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/329/in/11.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/329/in/14.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/329/in/15.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/329/in/10.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/329/in/17.png'],
#   'uv_corr_id': '81345d9e30e8ddeaa551a903974e69e7',
#   'datetime': '2018-12-13_16-02-50'},
#  PosixPath('/mnt/data/raw/_melanoma/Checkyourskin/342'): {'codes': [nan],
#   'r': '/mnt/data/raw/_melanoma/Checkyourskin/342/in/R.png',
#   'ir': '/mnt/data/raw/_melanoma/Checkyourskin/342/in/IR.png',
#   'g': '/mnt/data/raw/_melanoma/Checkyourskin/342/in/G.png',
#   'non_uv_corr_id': '548c6a064ded6afcad805275f665dc5b',
#   'datetime': '2018-12-17_13-14-56'},
#  PosixPath('/mnt/data/raw/_melanoma/Checkyourskin/343'): {'codes': [nan],
#   'r': '/mnt/data/raw/_melanoma/Checkyourskin/343/in/R.png',
#   'ir': '/mnt/data/raw/_melanoma/Checkyourskin/343/in/IR.png',
#   'g': '/mnt/data/raw/_melanoma/Checkyourskin/343/in/G.png',
#   'non_uv_corr_id': '75ff94ecb65ecd1f42d2153053f22e0c',
#   'datetime': '2018-12-17_13-16-34'},
#  PosixPath('/mnt/data/raw/_melanoma/Checkyourskin/344'): {'codes': [nan],
#   'r': '/mnt/data/raw/_melanoma/Checkyourskin/344/in/R.png',
#   'ir': '/mnt/data/raw/_melanoma/Checkyourskin/344/in/IR.png',
#   'g': '/mnt/data/raw/_melanoma/Checkyourskin/344/in/G.png',
#   'non_uv_corr_id': 'e52c432cdca4c07b3d53023ccaddb2bf',
#   'datetime': '2018-12-17_13-28-44'},
#  PosixPath('/mnt/data/raw/_melanoma/Checkyourskin/345'): {'codes': [nan],
#   'r': '/mnt/data/raw/_melanoma/Checkyourskin/345/in/R.png',
#   'ir': '/mnt/data/raw/_melanoma/Checkyourskin/345/in/IR.png',
#   'g': '/mnt/data/raw/_melanoma/Checkyourskin/345/in/G.png',
#   'non_uv_corr_id': '34df6a8d8b378471d7852a7c2b2c0430',
#   'datetime': '2018-12-17_14-05-25'},
#  PosixPath('/mnt/data/raw/_melanoma/Checkyourskin/346'): {'codes': [nan],
#   'r': '/mnt/data/raw/_melanoma/Checkyourskin/346/in/R.png',
#   'ir': '/mnt/data/raw/_melanoma/Checkyourskin/346/in/IR.png',
#   'g': '/mnt/data/raw/_melanoma/Checkyourskin/346/in/G.png',
#   'non_uv_corr_id': '653e52f99ac41eef5eb62ca868f83c91',
#   'datetime': '2018-12-17_14-23-45'},
#  PosixPath('/mnt/data/raw/_melanoma/Checkyourskin/347'): {'codes': [nan],
#   'r': '/mnt/data/raw/_melanoma/Checkyourskin/347/in/R.png',
#   'ir': '/mnt/data/raw/_melanoma/Checkyourskin/347/in/IR.png',
#   'g': '/mnt/data/raw/_melanoma/Checkyourskin/347/in/G.png',
#   'non_uv_corr_id': '3972e867f77ea3973d688b40484e511c',
#   'datetime': '2018-12-17_14-27-04'},
#  PosixPath('/mnt/data/raw/_melanoma/Checkyourskin/348'): {'codes': [nan],
#   'r': '/mnt/data/raw/_melanoma/Checkyourskin/348/in/R.png',
#   'ir': '/mnt/data/raw/_melanoma/Checkyourskin/348/in/IR.png',
#   'g': '/mnt/data/raw/_melanoma/Checkyourskin/348/in/G.png',
#   'non_uv_corr_id': '2037752031ef9a54594fe75c73d0a983',
#   'datetime': '2018-12-17_16-43-45'},
#  PosixPath('/mnt/data/raw/_melanoma/Checkyourskin/349'): {'codes': [nan],
#   'r': '/mnt/data/raw/_melanoma/Checkyourskin/349/in/R.png',
#   'ir': '/mnt/data/raw/_melanoma/Checkyourskin/349/in/IR.png',
#   'g': '/mnt/data/raw/_melanoma/Checkyourskin/349/in/G.png',
#   'non_uv_corr_id': '037604f29b9ac0d6bedc2e7b824a4726',
#   'datetime': '2018-12-17_16-44-43'},
#  PosixPath('/mnt/data/raw/_melanoma/Checkyourskin/350'): {'codes': [nan],
#   'r': '/mnt/data/raw/_melanoma/Checkyourskin/350/in/R.png',
#   'ir': '/mnt/data/raw/_melanoma/Checkyourskin/350/in/IR.png',
#   'g': '/mnt/data/raw/_melanoma/Checkyourskin/350/in/G.png',
#   'non_uv_corr_id': 'd1c1096cf4aa2bf5457a82487e87fb29',
#   'datetime': '2018-12-17_16-54-24'},
#  PosixPath('/mnt/data/raw/_melanoma/Checkyourskin/351'): {'codes': [nan],
#   'r': '/mnt/data/raw/_melanoma/Checkyourskin/351/in/R.png',
#   'ir': '/mnt/data/raw/_melanoma/Checkyourskin/351/in/IR.png',
#   'g': '/mnt/data/raw/_melanoma/Checkyourskin/351/in/G.png',
#   'non_uv_corr_id': '22f5b9db0400fc371f9123904d0d3596',
#   'datetime': '2018-12-17_16-57-50'},
#  PosixPath('/mnt/data/raw/_melanoma/Checkyourskin/393'): {'codes': [nan],
#   'r': '/mnt/data/raw/_melanoma/Checkyourskin/393/in/R.png',
#   'ir': '/mnt/data/raw/_melanoma/Checkyourskin/393/in/IR.png',
#   'g': '/mnt/data/raw/_melanoma/Checkyourskin/393/in/G.png',
#   'non_uv_corr_id': 'd65e8dde5ee3c964851e4a96c7b6c5ca',
#   'datetime': '2018-12-30_15-29-19'},
#  PosixPath('/mnt/data/raw/_melanoma/Checkyourskin/394'): {'codes': [nan],
#   'r': '/mnt/data/raw/_melanoma/Checkyourskin/394/in/R.png',
#   'ir': '/mnt/data/raw/_melanoma/Checkyourskin/394/in/IR.png',
#   'g': '/mnt/data/raw/_melanoma/Checkyourskin/394/in/G.png',
#   'non_uv_corr_id': '67edb36e51e6cdca1b53884a9208bf81',
#   'datetime': '2018-12-30_15-32-39'},
#  PosixPath('/mnt/data/raw/_melanoma/Checkyourskin/395'): {'codes': [nan],
#   'r': '/mnt/data/raw/_melanoma/Checkyourskin/395/in/R.png',
#   'ir': '/mnt/data/raw/_melanoma/Checkyourskin/395/in/IR.png',
#   'g': '/mnt/data/raw/_melanoma/Checkyourskin/395/in/G.png',
#   'non_uv_corr_id': '83cbe9391011ff0f1c40be10f94ec3d5',
#   'datetime': '2018-12-30_15-52-10'},
#  PosixPath('/mnt/data/raw/_melanoma/Checkyourskin
in/16.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/1951/in/13.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/1951/in/12.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/1951/in/39.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/1951/in/11.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/1951/in/14.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/1951/in/38.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/1951/in/15.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/1951/in/10.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/1951/in/17.png'],
#   'uv_corr_id': '4f90ffa1e1fd275f1fa76969b47a8e35',
#   'r': '/mnt/data/raw/_melanoma/Checkyourskin/1952/in/R.png',
#   'ir': '/mnt/data/raw/_melanoma/Checkyourskin/1952/in/IR.png',
#   'g': '/mnt/data/raw/_melanoma/Checkyourskin/1952/in/G.png',
#   'non_uv_corr_id': '6c6f7a2bfdb4f259c7b028008285f369',
#   'datetime': '2019-04-17_12-33-40'},
#  PosixPath('/mnt/data/raw/_melanoma/Checkyourskin/1954'): {'codes': [nan],
#   'uv': ['/mnt/data/raw/_melanoma/Checkyourskin/1954/in/16.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/1954/in/13.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/1954/in/12.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/1954/in/39.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/1954/in/11.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/1954/in/14.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/1954/in/38.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/1954/in/15.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/1954/in/10.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/1954/in/17.png'],
#   'uv_corr_id': '76371e36ff93b75347ecf27435fc8e86',
#   'r': '/mnt/data/raw/_melanoma/Checkyourskin/1953/in/R.png',
#   'ir': '/mnt/data/raw/_melanoma/Checkyourskin/1953/in/IR.png',
#   'g': '/mnt/data/raw/_melanoma/Checkyourskin/1953/in/G.png',
#   'non_uv_corr_id': 'e91d25e53de55a07af2d8ad956f321e7',
#   'datetime': '2019-04-17_12-35-22'},
#  PosixPath('/mnt/data/raw/_melanoma/Checkyourskin/1956'): {'codes': [nan],
#   'uv': ['/mnt/data/raw/_melanoma/Checkyourskin/1956/in/16.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/1956/in/13.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/1956/in/12.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/1956/in/39.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/1956/in/11.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/1956/in/14.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/1956/in/38.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/1956/in/15.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/1956/in/10.png',
#    '/mnt/data/raw/_melanoma/Checkyourskin/1956/in/17.png'],
#   'uv_corr_id': '8738c26fde59684bf0d66ccc2d34606e',
#   'r': '/mnt/data/raw/_melanoma/Checkyourskin/1955/in/R.png',
#   'ir': '/mnt/data/raw/_melanoma/Checkyourskin/1955/in/IR.png',
#   'g': '/mnt/data/raw/_melanoma/Checkyourskin/1955/in/G.png',
#   'non_uv_corr_id': '60a618fed5c9cf86f9b5b327b515ecef',
#   'datetime': '2019-04-17_13-00-52'}}

# %%
import uuid
import shutil
import os
import math
import collections

for k, v in root_folders.items():
    
    print('k,v-->', k, v['codes'])
    if isinstance(v['codes'], collections.Iterable):
        if len(v['codes']) == 0:
            code = 'benign'
        else:
            _v = v['codes'][0]
            _v = str(_v).strip()
            if _v == 'None' or _v == 'nan':
                code = 'nan'
            else:
                code = _v

    else:
        code = 'na_error2'
     
    if 'r' in v:
        src_r_path = v['r']
        src_ir_path = v['ir']
        src_g_path = v['g']
        folders_list = ['r', 'ir', 'g']
        measurements_list = [v['non_uv_corr_id'], v['non_uv_corr_id'], v['non_uv_corr_id']]
    else:
        src_r_path = None
        src_g_path = None
        src_ir_path = None
        
    if 'white' in v:
        src_white_path = v['white']
        folders_list.append('white')
        measurements_list.append(v['non_uv_corr_id'])
    else:
        src_white_path = None
        
    if 'uv' in v:
        src_uv_path = v['uv']
        folders_list.append('uv')
        measurements_list.append(v['uv_corr_id'])
    else:
        src_uv_path = None
        
    
    if src_r_path is None:
        print('R / IR / G is missing!!!')
    if src_white_path is None:
        print('White is missing!!!')
    if src_uv_path is None:
        print('UV is missing!!!') 
    
    date_time = v['datetime']
    target_parent_folder = os.path.join(target_cys_img_folder, code, date_time)

    # prepare folders
    if src_r_path is not None:
        os.makedirs(os.path.join(target_parent_folder, 'r'))
        os.makedirs(os.path.join(target_parent_folder, 'ir'))
        os.makedirs(os.path.join(target_parent_folder, 'g'))

        shutil.copy(src_r_path, os.path.join(target_parent_folder, 'r', os.path.basename(src_r_path)))
        shutil.copy(src_ir_path, os.path.join(target_parent_folder, 'ir', os.path.basename(src_ir_path)))
        shutil.copy(src_g_path, os.path.join(target_parent_folder, 'g', os.path.basename(src_g_path)))
    if src_white_path is not None:
        os.makedirs(os.path.join(target_parent_folder, 'white'))
        shutil.copy(src_white_path, os.path.join(target_parent_folder, 'white', os.path.basename(src_white_path)))
    if src_uv_paths is not None:
        os.makedirs(os.path.join(target_parent_folder, 'uv'))
        for src_uv_path in src_uv_paths:
            shutil.copy(src_uv_path, os.path.join(target_parent_folder, 'uv', os.path.basename(src_uv_path)))
    
    df_meta = pd.DataFrame({'measurementSetId': measurements_list, 'folder': folders_list})
    df_meta.to_csv(os.path.join(target_parent_folder, 'correlations.csv'))
# Out:
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin
['PXE']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1415 ['C44']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1417 ['C44']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1419 ['L98.8']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1421 [nan]
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1423 [nan]
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1425 ['L81.4']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1427 [None]
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1429 ['C44']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1431 ['C44']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1433 ['L85.5']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1435 ['Rm']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1437 ['Rm']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1439 ['Rm']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1460 ['L85.8']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1462 [nan]
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1471 ['C43']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1479 ['L92']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1481 ['L92']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1483 ['L92']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1485 ['L92']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1487 ['L92']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1489 ['L92']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1491 ['D22']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1493 ['D86.3']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1495 ['D86.3']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1497 ['D86.3']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1499 ['D86.3']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1501 ['D86.3']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1525 ['L98.9']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1527 [None]
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1529 ['C44']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1531 ['C44']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1533 ['C44']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1535 ['C44']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1537 ['C44']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1539 ['C44']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1541 ['C44']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1543 ['C44']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1545 ['C44']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1546 ['C44']
# White is missing!!!
# UV is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1548 ['C44']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1550 [nan]
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1552 ['Q80']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1554 ['Q80']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1556 ['Q80']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1558 ['Q80']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1560 ['Q80']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1562 ['Q80']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1566 ['D22']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1587 ['D22']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1588 [None]
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1593 ['L82']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1595 ['D18']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1603 ['C44']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1605 ['C44']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1609 ['C44']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1610 ['C44']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1613 ['C44']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1615 ['C44']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1617 ['C44']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1619 ['C44']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1620 ['C44']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1623 ['C44']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1625 ['C44']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1627 ['C44']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1633 [nan]
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1635 ['C44']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1637 ['C44']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1639 ['A63']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1641 ['A63']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1643 ['A63']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1645 ['D22']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1647 ['D22']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1649 [nan]
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1651 ['A63']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1653 ['A63']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1654 ['A63']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1657 ['D48']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1661 ['D48']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1663 ['D48']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1665 ['C43']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1667 ['C43']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1669 ['C43']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1679 ['L82']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1681 ['D48']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1701 ['C43']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1703 ['L98.8']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1705 ['C43']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1707 ['C44']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1709 ['C44']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1711 ['D48']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1713 ['D48']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1715 ['L21']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1717 ['L21']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1719 ['L21']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1725 [nan]
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1727 ['D22']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1729 ['C44']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1731 ['C44']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1733 ['C44']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1735 ['C44']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1755 ['PXE']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1757 ['PXE']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1759 ['PXE']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1761 ['PXE']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1763 ['PXE']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1765 ['PXE']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1767 ['PXE']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1769 ['PXE']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1771 ['PXE']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1773 ['PXE']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1775 ['PXE']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1777 ['PXE']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1779 ['PXE']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1781 ['PXE']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1783 ['PXE']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1785 ['PXE']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1787 ['PXE']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1791 [None]
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1793 ['L72']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1794 ['PXE']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1797 ['PXE']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1799 ['PXE']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1801 ['PXE']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1803 ['PXE']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1805 ['PXE']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1807 [None]
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1809 ['PXE']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1811 ['PXE']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1813 ['PXE']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1815 ['PXE']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1817 ['PXE']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1819 [nan]
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1821 ['PXE']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1823 ['PXE']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1825 ['PXE']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1827 ['PXE']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1829 ['PXE']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1831 ['PXE']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1833 ['PXE']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1835 ['PXE']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1837 [None]
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1839 ['PXE']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1841 ['PXE']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1843 ['D22']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1845 ['L57']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1847 ['L57']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1848 ['C44']
# R / IR / G is missing!!!
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1852 ['C44']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1854 ['C44']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1856 ['D48']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1858 [None]
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1860 ['D22']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1862 ['D22']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1864 ['C43']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1868 ['C44']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1870 [None]
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1872 ['Q82.5']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1874 ['Q82.5']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1876 ['Q82.5']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1877 ['C43']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1880 ['D22']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1882 ['L94.2']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1884 ['L94.2']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1886 ['L94.2']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1888 ['L94.2']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1890 ['L94.2']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1892 ['D21.9']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1894 ['D21.9']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1896 ['D21.9']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1898 ['D21.9']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1900 ['D21.9']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1902 ['D22']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1904 ['L85.1']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1906 [None]
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1908 [nan]
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1910 [None]
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1912 ['L80']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1914 ['C43']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1916 ['C43']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1918 ['C43']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1930 ['C43']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1932 ['C43']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1936 [nan]
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1938 ['L81.4']
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1952 [nan]
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1954 [nan]
# White is missing!!!
# k,v--> /mnt/data/raw/_melanoma/Checkyourskin/1956 [nan]
# White is missing!!!

# %%
print('Done')
# Out:
# Done

# %%
# df_cys_sorted.loc[df_cys_sorted['group'] == 523]

# %% [markdown]
# # Old LOC reading/copying (with designated R / IR / G / UV)

# %%
root_loc_old_img_folder = os.path.abspath('../../data/raw/_melanoma/merijumi_loc_old_colored')
root_loc_old_img_folder
# Out:
# '/mnt/data/raw/_melanoma/merijumi_loc_old_colored'

# %% [markdown]
# The idea is to gather old immages that had missing naming denoting channel R/IR/G/UV/White.
#
# To do this we have to read folder and collect paths to files (as well as info.txt files).
# We would like to collect ref / ada images as well!!!
#
# Then we will merge collected images from old format (ones not from *.tar sub-folders)

# %%
# '32.3222'[0:2]

# %%
def collect_images_loc_colored(non_tar_folder_path: str):
    images_paths_list = []
    for folder_file in os.listdir(non_tar_folder_path):
        img_file = os.path.join(non_tar_folder_path, folder_file)
        if os.path.isfile(img_file):
            if '.png' in folder_file or '.jpg' in folder_file or '.jpeg' in folder_file or '.tiff' in folder_file or '.txt' in folder_file:
                images_paths_list.append(img_file)
#                 print('      3) Image found:', folder_file)
            else:
#                 print('      3) Skipping file: ', folder_file)
                pass
        else:
#             print('      3) !!!! Found folder in subfolder: ', non_tar_folder_path, folder_file)
            pass
            
    return images_paths_list

# def get_earliest_date_time(images_paths_list):
#     for f_path in images_paths_list:
#         fname = os.path.basename(f_path).lower()
#         if fname.startswith('r') or fname.startswith('ir') or fname.startswith('g') or fname.startswith('uv'):
#             print(fname)
            
#     return None
                    
            
def process_non_tar_folder(non_tar_folder_path: str, date: str, patient_id: str):
#     print('   2) process_non_tar_folder', non_tar_folder_path)
    
    if 'kluda' in non_tar_folder_path or 'error' in non_tar_folder_path or 'analizei' in non_tar_folder_path:
        return []
    
    # We assume that above level contains "lesion_id"
    parent_folder_path = Path(non_tar_folder_path).parent
#     print('parent_folder_path', parent_folder_path)
    lesion_id = parent_folder_path.name
    
    metadata_json = {}  #load_metadata_csv(non_tar_folder_path)
    images_paths_list = collect_images_loc_colored(non_tar_folder_path)
    metadata_json['images_paths_list'] = images_paths_list
#     metadata_json['earliest_datetime'] = get_earliest_date_time(images_paths_list)
    metadata_json['date'] = date
    metadata_json['patient_id'] = patient_id
    metadata_json['lesion_id'] = lesion_id
    metadata_json['lesion_id_short'] = non_tar_folder_path.split('/')[-1:][0]
    metadata_json['folder_name'] = non_tar_folder_path  # this will allow to collect ref / ada images
    if 'ref' in non_tar_folder_path.lower():
        metadata_json['diagnoze_code'] = 'ref'
    elif 'ada' in non_tar_folder_path.lower():
        metadata_json['diagnoze_code'] = 'ada'
    elif 'cc' in non_tar_folder_path.lower():
        metadata_json['diagnoze_code'] = 'cc'
    else:
        lesion_id_short = metadata_json['lesion_id_short']
        if '.' in lesion_id_short:
            dot_indx = lesion_id_short.find('.')
            lesion_id_short = lesion_id_short[0:dot_indx]
        if ' ' in lesion_id_short:
            space_indx = lesion_id_short.find(' ')
            lesion_id_short = lesion_id_short[0:space_indx]
        
#         print(lesion_id_short)
        if 'b' in lesion_id_short.lower():
            lesion_id_short = lesion_id_short.lower().replace('b', '')
        if 'c' in lesion_id_short.lower():
            lesion_id_short = lesion_id_short.lower().replace('c', '')
        
        if not 'dif' in lesion_id_short.lower():
            lesion_id_int = int(lesion_id_short)
        else:
            # NO point to return this folder as it will not be matched with diagnosis
            print('Strange lesion_id: {}, root_folder: {}'.format(lesion_id_short, non_tar_folder_path))
            return []
        
        if 'onus' in patient_id.lower():
            # NO point to return this folder as it will not be matched with patient
            print('Strange patient_id: {}, root_folder: {}'.format(patient_id, non_tar_folder_path))
            return []
        
#         print(patient_id)
        if 'b' in patient_id.lower():
            patient_id = patient_id.lower().replace('b', '')
        if 'c' in patient_id.lower():
            patient_id = patient_id.lower().replace('c', '')
        if ' ' in patient_id:
            space_indx = patient_id.find(' ')
            patient_id = patient_id[0:space_indx]
        if '_' in patient_id:
            space_indx = patient_id.find('_')
            patient_id = patient_id[0:space_indx]
        
        patient_id_int = int(patient_id)
        df_patient_lesion = loc_eraf2017.loc[(loc_eraf2017['patient_id']==patient_id_int) & (loc_eraf2017['lesion_id']==lesion_id_int)]
        lst = df_patient_lesion['Kods'].tolist()
        if len(lst) == 1:
            metadata_json['diagnoze_code'] = lst[0]
        else:
            metadata_json['diagnoze_code'] = None
#             print(df_patient_lesion)
    return [metadata_json]

def folder_contains_images(root_folder_path):
    '''
    Returns true if at least two image files of interesting wavelenghts are present (R/IR/G/UV).
    '''
    r_present = 0
    ir_present = 0
    g_present = 0
    uv_present = 0
    for f in os.listdir(root_folder_path):
        if os.path.isfile(os.path.join(root_folder_path, f)):
            f_name = f.lower().replace('*','') 
#             print('      -- file={}, f_name={}'.format(f, f_name))
            if f_name.startswith('r') and r_present == 0:
                r_present = r_present + 1
#                 print('      -- R file={}, f_name={}, r_present={}'.format(f, f_name, r_present))
            elif f_name.startswith('ir') and ir_present == 0:
                ir_present = ir_present + 1
#                 print('      -- IR file={}, f_name={}, ir_present={}'.format(f, f_name, ir_present))
            elif f_name.startswith('g') and g_present == 0:
                g_present = g_present + 1
#                 print('      -- G file={}, f_name={}, g_present={}'.format(f, f_name, g_present))
            elif f_name.startswith('uv') and uv_present == 0:
                uv_present = uv_present + 1
#                 print('      -- UV file={}, f_name={}, uv_present={}'.format(f, f_name, uv_present))
#             else:
#                 print('         Unknown file type:', os.path.join(root_folder_path, f))
    score = r_present + ir_present + g_present + uv_present
#     print('      -- score={}'.format(int(r_present + ir_present + g_present + uv_present)))
#     print('      -- Folder {} contains images {} '.format(root_folder_path, score))
    return score >= 2

def folder_contains_folder(root_folder_path):
    '''
    Does what title says
    '''
    for f in os.listdir(root_folder_path):
        if os.path.isdir(os.path.join(root_folder_path, f)):
            return True
    return False


def process_loc_colored_subfolders(root_folder_path: str, date: str, patient_id: str):
    if os.path.isdir(root_folder_path):
#         print('         --> root_folder-{}'.format(root_folder_path))
        if 'tar' not in root_folder_path and folder_contains_images(root_folder_path):
            return process_non_tar_folder(root_folder_path, date, patient_id)
        if 'tar' not in root_folder_path and folder_contains_folder(root_folder_path):
            results_list = []
            for subfolder in os.listdir(root_folder_path):
                subfolder_path = os.path.join(root_folder_path, subfolder)
                if os.path.isdir(subfolder_path):
                    subresults_list = process_loc_colored_subfolders(subfolder_path, date, patient_id)
                    if len(subresults_list) > 0:
                        results_list.extend(subresults_list)
            return results_list
        
    return []

from tqdm.notebook import tqdm

def process_loc_colored_root_folder(_folder: str):
    full_rows_list = []
    for level1_folder in tqdm(os.listdir(_folder)):
        level1_subfolder = os.path.join(_folder, level1_folder)
        level1_date = level1_folder
        if os.path.isdir(level1_subfolder):
            for date_patient_id_folder in os.listdir(level1_subfolder):
                date_patient_id_folder_path = os.path.join(level1_subfolder, date_patient_id_folder)
#                 print('1)',date_patient_id_folder_path)
                if os.path.isdir(date_patient_id_folder_path) \
                   and 'VISION' not in date_patient_id_folder \
                   and 'bonuss' not in date_patient_id_folder:
                    if len(date_patient_id_folder) >= 10: 
                        date = date_patient_id_folder[0:10]
                        patient_id = date_patient_id_folder[11:]
                    else:
                        date = level1_date
                        patient_id = date_patient_id_folder
                    
#                     print('1) Folder:', date_patient_id_folder, ': date-', date, ': patient_id-', patient_id, '----')
                    rows_list = process_loc_colored_subfolders(date_patient_id_folder_path, date, patient_id) 
                    full_rows_list.extend(rows_list)
    return full_rows_list

# %%
files_lst_loc_colored = process_loc_colored_root_folder(root_loc_old_img_folder)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Strange lesion_id: 20190322_09-37-26_diff, root_folder: /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2019_03/2019-03-22_230/2/20190322_09-37-26_diff
# Strange lesion_id: 20190322_09-39-17_diff, root_folder: /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2019_03/2019-03-22_230/3.2/20190322_09-39-17_diff
# Strange lesion_id: 20190322_09-36-08_diff, root_folder: /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2019_03/2019-03-22_230/1/20190322_09-36-08_diff
# Strange lesion_id: 20190322_09-38-25_diff, root_folder: /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2019_03/2019-03-22_230/3.1/20190322_09-38-25_diff
# Strange lesion_id: 20190322_09-55-14_diff, root_folder: /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2019_03/2019-03-22_229/5/20190322_09-55-14_diff
# Strange lesion_id: 20190322_09-51-47_diff, root_folder: /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2019_03/2019-03-22_229/4/20190322_09-51-47_diff
# Strange lesion_id: 20190322_09-56-15_diff, root_folder: /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2019_03/2019-03-22_229/6/20190322_09-56-15_diff
# Strange lesion_id: 20190322_09-57-06_diff, root_folder: /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2019_03/2019-03-22_229/7/20190322_09-57-06_diff
# Strange lesion_id: 20190322_09-31-33_diff, root_folder: /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2019_03/2019-03-22_229/10/20190322_09-31-33_diff
# Strange lesion_id: 20190322_09-50-47_diff, root_folder: /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2019_03/2019-03-22_229/3/20190322_09-50-47_diff
# Strange lesion_id: 20190322_09-49-38_diff, root_folder: /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2019_03/2019-03-22_229/2/20190322_09-49-38_diff
# Strange lesion_id: 20190322_09-59-22_diff, root_folder: /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2019_03/2019-03-22_229/8/20190322_09-59-22_diff
# Strange lesion_id: 20190322_09-48-36_diff, root_folder: /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2019_03/2019-03-22_229/1/20190322_09-48-36_diff
# Strange patient_id: Bonuss, root_folder: /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2017_12/Bonuss/2017_12_04_54/1

# %%
len(files_lst_loc_colored)
# Out:
# 1914

# %%
files_lst_loc_colored[0:10]
# Out:
# [{'images_paths_list': ['/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/4/IR_a_10-27-50_885.png',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/4/G_a_10-27-35_880.png',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/4/UV_a_10-28-04_890.png',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/4/UV_a_10-28-03_889.png',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/4/R_a_10-27-42_882.png',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/4/R_a_10-27-44_884.png',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/4/IR_a_10-27-53_887.png',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/4/info.txt',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/4/R_a_10-27-43_883.png',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/4/IMG_3211.jpg',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/4/IR_a_10-27-51_886.png',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/4/UV_a_10-28-12_892.png',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/4/G_a_10-27-36_881.png',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/4/UV_a_10-28-10_891.png',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/4/UV_a_10-28-02_888.png',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/4/G_a_10-27-33_879.png'],
#   'date': '2018_02_09',
#   'patient_id': '88',
#   'lesion_id': '2018_02_09_88',
#   'lesion_id_short': '4',
#   'folder_name': '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/4',
#   'diagnoze_code': 'B07'},
#  {'images_paths_list': ['/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/ada1/IR_a_10-22-44_850.png',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/ada1/UV_a_10-22-52_854.png',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/ada1/R_a_10-22-34_846.png',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/ada1/info.txt',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/ada1/G_a_10-22-27_844.png',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/ada1/UV_a_10-22-49_852.png',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/ada1/IR_a_10-22-42_849.png',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/ada1/G_a_10-22-28_845.png',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/ada1/G_a_10-22-25_843.png',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/ada1/UV_a_10-22-51_853.png',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/ada1/R_a_10-22-36_847.png'],
#   'date': '2018_02_09',
#   'patient_id': '88',
#   'lesion_id': '2018_02_09_88',
#   'lesion_id_short': 'ada1',
#   'folder_name': '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/ada1',
#   'diagnoze_code': 'ada'},
#  {'images_paths_list': ['/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/ref/IR_a_09-31-31_827.png',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/ref/G_a_09-30-55_819.png',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/ref/UV_a_09-31-37_828.png',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/ref/R_a_09-31-17_824.png',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/ref/IR_a_09-31-30_826.png',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/ref/R_a_09-31-16_823.png',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/ref/UV_a_09-31-39_830.png',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/ref/info.txt',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/ref/R_a_09-31-14_822.png',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/ref/G_a_09-30-56_820.png',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/ref/IR_a_09-31-28_825.png',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/ref/G_a_09-30-58_821.png',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/ref/UV_a_09-31-38_829.png'],
#   'date': '2018_02_09',
#   'patient_id': '88',
#   'lesion_id': '2018_02_09_88',
#   'lesion_id_short': 'ref',
#   'folder_name': '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/ref',
#   'diagnoze_code': 'ref'},
#  {'images_paths_list': ['/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/ada2_4/R_a_10-28-34_900.png',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/ada2_4/UV_a_10-29-00_909.png',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/ada2_4/IR_a_10-28-45_904.png',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/ada2_4/G_a_10-28-27_897.png',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_09_88/ada2_4
png',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_12_90/ada1/UV_a_12-30-09_1051.png',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_12_90/ada1/IR_a_12-30-04_1050.png',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_12_90/ada1/info.txt',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_12_90/ada1/UV_a_12-30-11_1052.png',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_12_90/ada1/IR_a_12-30-01_1048.png',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_12_90/ada1/IR_a_12-30-02_1049.png',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_12_90/ada1/G_a_12-29-45_1043.png',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_12_90/ada1/G_a_12-29-43_1042.png',
#    '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_12_90/ada1/R_a_12-29-52_1045.png'],
#   'date': '2018_02_12',
#   'patient_id': '90',
#   'lesion_id': '2018_02_12_90',
#   'lesion_id_short': 'ada1',
#   'folder_name': '/mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_02/2018_02_12_90/ada1',
#   'diagnoze_code': 'ada'}]

# %%
list(map(lambda x: x['diagnoze_code'], files_lst_loc_colored))[0:10]
# Out:
# ['B07', 'ada', 'ref', 'ada', 'B07', 'B07', 'Rb', 'ada', 'D22', 'ada']

# %% [markdown]
# ## Copy old images with names to folders

# %%
df_loc_old = pd.DataFrame(files_lst_loc_colored)

# %%
df_loc_old.head(50)
# Out:
#                                     images_paths_list        date patient_id  \
# 0   [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...  2018_02_09         88
# 1   [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...  2018_02_09         88
# 2   [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...  2018_02_09         88
# 3   [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...  2018_02_09         88
# 4   [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...  2018_02_09         88
# 5   [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...  2018_02_09         88
# 6   [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...  2018_02_09         88
# 7   [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...  2018_02_12         90
# 8   [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...  2018_02_12         90
# 9   [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...  2018_02_12         90
# 10  [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...  2018_02_12         90
# 11  [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...  2018_02_12         90
# 12  [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...  2018_02_12         90
# 13  [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...  2018_02_12         90
# 14  [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...  2018_02_12         90
# 15  [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...  2018_02_12         90
# 16  [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...  2018_02_07         85
# 17  [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...  2018_02_07         85
# 18  [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...  2018_02_07         85
# 19  [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...  2018_02_07         85
# 20  [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...  2018_02_07         85
# 21  [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...  2018_02_07         85
# 22  [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...  2018_02_07         85
# 23  [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...  2018_02_07         85
# 24  [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...  2018_02_07         85
# 25  [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...  2018_02_07         87
# 26  [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...  2018_02_07         87
# 27  [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...  2018_02_07         87
# 28  [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...  2018_02_07         87
# 29  [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...  2018_02_07         87
# 30  [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...  2018_02_07         87
# 31  [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...  2018_02_07         87
# 32  [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...     2018_02         84
# 33  [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...     2018_02         84
# 34  [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...  2018_02_12         89
# 35  [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...  2018_02_12         89
# 36  [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...  2018_02_12         89
# 37  [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...  2018_02_12         89
# 38  [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...  2018_02_12         89
# 39  [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...  2018_02_12         89
# 40  [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...  2018_02_12         89
# 41  [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...     2018_02         83
# 42  [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...     2018_02         83
# 43  [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...     2018_02         83
# 44  [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...     2018_02         83
# 45  [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...     2018_02         83
# 46  [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...     2018_02         83
# 47  [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...     2018_02         83
# 48  [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...     2018_02         83
# 49  [/mnt/data/raw/_melanoma/merijumi_loc_old_colo...  2018_02_07         86
#
#         lesion_id lesion_id_short  \
# 0   2018_02_09_88               4
# 1   2018_02_09_88            ada1
# 2   2018_02_09_88             ref
# 3   2018_02_09_88          ada2_4
# 4   2018_02_09_88               3
# 5   2018_02_09_88               2
# 6   2018_02_09_88               1
# 7   2018_02_12_90            ada4
# 8   2018_02_12_90               4
# 9   2018_02_12_90            ada1
# 10  2018_02_12_90             ref
# 11  2018_02_12_90               3
# 12  2018_02_12_90            ada2
# 13  2018_02_12_90               2
# 14  2018_02_12_90            ada3
# 15  2018_02_12_90               1
# 16  2018_02_07_85               5
# 17  2018_02_07_85               4
# 18  2018_02_07_85            ada1
# 19  2018_02_07_85             ref
# 20  2018_02_07_85               3
# 21  2018_02_07_85            ada2
# 22  2018_02_07_85               2
# 23  2018_02_07_85          ada3_5
# 24  2018_02_07_85               1
# 25  2018_02_07_87          ada1_2
# 26  2018_02_07_87               4
# 27  2018_02_07_87          ada3_4
# 28  2018_02_07_87             ref
# 29  2018_02_07_87               3
# 30  2018_02_07_87               2
# 31  2018_02_07_87               1
# 32             84            ada1
# 33             84               1
# 34  2018_02_12_89            ada1
# 35  2018_02_12_89             ref
# 36  2018_02_12_89               3
# 37  2018_02_12_89            ada2
# 38  2018_02_12_89               2
# 39  2018_02_12_89            ada3
# 40  2018_02_12_89               1
# 41             83            ada4
# 42             83               4
# 43             83            ada1
# 44             83               3
# 45             83            ada2
# 46             83               2
# 47             83            ada3
# 48             83               1
# 49  2018_02_07_86            ada1
#
#                                           folder_name diagnoze_code
# 0   /mnt/data/raw/_melanoma/merijumi_loc_old_color...           B07
# 1   /mnt/data/raw/_melanoma/merijumi_loc_old_color...           ada
# 2   /mnt/data/raw/_melanoma/merijumi_loc_old_color...           ref
# 3   /mnt/data/raw/_melanoma/merijumi_loc_old_color...           ada
# 4   /mnt/data/raw/_melanoma/merijumi_loc_old_color...           B07
# 5   /mnt/data/raw/_melanoma/merijumi_loc_old_color...           B07
# 6   /mnt/data/raw/_melanoma/merijumi_loc_old_color...            Rb
# 7   /mnt/data/raw/_melanoma/merijumi_loc_old_color...           ada
# 8   /mnt/data/raw/_melanoma/merijumi_loc_old_color...           D22
# 9   /mnt/data/raw/_melanoma/merijumi_loc_old_color...           ada
# 10  /mnt/data/raw/_melanoma/merijumi_loc_old_color...           ref
# 11  /mnt/data/raw/_melanoma/merijumi_loc_old_color...           L82
# 12  /mnt/data/raw/_melanoma/merijumi_loc_old_color...           ada
# 13  /mnt/data/raw/_melanoma/merijumi_loc_old_color...            Rb
# 14  /mnt/data/raw/_melanoma/merijumi_loc_old_color...           ada
# 15  /mnt/data/raw/_melanoma/merijumi_loc_old_color...            Rb
# 16  /mnt/data/raw/_melanoma/merijumi_loc_old_color...           D48
# 17  /mnt/data/raw/_melanoma/merijumi_loc_old_color...            Rm
# 18  /mnt/data/raw/_melanoma/merijumi_loc_old_color...           ada
# 19  /mnt/data/raw/_melanoma/merijumi_loc_old_color...           ref
# 20  /mnt/data/raw/_melanoma/merijumi_loc_old_color...            Rm
# 21  /mnt/data/raw/_melanoma/merijumi_loc_old_color...           ada
# 22  /mnt/data/raw/_melanoma/merijumi_loc_old_color...           L93
# 23  /mnt/data/raw/_melanoma/merijumi_loc_old_color...           ada
# 24  /mnt/data/raw/_melanoma/merijumi_loc_old_color...           L93
# 25  /mnt/data/raw/_melanoma/merijumi_loc_old_color...           ada
# 26  /mnt/data/raw/_melanoma/merijumi_loc_old_color...           L82
# 27  /mnt/data/raw/_melanoma/merijumi_loc_old_color...           ada
# 28  /mnt/data/raw/_melanoma/merijumi_loc_old_color...           ref
# 29  /mnt/data/raw/_melanoma/merijumi_loc_old_color...            Rb
# 30  /mnt/data/raw/_melanoma/merijumi_loc_old_color...           L82
# 31  /mnt/data/raw/_melanoma/merijumi_loc_old_color...            Rb
# 32  /mnt/data/raw/_melanoma/merijumi_loc_old_color...           ada
# 33  /mnt/data/raw/_melanoma/merijumi_loc_old_color...           C44
# 34  /mnt/data/raw/_melanoma/merijumi_loc_old_color...           ada
# 35  /mnt/data/raw/_melanoma/merijumi_loc_old_color...           ref
# 36  /mnt/data/raw/_melanoma/merijumi_loc_old_color...           C43
# 37  /mnt/data/raw/_melanoma/merijumi_loc_old_color...           ada
# 38  /mnt/data/raw/_melanoma/merijumi_loc_old_color...           D48
# 39  /mnt/data/raw/_melanoma/merijumi_loc_old_color...           ada
# 40  /mnt/data/raw/_melanoma/merijumi_loc_old_color...           C43
# 41  /mnt/data/raw/_melanoma/merijumi_loc_old_color...           ada
# 42  /mnt/data/raw/_melanoma/merijumi_loc_old_color...           D18
# 43  /mnt/data/raw/_melanoma/merijumi_loc_old_color...           ada
# 44  /mnt/data/raw/_melanoma/merijumi_loc_old_color...           D17
# 45  /mnt/data/raw/_melanoma/merijumi_loc_old_color...           ada
# 46  /mnt/data/raw/_melanoma/merijumi_loc_old_color...            Rb
# 47  /mnt/data/raw/_melanoma/merijumi_loc_old_color...           ada
# 48  /mnt/data/raw/_melanoma/merijumi_loc_old_color...             R
# 49  /mnt/data/raw/_melanoma/merijumi_loc_old_color...           ada

# %%
target_loc_old_colored_img_folder = os.path.abspath('../../data/interim/_melanoma_20200728/loc_old_colored')
target_loc_old_colored_img_folder
# Out:
# '/mnt/data/interim/_melanoma_20200728/loc_old_colored'

# %%
import shutil

def copy_loc_old_colored_immages(files_lst_loc_colored, target_folder):
    '''
    Function copies list of loc-old-colored files into new structure
    No correlation.txt is created as files have unique naming.
    '''
    
    def collect_images_paths(images_paths_list):
        r = []
        ir = []
        g = []
        uv = []
        txt = []
        for f_path in images_paths_list:
            f_name = os.path.basename(f_path)
            f_name_trunc = f_name.replace('*', '').lower()
            if f_name_trunc.startswith('r'):
                r.append(f_path)
            elif f_name_trunc.startswith('ir'):
                ir.append(f_path)
            elif f_name_trunc.startswith('g'):
                g.append(f_path)
            elif f_name_trunc.startswith('uv'):
                uv.append(f_path)
            elif f_name_trunc.endswith('txt'):
                txt.append(f_path)
            else:
                print('Unknown type of file! {}'.format(f_path))
        return r, ir, g, uv, txt
    
    os.makedirs(target_folder)
    
    for record in tqdm(files_lst_loc_colored):
        images_paths_list = record['images_paths_list']
        date_str = record['date']
        patient_id = record['patient_id']
        lesion_id_short = record['lesion_id_short']
        diagnoze_code = record['diagnoze_code']
        if diagnoze_code is not None and str(diagnoze_code) != 'nan':
            if diagnoze_code.endswith('imi'):
                diagnoze_code = diagnoze_code.replace('imi', '')
            diagnoze_code = diagnoze_code.strip()
#             print(diagnoze_code)
            target_parent_folder = os.path.join(target_folder, diagnoze_code, date_str + '_' + patient_id + '_' + lesion_id_short)
            
            os.makedirs(os.path.join(target_parent_folder, 'r'))
            os.makedirs(os.path.join(target_parent_folder, 'ir'))
            os.makedirs(os.path.join(target_parent_folder, 'g'))
            os.makedirs(os.path.join(target_parent_folder, 'uv'))
            
            r, ir, g, uv, txt = collect_images_paths(images_paths_list)
#             print('r:{}, ir:{}, g:{}, uv:{}, txt:{}'.format(r, ir, g, uv, txt))
        
            for src_r_path in r:
                shutil.copy(src_r_path, os.path.join(target_parent_folder, 'r', os.path.basename(src_r_path)))
            
            for src_ir_path in ir:
                shutil.copy(src_ir_path, os.path.join(target_parent_folder, 'ir', os.path.basename(src_ir_path)))
                
            for src_g_path in g:
                shutil.copy(src_g_path, os.path.join(target_parent_folder, 'g', os.path.basename(src_g_path)))
                
            for src_uv_path in uv:
                shutil.copy(src_uv_path, os.path.join(target_parent_folder, 'uv', os.path.basename(src_uv_path)))
                
            for src_txt_path in txt:
                shutil.copy(src_txt_path, os.path.join(target_parent_folder, os.path.basename(src_txt_path)))

# %%
copy_loc_old_colored_immages(files_lst_loc_colored, target_loc_old_colored_img_folder)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=
jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_03/2018_03_19_98/9/IMG_6764.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_03/2018_03_19_98/1 rēta pēc C43/IMG_6757.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_03/2018_03_19_98/8/IMG_6765.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_03/2018_03_14_97/5/5.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_03/2018_03_14_97/4/4.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_03/2018_03_14_97/6/6.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_03/2018_03_14_97/7/7_9.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_03/2018_03_14_97/3/3.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_03/2018_03_14_97/2/2.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_03/2018_03_14_97/9/7_9.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_03/2018_03_14_97/5-7 un 9 ref/6.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_03/2018_03_14_97/8/8.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_03/2018_03_14_97/1/1.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2019_01/2019-01-14_213/3/IMAG8206.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2019_01/2019-01-14_213/2/IMAG8205.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2017_11/2017_11_17_34/9/IM9.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2017_11/2017_11_17_34/8/IM8.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2017_11/2017_11_17_36/1/IMAG4559.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_09/2018-09-12_169/5/IMAG6904.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_09/2018-09-12_169/4/2-4.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_09/2018-09-12_169/6/IMAG6905.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_09/2018-09-12_169/3/2-4.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_09/2018-09-12_169/2/2-4.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_09/2018-09-12_169/1/IMAG6901.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_05/2018-05-30_125/4/IMAG5918.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_05/2018-05-30_125/2/IMAG5916.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_05/2018-05-30_125/1/IMAG5916.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_05/2018-05-28_123/4/IMG_3810.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_05/2018-05-28_123/3/IMG_3809.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_05/2018-05-28_123/2/IMG_3808.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_05/2018-05-28_123/1/IMG_3807.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_05/2018-05-28_124/1/IMG_3811.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_08/2018-08-24_93B/93B/1B/IMAG6711.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_08/2018-08-24_93B/93B/5B/IMAG6709.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_08/2018-08-24_93B/93B/10/IMAG6712.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_08/2018-08-24_93B/93B/9B/IMAG6707.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_08/2018-08-24_158/4/IMAG6718.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_08/2018-08-24_158/3/IMAG6715.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_08/2018-08-24_158/2/IMAG6713.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_08/2018-08-31_162/5/3-4-5.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_08/2018-08-31_162/4/3-4-5.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_08/2018-08-31_162/6/IMAG6809.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_08/2018-08-31_162/3/3-4-5.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_08/2018-08-31_162/2/IMAG6805.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_08/2018-08-31_162/1/IMAG6804.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_10/2018-10-15_175/5/IMAG7210.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_10/2018-10-15_175/4/IMAG7209.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_10/2018-10-15_175/6/IMAG7212.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_10/2018-10-15_175/7/IMAG7213.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_10/2018-10-15_175/3/IMAG7208.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_10/2018-10-15_175/2/IMAG7207.jpg
# Unknown type of file! /mnt/data/raw/_melanoma/merijumi_loc_old_colored/2018_10/2018-10-15_175/1/IMAG7206.jpg

# %%
# date_time = v['datetime']
# target_parent_folder = os.path.join(target_cys_img_folder, code, date_time)

# # prepare folders
# if src_r_path is not None:
#     os.makedirs(os.path.join(target_parent_folder, 'r'))
#     os.makedirs(os.path.join(target_parent_folder, 'ir'))
#     os.makedirs(os.path.join(target_parent_folder, 'g'))

#     shutil.copy(src_r_path, os.path.join(target_parent_folder, 'r', os.path.basename(src_r_path)))
#     shutil.copy(src_ir_path, os.path.join(target_parent_folder, 'ir', os.path.basename(src_ir_path)))
#     shutil.copy(src_g_path, os.path.join(target_parent_folder, 'g', os.path.basename(src_g_path)))
# if src_white_path is not None:
#     os.makedirs(os.path.join(target_parent_folder, 'white'))
#     shutil.copy(src_white_path, os.path.join(target_parent_folder, 'white', os.path.basename(src_white_path)))
# if src_uv_paths is not None:
#     os.makedirs(os.path.join(target_parent_folder, 'uv'))
#     for src_uv_path in src_uv_paths:
#         shutil.copy(src_uv_path, os.path.join(target_parent_folder, 'uv', os.path.basename(src_uv_path)))

# df_meta = pd.DataFrame({'measurementSetId': measurements_list, 'folder': folders_list})
# df_meta.to_csv(os.path.join(target_parent_folder, 'correlations.csv'))

# %%
# loc_eraf2017.rename(columns={'Pacienta nr': 'patient_id', 'Veidojuma Nr': 'lesion_id'}, inplace=True)

# loc_eraf2017['patient_id'] = pd.to_numeric(loc_eraf2017['patient_id'], errors='coerce', downcast='signed')
# loc_eraf2017['lesion_id'] = pd.to_numeric(loc_eraf2017['lesion_id'], errors='coerce', downcast='signed')

# df_loc['patient_id'] = pd.to_numeric(df_loc['patient_id'], errors='coerce', downcast='signed')
# df_loc['lesion_id'] = pd.to_numeric(df_loc['lesion_id'], errors='coerce', downcast='signed')

# df_loc_merged = pd.merge(df_loc, loc_eraf2017, how='inner', on=['patient_id', 'lesion_id'])

# %%
# loc_eraf2017.head(10)

# %%
# list(loc_eraf2017.columns)

# %%
# loc_eraf2017.drop(['Dzimums (s- sieviete, v- vīrietis)', 'Dzimšanas gads', 'Vecums mērīšanas brīdī, gadi', 'Lokalizācija', 'Piezīmes', 'Vizītes Datums', 'Clark',
#  'Stadija',
#  'TNM',
#  'Histoloģija',
#  'Citoloģija',
#  'Piezīmes.1',
#  'Unnamed: 19',
#  'Unnamed: 20',
#  'Fototips',
#  'Veidojuma izmērs: GarumsxPlatumsxAugstums, mm',
#  'Unnamed: 23',
#  'Izmeklējuma veids (d-dermaskopija; s- siaskopija)'], axis=1, inplace=False)

# %% [markdown]
# # Summary

# %%
import os

diagnoze_counts = {}

root_paths = ['/mnt/data/interim/_melanoma_20200728/checkyourskin', '/mnt/data/interim/_melanoma_20200728/loc', '/mnt/data/interim/_melanoma_20200728/loc_old_colored']
for r in root_paths:
    r_diagnoze_folders = os.listdir(r)
    r_diagnoze_folders = map(lambda p: os.path.join(r, p), r_diagnoze_folders)
    r_diagnoze_folders = list(filter(lambda p: os.path.isdir(p), r_diagnoze_folders))
    for diagnoze in r_diagnoze_folders:
        diagnoze_name = os.path.basename(os.path.normpath(diagnoze.lower())).upper()
#         diagnoze = diagnoze.lower()
        if diagnoze_name not in diagnoze_counts:
            diagnoze_counts[diagnoze_name] = 0
        count = len(list(os.listdir(diagnoze)))
        diagnoze_counts[diagnoze_name] = diagnoze_counts[diagnoze_name] + count
    
# sort dict with diagnoze counts
{k: v for k, v in sorted(diagnoze_counts.items(), key=lambda item: item[1])}
# Out:
# {'L72': 1,
#  'L85.8': 1,
#  'L85.1': 1,
#  'B07.9': 1,
#  'L90.9': 1,
#  'L81.2': 1,
#  'D81': 1,
#  'L85.5': 2,
#  'D17': 2,
#  'L72.3': 3,
#  'Q82.5': 3,
#  'L21': 3,
#  'D48.5': 3,
#  'M79.81': 3,
#  'L94.0': 3,
#  'L57.0': 3,
#  'D03.9': 4,
#  'L93': 4,
#  'C44IMI': 4,
#  'D21.9': 5,
#  'L80': 5,
#  'D86.3': 5,
#  'L94.2': 5,
#  'RL': 5,
#  'L92': 6,
#  'Q80': 6,
#  'D09': 6,
#  'A63': 6,
#  'L98.8': 6,
#  'RS': 6,
#  'L30': 6,
#  'L81.4': 7,
#  'L57': 9,
#  'T': 11,
#  'L40': 12,
#  'L81': 29,
#  'RM': 31,
#  'L57.9': 35,
#  'D18': 36,
#  'B07': 41,
#  'L98.9': 42,
#  'C43': 43,
#  'PXE': 54,
#  'BENIGN': 57,
#  'R': 85,
#  'CC': 85,
#  'L85': 91,
#  'D48': 101,
#  'L82': 131,
#  'D23': 145,
#  'C44': 167,
#  'NAN': 171,
#  'ADA': 172,
#  'RB': 209,
#  'D22': 398,
#  'REF': 437}
